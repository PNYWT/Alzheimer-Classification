# %%
import pandas as pd
import numpy as np

# %%
dataSet = pd.read_csv("Alzheimer.csv")
dataSet
# Out:
#          HN         Education   age  hypertension  heart_disease  \
# 0     11046  Secondary School  67.0             0              1
# 1     51676          Bachelor  61.0             0              0
# 2     35112  Secondary School  80.0             0              1
# 3     67182          Bachelor  49.0             0              0
# 4      1665          Bachelor  79.0             1              0
# ...     ...               ...   ...           ...            ...
# 4095  68398  Secondary School  82.0             1              0
# 4096  14180          Bachelor  13.0             0              0
# 4097  44873          Bachelor  81.0             0              0
# 4098  19723          Bachelor  35.0             0              0
# 4099  44679          Bachelor  44.0             0              0
#
#      family history Occupation Triglycerides  Blood Sugar   BMI  \
# 0               Yes    Private        Normal       228.69  36.6
# 1               Yes  Freelance          High       202.21   NaN
# 2               Yes    Private          High       105.92  32.5
# 3               Yes    Private        Normal       171.23  34.4
# 4               Yes  Freelance          High       174.12  24.0
# ...             ...        ...           ...          ...   ...
# 4095            Yes  Freelance          High        71.97  28.3
# 4096             No     Farmer          High       103.08  18.6
# 4097            Yes  Freelance        Normal       125.20  40.0
# 4098            Yes  Freelance          High        82.99  30.6
# 4099            Yes    Officer        Normal        85.28  26.2
#
#        smoking_status  alzheimer
# 0     formerly smoked          1
# 1        never smoked          1
# 2        never smoked          1
# 3              smokes          1
# 4        never smoked          1
# ...               ...        ...
# 4095     never smoked          0
# 4096          Unknown          0
# 4097     never smoked          0
# 4098     never smoked          0
# 4099          Unknown          0
#
# [4100 rows x 12 columns]

# %% [markdown]
# # MARK: Data Processing

# %%
dataSet.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4100 entries, 0 to 4099
# Data columns (total 12 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   HN              4100 non-null   int64
#  1   Education       4100 non-null   object
#  2   age             4100 non-null   float64
#  3   hypertension    4100 non-null   int64
#  4   heart_disease   4100 non-null   int64
#  5   family history  4100 non-null   object
#  6   Occupation      4100 non-null   object
#  7   Triglycerides   4100 non-null   object
#  8   Blood Sugar     4100 non-null   float64
#  9   BMI             3936 non-null   float64
#  10  smoking_status  4100 non-null   object
#  11  alzheimer       4100 non-null   int64
# dtypes: float64(3), int64(4), object(5)
# memory usage: 384.5+ KB

# %%
dataSet.isna().sum()
# Out:
# HN                  0
# Education           0
# age                 0
# hypertension        0
# heart_disease       0
# family history      0
# Occupation          0
# Triglycerides       0
# Blood Sugar         0
# BMI               164
# smoking_status      0
# alzheimer           0
# dtype: int64

# %%
dataSet[(dataSet['BMI'].isna()) & (dataSet['alzheimer'] == 1)]
# Out:
#         HN         Education    age  hypertension  heart_disease  \
# 1    51676          Bachelor  61.00             0              0
# 8    27466          Bachelor  59.00             0              0
# 13   38213  Secondary School  78.00             0              1
# 19   25226  Secondary School  57.00             0              1
# 27   61843  Secondary School  58.00             0              0
# 29   69160  Secondary School  59.00             0              0
# 43    1845          Bachelor  63.00             0              0
# 46   37937          Bachelor  75.00             0              1
# 49    8752          Bachelor  63.00             0              0
# 54    7356  Secondary School  75.00             0              0
# 60   70676          Bachelor  76.00             0              0
# 68   45805          Bachelor  51.00             0              0
# 71   26015          Bachelor  66.00             0              0
# 74   70042  Secondary School  58.00             0              0
# 95    2346  Secondary School  58.00             0              0
# 102  36706          Bachelor  76.00             0              0
# 114  14164          Bachelor  72.00             0              0
# 116   3352  Secondary School  78.00             1              0
# 119  48796          Bachelor  75.00             0              0
# 123  31563          Bachelor  38.00             0              0
# 136  41241  Secondary School  65.00             0              0
# 140  11933          Bachelor  79.00             0              0
# 150  50931          Bachelor  76.00             0              0
# 151  16590  Secondary School  71.00             0              1
# 152  69768          Bachelor   1.32             0              0
# 157  43364  Secondary School  79.00             1              0
# 160  28939  Secondary School  64.00             0              0
# 161  60739          Bachelor  79.00             1              1
# 164  40899          Bachelor  78.00             0              0
# 168  33486          Bachelor  80.00             0              0
# 173   8003          Bachelor  77.00             0              0
# 179  66955  Secondary School  61.00             0              1
# 188  18937  Secondary School  79.00             0              0
# 190  54695  Secondary School  74.00             0              0
# 208  25904          Bachelor  76.00             1              1
# 217  39105  Secondary School  74.00             0              0
# 237  34060  Secondary School  71.00             1              0
#
#     family history Occupation Triglycerides  Blood Sugar  BMI  \
# 1              Yes  Freelance          High       202.21  NaN
# 8              Yes    Private          High        76.15  NaN
# 13             Yes    Private        Normal       219.84  NaN
# 19              No    Officer        Normal       217.08  NaN
# 27             Yes    Private          High       189.84  NaN
# 29             Yes    Private          High       211.78  NaN
# 43             Yes    Private        Normal        90.90  NaN
# 46              No  Freelance        Normal       109.78  NaN
# 49             Yes    Officer        Normal       197.54  NaN
# 54             Yes    Private        Normal       104.72  NaN
# 60             Yes    Officer          High        62.57  NaN
# 68             Yes    Private        Normal       165.31  NaN
# 71             Yes  Freelance        Normal       101.45  NaN
# 74             Yes    Private        Normal        71.20  NaN
# 95             Yes    Private        Normal        82.30  NaN
# 102            Yes  Freelance        Normal       106.41  NaN
# 114            Yes    Private        Normal       219.91  NaN
# 116            Yes  Freelance        Normal        93.13  NaN
# 119            Yes    Officer        Normal        62.48  NaN
# 123            Yes    Private          High       101.45  NaN
# 136            Yes  Freelance        Normal        68.43  NaN
# 140            Yes    Private          High       169.67  NaN
# 150            Yes    Private        Normal        57.92  NaN
# 151            Yes    Private        Normal        81.76  NaN
# 152             No     Farmer        Normal        70.37  NaN
# 157            Yes    Private          High        75.02  NaN
# 160            Yes  Freelance          High       111.98  NaN
# 161             No  Freelance          High        60.94  NaN
# 164            Yes  Freelance          High        60.67  NaN
# 168            Yes    Officer        Normal       110.66  NaN
# 173             No    Private        Normal        81.32  NaN
# 179            Yes    Private        Normal       209.86  NaN
# 188            Yes    Private          High       114.77  NaN
# 190            Yes    Private        Normal       167.13  NaN
# 208            Yes  Freelance        Normal       199.86  NaN
# 217            Yes  Freelance          High        60.98  NaN
# 237            Yes  Freelance          High        87.80  NaN
#
#       smoking_status  alzheimer
# 1       never smoked          1
# 8            Unknown          1
# 13           Unknown          1
# 19           Unknown          1
# 27           Unknown          1
# 29   formerly smoked          1
# 43   formerly smoked          1
# 46           Unknown          1
# 49      never smoked          1
# 54           Unknown          1
# 60   formerly smoked          1
# 68      never smoked          1
# 71           Unknown          1
# 74           Unknown          1
# 95            smokes          1
# 102  formerly smoked          1
# 114          Unknown          1
# 116  formerly smoked          1
# 119          Unknown          1
# 123  formerly smoked          1
# 136  formerly smoked          1
# 140          Unknown          1
# 150  formerly smoked          1
# 151           smokes          1
# 152          Unknown          1
# 157     never smoked          1
# 160  formerly smoked          1
# 161     never smoked          1
# 164  formerly smoked          1
# 168          Unknown          1
# 173          Unknown          1
# 179          Unknown          1
# 188  formerly smoked          1
# 190          Unknown          1
# 208           smokes          1
# 217     never smoked          1
# 237          Unknown          1

# %%
len(dataSet[(dataSet['alzheimer'] == 1)])
# Out:
# 239

# %%
len(dataSet[(dataSet['BMI'].isna()) & (dataSet['alzheimer'] == 1)])
# Out:
# 37

# %%
len(dataSet[(dataSet['BMI'].isna() == False) & (dataSet['alzheimer'] == 1)])
# Out:
# 202

# %% [markdown]
# ## สร้าง contingency table ระหว่างแต่ละ feature และ class target (ตารางสรุปความถี่ของ Feature)

# %%
from scipy.stats import chi2_contingency
import matplotlib.pyplot as plt

# %%
contingency_tables = {}
for feature in dataSet.columns:
    if feature != 'alzheimer':
        contingency_table = pd.crosstab(dataSet[feature], dataSet['alzheimer'])
        contingency_tables[feature] = contingency_table

# %% [markdown]
# ## ทดสอบ Chi-Square และแสดงผลลัพธ์

# %%
chi_square_results = {}
for feature, contingency_table in contingency_tables.items():
    chi2, p, _, _ = chi2_contingency(contingency_table)
    chi_square_results[feature] = {'Chi-Square': chi2, 'p-value': p}

# %%
# for feature, result in chi_square_results.items():
#     print(f"Feature: {feature}")
#     print(f"Chi-Square: {result['Chi-Square']:.4f}")
#     print(f"p-value: {result['p-value']:.4f}")
#     print("")

# %%
sorted_results = sorted(chi_square_results.items(), key=lambda x: x[1]['Chi-Square'], reverse=True)

features = [item[0] for item in sorted_results]
chi_square_values = [item[1]['Chi-Square'] for item in sorted_results]

plt.figure(figsize=(12, 6))
plt.barh(features, chi_square_values)
plt.xlabel('Chi-Square Value')
plt.ylabel('Feature')
plt.title('Chi-Square Test Results for Features vs. Alzheimer')
plt.gca().invert_yaxis()  # กลับขั้น Feature เพื่อเรียงจากมากไปน้อย
plt.show()

# %% [markdown]
# ### MARK: จากการตรวจสอบ พิจารณา Top 5 ความสัมพันธ์ระหว่าง Feature กับ Class พบว่า BMI ค่อนข้างมีผลกับ Class จึงตัดสินใจแก้ไข BMI None ด้วยค่าเฉลี่ย

# %%
average_bmi = dataSet['BMI'].mean()
dataSet['BMI'].fillna(average_bmi, inplace=True)

# %%
dataSet.isna().sum()
# Out:
# HN                0
# Education         0
# age               0
# hypertension      0
# heart_disease     0
# family history    0
# Occupation        0
# Triglycerides     0
# Blood Sugar       0
# BMI               0
# smoking_status    0
# alzheimer         0
# dtype: int64

# %% [markdown]
# ### MARK: ตรวจสอบ Class Target จำนวนเหมาะสมกันหรือไม่

# %%
print("Target == 1 ->", len(dataSet.loc[dataSet["alzheimer"] == 1, "alzheimer"]))
# Out:
# Target == 1 -> 239

# %%
print("Target == 0 ->", len(dataSet.loc[dataSet["alzheimer"] == 0, "alzheimer"]))
# Out:
# Target == 0 -> 3861

# %% [markdown]
# ### MARK: ปรับข้อมูล เป็น 0,1 <- LabelEncoder

# %%
from sklearn.preprocessing import LabelEncoder

# %%
dataSet.head()
# Out:
#       HN         Education   age  hypertension  heart_disease family history  \
# 0  11046  Secondary School  67.0             0              1            Yes
# 1  51676          Bachelor  61.0             0              0            Yes
# 2  35112  Secondary School  80.0             0              1            Yes
# 3  67182          Bachelor  49.0             0              0            Yes
# 4   1665          Bachelor  79.0             1              0            Yes
#
#   Occupation Triglycerides  Blood Sugar        BMI   smoking_status  alzheimer
# 0    Private        Normal       228.69  36.600000  formerly smoked          1
# 1  Freelance          High       202.21  28.680056     never smoked          1
# 2    Private          High       105.92  32.500000     never smoked          1
# 3    Private        Normal       171.23  34.400000           smokes          1
# 4  Freelance          High       174.12  24.000000     never smoked          1

# %%
label_encoder = LabelEncoder()

# %%
dataSet['Education'] = label_encoder.fit_transform(dataSet['Education'])
dataSet['family history'] = label_encoder.fit_transform(dataSet['family history'])
dataSet['Occupation'] = label_encoder.fit_transform(dataSet['Occupation'])
dataSet['Triglycerides'] = label_encoder.fit_transform(dataSet['Triglycerides'])
dataSet['smoking_status'] = label_encoder.fit_transform(dataSet['smoking_status'])

# %%
dataSet
# Out:
#       HN  Education   age  hypertension  heart_disease  family history  \
# 0  11046          1  67.0             0              1               1
# 1  51676          0  61.0             0              0               1
# 2  35112          1  80.0             0              1               1
# 3  67182          0  49.0             0              0               1
# 4   1665          0  79.0             1              0               1
#
#    Occupation  Triglycerides  Blood Sugar        BMI  smoking_status  \
# 0           4              1       228.69  36.600000               1
# 1           1              0       202.21  28.680056               2
# 2           4              0       105.92  32.500000               2
# 3           4              1       171.23  34.400000               3
# 4           1              0       174.12  24.000000               2
#
#    alzheimer
# 0          1
# 1          1
# 2          1
# 3          1
# 4          1

# %% [markdown]
# # MARK: แบ่งข้อมูล

# %%
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, classification_report
from sklearn import tree
from sklearn.tree import plot_tree
import matplotlib.pyplot as plt

# %% [markdown]
# ### MARK: train_test_split

# %%
X = dataSet.drop(['HN', 'alzheimer'], axis=1)#dataSet.drop('alzheimer', axis=1)
y = dataSet["alzheimer"]
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# %%
X_train.head()
# Out:
#       Education   age  hypertension  heart_disease  family history  \
# 4002          1  12.0             0              0               0
# 1334          0  35.0             0              0               1
# 765           0  23.0             0              0               0
# 2157          1  60.0             0              0               1
# 3694          1  57.0             0              0               1
#
#       Occupation  Triglycerides  Blood Sugar   BMI  smoking_status
# 4002           0              1        69.25  18.6               0
# 1334           3              0        89.11  24.4               2
# 765            4              1        79.39  27.6               2
# 2157           4              0        70.52  26.5               1
# 3694           4              1       134.76  29.1               0

# %%
X_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2870 entries, 4002 to 860
# Data columns (total 10 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Education       2870 non-null   int32
#  1   age             2870 non-null   float64
#  2   hypertension    2870 non-null   int64
#  3   heart_disease   2870 non-null   int64
#  4   family history  2870 non-null   int32
#  5   Occupation      2870 non-null   int32
#  6   Triglycerides   2870 non-null   int32
#  7   Blood Sugar     2870 non-null   float64
#  8   BMI             2870 non-null   float64
#  9   smoking_status  2870 non-null   int32
# dtypes: float64(3), int32(5), int64(2)
# memory usage: 190.6 KB

# %%
y_train.info()
# Out:
# <class 'pandas.core.series.Series'>
# Int64Index: 2870 entries, 4002 to 860
# Series name: alzheimer
# Non-Null Count  Dtype
# --------------  -----
# 2870 non-null   int64
# dtypes: int64(1)
# memory usage: 44.8 KB

# %% [markdown]
# ### SMOTE (Synthetic Minority Over-sampling Technique): วิธีการที่ใช้การสร้างตัวอย่างสัญญาณเทียบเท่าจากคลาสน้อยโดยการผสมคุณลักษณะของตัวอย่างในคลาสน้อย

# %%
from imblearn.over_sampling import SMOTE
from sklearn.preprocessing import StandardScaler

# %%
smote = SMOTE(random_state=42)
X_train_smote, y_train_smote = smote.fit_resample(X_train, y_train)

# %% [markdown]
# ## MARK: ทำ scaler

# %%
scaler = StandardScaler()

X_train_scaled = scaler.fit_transform(X_train_smote)
X_test_scaled = scaler.transform(X_test)

# %% [markdown]
# # MARK: Decision tree model Start (Default)

# %%
clfModel = tree.DecisionTreeClassifier(criterion="gini",class_weight='balanced',random_state=42)

# %%
clfModel.get_params()
# Out:
# {'ccp_alpha': 0.0,
#  'class_weight': 'balanced',
#  'criterion': 'gini',
#  'max_depth': None,
#  'max_features': None,
#  'max_leaf_nodes': None,
#  'min_impurity_decrease': 0.0,
#  'min_samples_leaf': 1,
#  'min_samples_split': 2,
#  'min_weight_fraction_leaf': 0.0,
#  'random_state': 42,
#  'splitter': 'best'}

# %%
clfModel.fit(X_train_scaled,y_train_smote)
# Out:
# DecisionTreeClassifier(class_weight='balanced', random_state=42)

# %%
print("ตัวอย่างข้อมูลชุดเรียนรู้ ->",clfModel.score(X_train_scaled,y_train_smote))
# Out:
# ตัวอย่างข้อมูลชุดเรียนรู้ -> 1.0

# %%
# อันเดียวกัน
# y_train_pred = clf.predict(X_train)
# accuracy_score(y_train, y_train_pred)

# %% [markdown]
# ### MARK: Visualize Decision Tree

# %%
plt.figure(figsize=(12, 6))
tree.plot_tree(clfModel.fit(X_train_scaled,y_train_smote))
plt.show()

# %% [markdown]
# ### MARK: Predict and Score Model

# %%
y_pred = clfModel.predict(X_test_scaled)
print("ตัวอย่างข้อมูลชุดทดสอบ ->",accuracy_score(y_test, y_pred))
# Out:
# ตัวอย่างข้อมูลชุดทดสอบ -> 0.8455284552845529

# %%
pd.crosstab(y_test, y_pred)
# Out:
# col_0         0    1
# alzheimer
# 0          1020  125
# 1            65   20

# %%
print("Classification Report:\n", classification_report(y_test, y_pred))
# Out:
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.94      0.89      0.91      1145
#            1       0.14      0.24      0.17        85
#
#     accuracy                           0.85      1230
#    macro avg       0.54      0.56      0.54      1230
# weighted avg       0.88      0.85      0.86      1230

# %%
plt.figure(figsize=(12, 6))
tree.plot_tree(clfModel.fit(X_test_scaled,y_test))
plt.show()

# %% [markdown]
# ## MARK: หา Best Parameter และ ลองทำ Pruning

# %%
from sklearn.model_selection import GridSearchCV

# %% [markdown]
# ### MARK: ค้นหา best_params และประเมิน best_accuracy

# %%
param_grid = {
    'max_depth': [2, 4, 6, 8, 10],
    'min_samples_split': [2, 5, 10],
    'min_samples_leaf': [1, 2, 4],
    'max_features': ['auto', 'sqrt', 'log2'],
    'criterion': ['gini', 'entropy']
}
treeModel = tree.DecisionTreeClassifier()
# สร้าง Grid Search
grid_search = GridSearchCV(treeModel, param_grid, cv=10, scoring='accuracy')

# %%
grid_search.fit(X_train_scaled,y_train_smote)
# Out:
# C:\Users\PP\anaconda3\envs\CallmeEnv\lib\site-packages\sklearn\model_selection\_validation.py:425: FitFailedWarning:
# 900 fits failed out of a total of 2700.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 900 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\Users\PP\anaconda3\envs\CallmeEnv\lib\site-packages\sklearn\model_selection\_validation.py", line 732, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\PP\anaconda3\envs\CallmeEnv\lib\site-packages\sklearn\base.py", line 1144, in wrapper
#     estimator._validate_params()
#   File "C:\Users\PP\anaconda3\envs\CallmeEnv\lib\site-packages\sklearn\base.py", line 637, in _validate_params
#     validate_parameter_constraints(
#   File "C:\Users\PP\anaconda3\envs\CallmeEnv\lib\site-packages\sklearn\utils\_param_validation.py", line 95, in validate_parameter_constraints
#     raise InvalidParameterError(
# sklearn.utils._param_validation.InvalidParameterError: The 'max_features' parameter of DecisionTreeClassifier must be an int in the range [1, inf), a float in the range (0.0, 1.0], a str among {'sqrt', 'log2'} or None. Got 'auto' instead.
#
#   warnings.warn(some_fits_failed_message, FitFailedWarning)
# C:\Users\PP\anaconda3\envs\CallmeEnv\lib\site-packages\sklearn\model_selection\_search.py:976: UserWarning: One or more of the test scores are non-finite: [       nan        nan        nan        nan        nan        nan
#         nan        nan        nan 0.6818878  0.69125027 0.71595744
#  0.72018775 0.72089021 0.70840138 0.70820774 0.72826549 0.70381764
#  0.71060963 0.7443079  0.7087521  0.72127004 0.67712904 0.7078235
#  0.70892407 0.72166003 0.67545973        nan        nan        nan
#         nan        nan        nan        nan        nan        nan
#  0.77134689 0.75937398 0.75312432 0.78939139 0.76602244 0.76103652
#  0.77246371 0.76380674 0.76529053 0.77577423 0.76216079 0.75809467
#  0.75293068 0.77615846 0.77780069 0.75404818 0.75110802 0.76769513
#         nan        nan        nan        nan        nan        nan
#         nan        nan        nan 0.80266189 0.8011869  0.80304104
#  0.78957758 0.79841905 0.79898474 0.79767969 0.80505024 0.80431596
#  0.79934663 0.80725714 0.81977372 0.78884601 0.80670702 0.79860931
#  0.8164649  0.78737339 0.80946573        nan        nan        nan
#         nan        nan        nan        nan        nan        nan
#  0.84132001 0.82917513 0.82897912 0.83211563 0.83671697 0.82770014
#  0.82437541 0.82990264 0.82585547 0.84297882 0.83800611 0.82824484
#  0.83450229 0.82438387 0.82364384 0.83506019 0.82603388 0.82842866
#         nan        nan        nan        nan        nan        nan
#         nan        nan        nan 0.8531101  0.86304199 0.85309758
#  0.8689389  0.85346726 0.85419917 0.85696769 0.85530989 0.8477606
#  0.85456952 0.84795357 0.86028227 0.86322243 0.85550116 0.86450784
#  0.85642096 0.85438671 0.86598351        nan        nan        nan
#         nan        nan        nan        nan        nan        nan
#  0.69716682 0.71463547 0.68978611 0.72166613 0.70819081 0.71463682
#  0.69920411 0.68449112 0.67488659 0.67616963 0.70747346 0.6919859
#  0.69330618 0.69695693 0.68557239 0.70894337 0.71776859 0.71040076
#         nan        nan        nan        nan        nan        nan
#         nan        nan        nan 0.7577277  0.74741902 0.7583005
#  0.75755978 0.74944988 0.74761334 0.77081945 0.76784307 0.73601485
#  0.74779344 0.76600043 0.76583387 0.74927486 0.77079813 0.75737427
#  0.76526785 0.7349109  0.74999357        nan        nan        nan
#         nan        nan        nan        nan        nan        nan
#  0.79179396 0.80928156 0.80302141 0.81535587 0.78554057 0.79530048
#  0.7951082  0.79952504 0.79842481 0.80098919 0.79216566 0.8059724
#  0.80652421 0.80798701 0.80651913 0.7919859  0.79327402 0.79567625
#         nan        nan        nan        nan        nan        nan
#         nan        nan        nan 0.83321688 0.82383003 0.82603828
#  0.82548275 0.8223591  0.82622346 0.81591208 0.83653653 0.8206969
#  0.82161501 0.82309372 0.82106455 0.8332206  0.83211631 0.8218056
#  0.82125582 0.81812811 0.82015254        nan        nan        nan
#         nan        nan        nan        nan        nan        nan
#  0.85199802 0.84757813 0.84886794 0.8532902  0.860091   0.85309589
#  0.85770569 0.85402347 0.8558634  0.85310029 0.84996716 0.84721286
#  0.85715422 0.85549947 0.85493852 0.84942619 0.84923695 0.84812859]
#   warnings.warn(
# GridSearchCV(cv=10, estimator=DecisionTreeClassifier(),
#              param_grid={'criterion': ['gini', 'entropy'],
#                          'max_depth': [2, 4, 6, 8, 10],
#                          'max_features': ['auto', 'sqrt', 'log2'],
#                          'min_samples_leaf': [1, 2, 4],
#                          'min_samples_split': [2, 5, 10]},
#              scoring='accuracy')

# %%
best_params = grid_search.best_params_
print("Best Parameters:", best_params)
# best_params = {'criterion': 'gini', 'max_depth': 10, 'max_features': 'log2', 'min_samples_leaf': 4, 'min_samples_split': 5}
# Out:
# Best Parameters: {'criterion': 'gini', 'max_depth': 10, 'max_features': 'sqrt', 'min_samples_leaf': 2, 'min_samples_split': 2}

# %%
best_accuracy = grid_search.best_score_
print("Best Accuracy:", best_accuracy)
# Out:
# Best Accuracy: 0.8689389015274618

# %%
print("Best:",grid_search.best_score_,"using" , grid_search.best_params_)
means = grid_search.cv_results_["mean_test_score"]
stds = grid_search.cv_results_["std_test_score"]
params = grid_search.cv_results_["params"]
for means, stds, params in zip(means, stds, params):
    print("means -> %f stds-> (%f) params with: %r", means, stds, params)
# Out:
# Best: 0.8689389015274618 using {'criterion': 'gini', 'max_depth': 10, 'max_features': 'sqrt', 'min_samples_leaf': 2, 'min_samples_split': 2}
# means -> %f stds-> (%f) params with: %r nan nan {'criterion': 'gini', 'max_depth': 2, 'max_features': 'auto', 'min_samples_leaf': 1, 'min_samples_split': 2}
# means -> %f stds-> (%f) params with: %r nan nan {'criterion': 'gini', 'max_depth': 2, 'max_features': 'auto', 'min_samples_leaf': 1, 'min_samples_split': 5}
# means -> %f stds-> (%f) params with: %r nan nan {'criterion': 'gini', 'max_depth': 2, 'max_features': 'auto', 'min_samples_leaf': 1, 'min_samples_split': 10}
# means -> %f stds-> (%f) params with: %r nan nan {'criterion': 'gini', 'max_depth': 2, 'max_features': 'auto', 'min_samples_leaf': 2, 'min_samples_split': 2}
# means -> %f stds-> (%f) params with: %r nan nan {'criterion': 'gini', 'max_depth': 2, 'max_features': 'auto', 'min_samples_leaf': 2, 'min_samples_split': 5}
# means -> %f stds-> (%f) params with: %r nan nan {'criterion': 'gini', 'max_depth': 2, 'max_features': 'auto', 'min_samples_leaf': 2, 'min_samples_split': 10}
# means -> %f stds-> (%f) params with: %r nan nan {'criterion': 'gini', 'max_depth': 2, 'max_features': 'auto', 'min_samples_leaf': 4, 'min_samples_split': 2}
# means -> %f stds-> (%f) params with: %r nan nan {'criterion': 'gini', 'max_depth': 2, 'max_features': 'auto', 'min_samples_leaf': 4, 'min_samples_split': 5}
# means -> %f stds-> (%f) params with: %r nan nan {'criterion': 'gini', 'max_depth': 2, 'max_features': 'auto', 'min_samples_leaf': 4, 'min_samples_split': 10}
# means -> %f stds-> (%f) params with: %r 0.6818877965550861 0.06695070696851793 {'criterion': 'gini', 'max_depth': 2, 'max_features': 'sqrt', 'min_samples_leaf': 1, 'min_samples_split': 2}
# means -> %f stds-> (%f) params with: %r 0.6912502708265628 0.07719277867000429 {'criterion': 'gini', 'max_depth': 2, 'max_features': 'sqrt', 'min_samples_leaf': 1, 'min_samples_split': 5}
# means -> %f stds-> (%f) params with: %r 0.7159574396056765 0.06521947380765876 {'criterion': 'gini', 'max_depth': 2, 'max_features': 'sqrt', 'min_samples_leaf': 1, 'min_samples_split': 10}
# means -> %f stds-> (%f) params with: %r 0.7201877505145704 0.06289898415455011 {'criterion': 'gini', 'max_depth': 2, 'max_features': 'sqrt', 'min_samples_leaf': 2, 'min_samples_split': 2}
# means -> %f stds-> (%f) params with: %r 0.7208902069114939 0.06354010894339258 {'criterion': 'gini', 'max_depth': 2, 'max_features': 'sqrt', 'min_samples_leaf': 2, 'min_samples_split': 5}
# means -> %f stds-> (%f) params with: %r 0.7084013785072041 0.07365420719581348 {'criterion': 'gini', 'max_depth': 2, 'max_features': 'sqrt', 'min_samples_leaf': 2, 'min_samples_split': 10}
# means -> %f stds-> (%f) params with: %r 0.7082077375148954 0.06860120814411647 {'criterion': 'gini', 'max_depth': 2, 'max_features': 'sqrt', 'min_samples_leaf': 4, 'min_samples_split': 2}
# means -> %f stds-> (%f) params with: %r 0.7282654912793846 0.04992757982354897 {'criterion': 'gini', 'max_depth': 2, 'max_features': 'sqrt', 'min_samples_leaf': 4, 'min_samples_split': 5}
# means -> %f stds-> (%f) params with: %r 0.7038176389340267 0.07566214874718456 {'criterion': 'gini', 'max_depth': 2, 'max_features': 'sqrt', 'min_samples_leaf': 4, 'min_samples_split': 10}
# means -> %f stds-> (%f) params with: %r 0.7106096305925684 0.06543858623087496 {'criterion': 'gini', 'max_depth': 2, 'max_features': 'log2', 'min_samples_leaf': 1, 'min_samples_split': 2}
# means -> %f stds-> (%f) params with: %r 0.7443079027190986 0.051075362150219406 {'criterion': 'gini', 'max_depth': 2, 'max_features': 'log2', 'min_samples_leaf': 1, 'min_samples_split': 5}
# means -> %f stds-> (%f) params with: %r 0.7087520989058607 0.07060946369640056 {'criterion': 'gini', 'max_depth': 2, 'max_features': 'log2', 'min_samples_leaf': 1, 'min_samples_split': 10}
# means -> %f stds-> (%f) params with: %r 0.7212700411656374 0.0667102419621182 {'criterion': 'gini', 'max_depth': 2, 'max_features': 'log2', 'min_samples_leaf': 2, 'min_samples_split': 2}
# means -> %f stds-> (%f) params with: %r 0.6771290353157837 0.068243226340967 {'criterion': 'gini', 'max_depth': 2, 'max_features': 'log2', 'min_samples_leaf': 2, 'min_samples_split': 5}
# means -> %f stds-> (%f) params with: %r 0.7078235023291085 0.06235676391319702 {'criterion': 'gini', 'max_depth': 2, 'max_features': 'log2', 'min_samples_leaf': 2, 'min_samples_split': 10}
# means -> %f stds-> (%f) params with: %r 0.7089240737731556 0.06567637895508939 {'criterion': 'gini', 'max_depth': 2, 'max_features': 'log2', 'min_samples_leaf': 4, 'min_samples_split': 2}
# means -> %f stds-> (%f) params with: %r 0.7216600314158812 0.0625082921234811 {'criterion': 'gini', 'max_depth': 2, 'max_features': 'log2', 'min_samples_leaf': 4, 'min_samples_split': 5}
# means -> %f stds-> (%f) params with: %r 0.6754597280901311 0.07077562395854216 {'criterion': 'gini', 'max_depth': 2, 'max_features': 'log2', 'min_samples_leaf': 4, 'min_samples_split': 10}
# means -> %f stds-> (%f) params with: %r nan nan {'criterion': 'gini', 'max_depth': 4, 'max_features': 'auto', 'min_samples_leaf': 1, 'min_samples_split': 2}
# means -> %f stds-> (%f) params with: %r nan nan {'criterion': 'gini', 'max_depth': 4, 'max_features': 'auto', 'min_samples_leaf': 1, 'min_samples_split': 5}
# means -> %f stds-> (%f) params with: %r nan nan {'criterion': 'gini', 'max_depth': 4, 'max_features': 'auto', 'min_samples_leaf': 1, 'min_samples_split': 10}
# means -> %f stds-> (%f) params with: %r nan nan {'criterion': 'gini', 'max_depth': 4, 'max_features': 'auto', 'min_samples_leaf': 2, 'min_samples_split': 2}
# means -> %f stds-> (%f) params with: %r nan nan {'criterion': 'gini', 'max_depth': 4, 'max_features': 'auto', 'min_samples_leaf': 2, 'min_samples_split': 5}
# means -> %f stds-> (%f) params with: %r nan nan {'criterion': 'gini', 'max_depth': 4, 'max_features': 'auto', 'min_samples_leaf': 2, 'min_samples_split': 10}
# means -> %f stds-> (%f) params with: %r nan nan {'criterion': 'gini', 'max_depth': 4, 'max_features': 'auto', 'min_samples_leaf': 4, 'min_samples_split': 2}
# means -> %f stds-> (%f) params with: %r nan nan {'criterion': 'gini', 'max_depth': 4, 'max_features': 'auto', 'min_samples_leaf': 4, 'min_samples_split': 5}
# means -> %f stds-> (%f) params with: %r nan nan {'criterion': 'gini', 'max_depth': 4, 'max_features': 'auto', 'min_samples_leaf': 4, 'min_samples_split': 10}
# means -> %f stds-> (%f) params with: %r 0.771346888202795 0.032225471918434306 {'criterion': 'gini', 'max_depth': 4, 'max_features': 'sqrt', 'min_samples_leaf': 1, 'min_samples_split': 2}
# means -> %f stds-> (%f) params with: %r 0.75937398440039 0.037468380359600165 {'criterion': 'gini', 'max_depth': 4, 'max_features': 'sqrt', 'min_samples_leaf': 1, 'min_samples_split': 5}
# means -> %f stds-> (%f) params with: %r 0.7531243229335933 0.04118798279426996 {'criterion': 'gini', 'max_depth': 4, 'max_features': 'sqrt', 'min_samples_leaf': 1, 'min_samples_split': 10}
# means -> %f stds-> (%f) params with: %r 0.7893913850070415 0.02413799534027678 {'criterion': 'gini', 'max_depth': 4, 'max_features': 'sqrt', 'min_samples_leaf': 2, 'min_samples_split': 2}
# means -> %f stds-> (%f) params with: %r 0.7660224379807172 0.03529751280559936 {'criterion': 'gini', 'max_depth': 4, 'max_features': 'sqrt', 'min_samples_leaf': 2, 'min_samples_split': 5}
# means -> %f stds-> (%f) params with: %r 0.7610365209619759 0.0462546512258832 {'criterion': 'gini', 'max_depth': 4, 'max_features': 'sqrt', 'min_samples_leaf': 2, 'min_samples_split': 10}
# means -> %f stds-> (%f) params with: %r 0.7724637092406024 0.03213190292544754 {'criterion': 'gini', 'max_depth': 4, 'max_features': 'sqrt', 'min_samples_leaf': 4, 'min_samples_split': 2}
# means -> %f stds-> (%f) params with: %r 0.7638067381648792 0.04116848590012382 {'criterion': 'gini', 'max_depth': 4, 'max_features': 'sqrt', 'min_samples_leaf': 4, 'min_samples_split': 5}
# means -> %f stds-> (%f) params with: %r 0.7652905291951034 0.031053102878464175 {'criterion': 'gini', 'max_depth': 4, 'max_features': 'sqrt', 'min_samples_leaf': 4, 'min_samples_split': 10}
# means -> %f stds-> (%f) params with: %r 0.7757742254360307 0.040126183113115804 {'criterion': 'gini', 'max_depth': 4, 'max_features': 'log2', 'min_samples_leaf': 1, 'min_samples_split': 2}
# means -> %f stds-> (%f) params with: %r 0.7621607897302568 0.042400270587418645 {'criterion': 'gini', 'max_depth': 4, 'max_features': 'log2', 'min_samples_leaf': 1, 'min_samples_split': 5}
# means -> %f stds-> (%f) params with: %r 0.7580946674249811 0.050261633229936695 {'criterion': 'gini', 'max_depth': 4, 'max_features': 'log2', 'min_samples_leaf': 1, 'min_samples_split': 10}
# means -> %f stds-> (%f) params with: %r 0.7529306819412847 0.053617037770028304 {'criterion': 'gini', 'max_depth': 4, 'max_features': 'log2', 'min_samples_leaf': 2, 'min_samples_split': 2}
# means -> %f stds-> (%f) params with: %r 0.7761584606218178 0.03021145826911576 {'criterion': 'gini', 'max_depth': 4, 'max_features': 'log2', 'min_samples_leaf': 2, 'min_samples_split': 5}
# means -> %f stds-> (%f) params with: %r 0.7778006851912036 0.02877119014735666 {'criterion': 'gini', 'max_depth': 4, 'max_features': 'log2', 'min_samples_leaf': 2, 'min_samples_split': 10}
# means -> %f stds-> (%f) params with: %r 0.7540481800454988 0.04291941932735007 {'criterion': 'gini', 'max_depth': 4, 'max_features': 'log2', 'min_samples_leaf': 4, 'min_samples_split': 2}
# means -> %f stds-> (%f) params with: %r 0.7511080191745206 0.03895321832641559 {'criterion': 'gini', 'max_depth': 4, 'max_features': 'log2', 'min_samples_leaf': 4, 'min_samples_split': 5}
# means -> %f stds-> (%f) params with: %r 0.7676951305384032 0.05363247604173311 {'criterion': 'gini', 'max_depth': 4, 'max_features': 'log2', 'min_samples_leaf': 4, 'min_samples_split': 10}
# means -> %f stds-> (%f) params with: %r nan nan {'criterion': 'gini', 'max_depth': 6, 'max_features': 'auto', 'min_samples_leaf': 1, 'min_samples_split': 2}
# means -> %f stds-> (%f) params with: %r nan nan {'criterion': 'gini', 'max_depth': 6, 'max_features': 'auto', 'min_samples_leaf': 1, 'min_samples_split': 5}
# means -> %f stds-> (%f) params with: %r nan nan {'criterion': 'gini', 'max_depth': 6, 'max_features': 'auto', 'min_samples_leaf': 1, 'min_samples_split': 10}
# means -> %f stds-> (%f) params with: %r nan nan {'criterion': 'gini', 'max_depth': 6, 'max_features': 'auto', 'min_samples_leaf': 2, 'min_samples_split': 2}
# means -> %f stds-> (%f) params with: %r nan nan {'criterion': 'gini', 'max_depth': 6, 'max_features': 'auto', 'min_samples_leaf': 2, 'min_samples_split': 5}
# means -> %f stds-> (%f) params with: %r nan nan {'criterion': 'gini', 'max_depth': 6, 'max_features': 'auto', 'min_samples_leaf': 2, 'min_samples_split': 10}
# means -> %f stds-> (%f) params with: %r nan nan {'criterion': 'gini', 'max_depth': 6, 'max_features': 'auto', 'min_samples_leaf': 4, 'min_samples_split': 2}
# means -> %f stds-> (%f) params with: %r nan nan {'criterion': 'gini', 'max_depth': 6, 'max_features': 'auto', 'min_samples_leaf': 4, 'min_samples_split': 5}
# means -> %f stds-> (%f) params with: %r nan nan {'criterion': 'gini', 'max_depth': 6, 'max_features': 'auto', 'min_samples_leaf': 4, 'min_samples_split': 10}
# means -> %f stds-> (%f) params with: %r 0.8026618865778354 0.020855631170618703 {'criterion': 'gini', 'max_depth': 6, 'max_features': 'sqrt', 'min_samples_leaf': 1, 'min_samples_split': 2}
# means -> %f stds-> (%f) params with: %r 0.801186897410898 0.026562719875679607 {'criterion': 'gini', 'max_depth': 6, 'max_features': 'sqrt', 'min_samples_leaf': 1, 'min_samples_split': 5}
# means -> %f stds-> (%f) params with: %r 0.8030410437655725 0.04322782859569545 {'criterion': 'gini', 'max_depth': 6, 'max_features': 'sqrt', 'min_samples_leaf': 1, 'min_samples_split': 10}
# means -> %f stds-> (%f) params with: %r 0.7895775782688765 0.020255390617424023 {'criterion': 'gini', 'max_depth': 6, 'max_features': 'sqrt', 'min_samples_leaf': 2, 'min_samples_split': 2}
# means -> %f stds-> (%f) params with: %r 0.798419049940418 0.03836543341656398 {'criterion': 'gini', 'max_depth': 6, 'max_features': 'sqrt', 'min_samples_leaf': 2, 'min_samples_split': 5}
# means -> %f stds-> (%f) params with: %r 0.7989847389231935 0.047253030649505236 {'criterion': 'gini', 'max_depth': 6, 'max_features': 'sqrt', 'min_samples_leaf': 2, 'min_samples_split': 10}
# means -> %f stds-> (%f) params with: %r 0.7976796934243311 0.033846787393693144 {'criterion': 'gini', 'max_depth': 6, 'max_features': 'sqrt', 'min_samples_leaf': 4, 'min_samples_split': 2}
# means -> %f stds-> (%f) params with: %r 0.805050238327375 0.02968574875671148 {'criterion': 'gini', 'max_depth': 6, 'max_features': 'sqrt', 'min_samples_leaf': 4, 'min_samples_split': 5}
# means -> %f stds-> (%f) params with: %r 0.804315959809338 0.0191699283270406 {'criterion': 'gini', 'max_depth': 6, 'max_features': 'sqrt', 'min_samples_leaf': 4, 'min_samples_split': 10}
# means -> %f stds-> (%f) params with: %r 0.7993466309175604 0.02797382924963423 {'criterion': 'gini', 'max_depth': 6, 'max_features': 'log2', 'min_samples_leaf': 1, 'min_samples_split': 2}
# means -> %f stds-> (%f) params with: %r 0.8072571362799262 0.028321730119896943 {'criterion': 'gini', 'max_depth': 6, 'max_features': 'log2', 'min_samples_leaf': 1, 'min_samples_split': 5}
# means -> %f stds-> (%f) params with: %r 0.8197737244068899 0.02630176294489581 {'criterion': 'gini', 'max_depth': 6, 'max_features': 'log2', 'min_samples_leaf': 1, 'min_samples_split': 10}
# means -> %f stds-> (%f) params with: %r 0.7888460080164662 0.024235031177870854 {'criterion': 'gini', 'max_depth': 6, 'max_features': 'log2', 'min_samples_leaf': 2, 'min_samples_split': 2}
# means -> %f stds-> (%f) params with: %r 0.8067070198245043 0.017742234501962568 {'criterion': 'gini', 'max_depth': 6, 'max_features': 'log2', 'min_samples_leaf': 2, 'min_samples_split': 5}
# means -> %f stds-> (%f) params with: %r 0.7986093056006933 0.01810312740285413 {'criterion': 'gini', 'max_depth': 6, 'max_features': 'log2', 'min_samples_leaf': 2, 'min_samples_split': 10}
# means -> %f stds-> (%f) params with: %r 0.816464900877478 0.03563797562202742 {'criterion': 'gini', 'max_depth': 6, 'max_features': 'log2', 'min_samples_leaf': 4, 'min_samples_split': 2}
# means -> %f stds-> (%f) params with: %r 0.7873733885819522 0.026718495125366275 {'criterion': 'gini', 'max_depth': 6, 'max_features': 'log2', 'min_samples_leaf': 4, 'min_samples_split': 5}
# means -> %f stds-> (%f) params with: %r 0.8094657268984943 0.03193509891190614 {'criterion': 'gini', 'max_depth': 6, 'max_features': 'log2', 'min_samples_leaf': 4, 'min_samples_split': 10}
# means -> %f stds-> (%f) params with: %r nan nan {'criterion': 'gini', 'max_depth': 8, 'max_features': 'auto', 'min_samples_leaf': 1, 'min_samples_split': 2}
# means -> %f stds-> (%f) params with: %r nan nan {'criterion': 'gini', 'max_depth': 8, 'max_features': 'auto', 'min_samples_leaf': 1, 'min_samples_split': 5}
# means -> %f stds-> (%f) params with: %r nan nan {'criterion': 'gini', 'max_depth': 8, 'max_features': 'auto', 'min_samples_leaf': 1, 'min_samples_split': 10}
# means -> %f stds-> (%f) params with: %r nan nan {'criterion': 'gini', 'max_depth': 8, 'max_features': 'auto', 'min_samples_leaf': 2, 'min_samples_split': 2}
# means -> %f stds-> (%f) params with: %r nan nan {'criterion': 'gini', 'max_depth': 8, 'max_features': 'auto', 'min_samples_leaf': 2, 'min_samples_split': 5}
# means -> %f stds-> (%f) params with: %r nan nan {'criterion': 'gini', 'max_depth': 8, 'max_features': 'auto', 'min_samples_leaf': 2, 'min_samples_split': 10}
# means -> %f stds-> (%f) params with: %r nan nan {'criterion': 'gini', 'max_depth': 8, 'max_features': 'auto', 'min_samples_leaf': 4, 'min_samples_split': 2}
# means -> %f stds-> (%f) params with: %r nan nan {'criterion': 'gini', 'max_depth': 8, 'max_features': 'auto', 'min_samples_leaf': 4, 'min_samples_split': 5}
# means -> %f stds-> (%f) params with: %r nan nan {'criterion': 'gini', 'max_depth': 8, 'max_features': 'auto', 'min_samples_leaf': 4, 'min_samples_split': 10}
# means -> %f stds-> (%f) params with: %r 0.8413200086664501 0.02415863063254899 {'criterion': 'gini', 'max_depth': 8, 'max_features': 'sqrt', 'min_samples_leaf': 1, 'min_samples_split': 2}
# means -> %f stds-> (%f) params with: %r 0.8291751299967501 0.025750961630034135 {'criterion': 'gini', 'max_depth': 8, 'max_features': 'sqrt', 'min_samples_leaf': 1, 'min_samples_split': 5}
# means -> %f stds-> (%f) params with: %r 0.8289791192720182 0.02522277588513578 {'criterion': 'gini', 'max_depth': 8, 'max_features': 'sqrt', 'min_samples_leaf': 1, 'min_samples_split': 10}
# means -> %f stds-> (%f) params with: %r 0.8321156294009316 0.028000954562832983 {'criterion': 'gini', 'max_depth': 8, 'max_features': 'sqrt', 'min_samples_leaf': 2, 'min_samples_split': 2}
# means -> %f stds-> (%f) params with: %r 0.8367169727006825 0.019760030790426077 {'criterion': 'gini', 'max_depth': 8, 'max_features': 'sqrt', 'min_samples_leaf': 2, 'min_samples_split': 5}
# means -> %f stds-> (%f) params with: %r 0.8277001408298126 0.031598472347393804 {'criterion': 'gini', 'max_depth': 8, 'max_features': 'sqrt', 'min_samples_leaf': 2, 'min_samples_split': 10}
# means -> %f stds-> (%f) params with: %r 0.8243754062398441 0.026756719379557807 {'criterion': 'gini', 'max_depth': 8, 'max_features': 'sqrt', 'min_samples_leaf': 4, 'min_samples_split': 2}
# means -> %f stds-> (%f) params with: %r 0.8299026378507206 0.030936140480000193 {'criterion': 'gini', 'max_depth': 8, 'max_features': 'sqrt', 'min_samples_leaf': 4, 'min_samples_split': 5}
# means -> %f stds-> (%f) params with: %r 0.8258554734048316 0.02507551220965519 {'criterion': 'gini', 'max_depth': 8, 'max_features': 'sqrt', 'min_samples_leaf': 4, 'min_samples_split': 10}
# means -> %f stds-> (%f) params with: %r 0.8429788213627992 0.02957158534289318 {'criterion': 'gini', 'max_depth': 8, 'max_features': 'log2', 'min_samples_leaf': 1, 'min_samples_split': 2}
# means -> %f stds-> (%f) params with: %r 0.8380061071389882 0.02664439688502689 {'criterion': 'gini', 'max_depth': 8, 'max_features': 'log2', 'min_samples_leaf': 1, 'min_samples_split': 5}
# means -> %f stds-> (%f) params with: %r 0.8282448407539812 0.024962550997333337 {'criterion': 'gini', 'max_depth': 8, 'max_features': 'log2', 'min_samples_leaf': 1, 'min_samples_split': 10}
# means -> %f stds-> (%f) params with: %r 0.8345022884844544 0.020092715590911768 {'criterion': 'gini', 'max_depth': 8, 'max_features': 'log2', 'min_samples_leaf': 2, 'min_samples_split': 2}
# means -> %f stds-> (%f) params with: %r 0.8243838695699275 0.018255193744758806 {'criterion': 'gini', 'max_depth': 8, 'max_features': 'log2', 'min_samples_leaf': 2, 'min_samples_split': 5}
# means -> %f stds-> (%f) params with: %r 0.8236438359874336 0.024504169866426378 {'criterion': 'gini', 'max_depth': 8, 'max_features': 'log2', 'min_samples_leaf': 2, 'min_samples_split': 10}
# means -> %f stds-> (%f) params with: %r 0.8350601912035532 0.029703208627783813 {'criterion': 'gini', 'max_depth': 8, 'max_features': 'log2', 'min_samples_leaf': 4, 'min_samples_split': 2}
# means -> %f stds-> (%f) params with: %r 0.82603388040299 0.027140776664875563 {'criterion': 'gini', 'max_depth': 8, 'max_features': 'log2', 'min_samples_leaf': 4, 'min_samples_split': 5}
# means -> %f stds-> (%f) params with: %r 0.8284286642833928 0.030959295327269987 {'criterion': 'gini', 'max_depth': 8, 'max_features': 'log2', 'min_samples_leaf': 4, 'min_samples_split': 10}
# means -> %f stds-> (%f) params with: %r nan nan {'criterion': 'gini', 'max_depth': 10, 'max_features': 'auto', 'min_samples_leaf': 1, 'min_samples_split': 2}
# means -> %f stds-> (%f) params with: %r nan nan {'criterion': 'gini', 'max_depth': 10, 'max_features': 'auto', 'min_samples_leaf': 1, 'min_samples_split': 5}
# means -> %f stds-> (%f) params with: %r nan nan {'criterion': 'gini', 'max_depth': 10, 'max_features': 'auto', 'min_samples_leaf': 1, 'min_samples_split': 10}
# means -> %f stds-> (%f) params with: %r nan nan {'criterion': 'gini', 'max_depth': 10, 'max_features': 'auto', 'min_samples_leaf': 2, 'min_samples_split': 2}
# means -> %f stds-> (%f) params with: %r nan nan {'criterion': 'gini', 'max_depth': 10, 'max_features': 'auto', 'min_samples_leaf': 2, 'min_samples_split': 5}
# means -> %f stds-> (%f) params with: %r nan nan {'criterion': 'gini', 'max_depth': 10, 'max_features': 'auto', 'min_samples_leaf': 2, 'min_samples_split': 10}
# means -> %f stds-> (%f) params with: %r nan nan {'criterion': 'gini', 'max_depth': 10, 'max_features': 'auto', 'min_samples_leaf': 4, 'min_samples_split': 2}
# means -> %f stds-> (%f) params with: %r nan nan {'criterion': 'gini', 'max_depth': 10, 'max_features': 'auto', 'min_samples_leaf': 4, 'min_samples_split': 5}
# means -> %f stds-> (%f) params with: %r nan nan {'criterion': 'gini', 'max_depth': 10, 'max_features': 'auto', 'min_samples_leaf': 4, 'min_samples_split': 10}
# means -> %f stds-> (%f) params with: %r 0.8531101045390532 0.032652649619553165 {'criterion': 'gini', 'max_depth': 10, 'max_features': 'sqrt', 'min_samples_leaf': 1, 'min_samples_split': 2}
# means -> %f stds-> (%f) params with: %r 0.8630419916585419 0.03482312485088668 {'criterion': 'gini', 'max_depth': 10, 'max_features': 'sqrt', 'min_samples_leaf': 1, 'min_samples_split': 5}
# means -> %f stds-> (%f) params with: %r 0.8530975788105298 0.0279925309436465 {'criterion': 'gini', 'max_depth': 10, 'max_features': 'sqrt', 'min_samples_leaf': 1, 'min_samples_split': 10}
# means -> %f stds-> (%f) params with: %r 0.8689389015274618 0.03215705665524654 {'criterion': 'gini', 'max_depth': 10, 'max_features': 'sqrt', 'min_samples_leaf': 2, 'min_samples_split': 2}
# means -> %f stds-> (%f) params with: %r 0.8534672570685732 0.03097281757264138 {'criterion': 'gini', 'max_depth': 10, 'max_features': 'sqrt', 'min_samples_leaf': 2, 'min_samples_split': 5}
# means -> %f stds-> (%f) params with: %r 0.854199165854187 0.022846561236797243 {'criterion': 'gini', 'max_depth': 10, 'max_features': 'sqrt', 'min_samples_leaf': 2, 'min_samples_split': 10}
# means -> %f stds-> (%f) params with: %r 0.8569676903910736 0.02210991836272839 {'criterion': 'gini', 'max_depth': 10, 'max_features': 'sqrt', 'min_samples_leaf': 4, 'min_samples_split': 2}
# means -> %f stds-> (%f) params with: %r 0.8553098932943343 0.02615728061618913 {'criterion': 'gini', 'max_depth': 10, 'max_features': 'sqrt', 'min_samples_leaf': 4, 'min_samples_split': 5}
# means -> %f stds-> (%f) params with: %r 0.8477606028599286 0.019413433591240137 {'criterion': 'gini', 'max_depth': 10, 'max_features': 'sqrt', 'min_samples_leaf': 4, 'min_samples_split': 10}
# means -> %f stds-> (%f) params with: %r 0.8545695211786372 0.025291678549168625 {'criterion': 'gini', 'max_depth': 10, 'max_features': 'log2', 'min_samples_leaf': 1, 'min_samples_split': 2}
# means -> %f stds-> (%f) params with: %r 0.8479535667858304 0.030439259167434323 {'criterion': 'gini', 'max_depth': 10, 'max_features': 'log2', 'min_samples_leaf': 1, 'min_samples_split': 5}
# means -> %f stds-> (%f) params with: %r 0.860282268984942 0.030103991632443115 {'criterion': 'gini', 'max_depth': 10, 'max_features': 'log2', 'min_samples_leaf': 1, 'min_samples_split': 10}
# means -> %f stds-> (%f) params with: %r 0.8632224298559203 0.026504027695425824 {'criterion': 'gini', 'max_depth': 10, 'max_features': 'log2', 'min_samples_leaf': 2, 'min_samples_split': 2}
# means -> %f stds-> (%f) params with: %r 0.8555011645542194 0.029352947191273092 {'criterion': 'gini', 'max_depth': 10, 'max_features': 'log2', 'min_samples_leaf': 2, 'min_samples_split': 5}
# means -> %f stds-> (%f) params with: %r 0.8645078404289892 0.02334007805666664 {'criterion': 'gini', 'max_depth': 10, 'max_features': 'log2', 'min_samples_leaf': 2, 'min_samples_split': 10}
# means -> %f stds-> (%f) params with: %r 0.856420959267685 0.034975125872505966 {'criterion': 'gini', 'max_depth': 10, 'max_features': 'log2', 'min_samples_leaf': 4, 'min_samples_split': 2}
# means -> %f stds-> (%f) params with: %r 0.8543867132488355 0.03023442870531715 {'criterion': 'gini', 'max_depth': 10, 'max_features': 'log2', 'min_samples_leaf': 4, 'min_samples_split': 5}
# means -> %f stds-> (%f) params with: %r 0.8659835066623334 0.02322049832081305 {'criterion': 'gini', 'max_depth': 10, 'max_features': 'log2', 'min_samples_leaf': 4, 'min_samples_split': 10}
# means -> %f stds-> (%f) params with: %r nan nan {'criterion': 'entropy', 'max_depth': 2, 'max_features': 'auto', 'min_samples_leaf': 1, 'min_samples_split': 2}
# means -> %f stds-> (%f) params with: %r nan nan {'criterion': 'entropy', 'max_depth': 2, 'max_features': 'auto', 'min_samples_leaf': 1, 'min_samples_split': 5}
# means -> %f stds-> (%f) params with: %r nan nan {'criterion': 'entropy', 'max_depth': 2, 'max_features': 'auto', 'min_samples_leaf': 1, 'min_samples_split': 10}
# means -> %f stds-> (%f) params with: %r nan nan {'criterion': 'entropy', 'max_depth': 2, 'max_features': 'auto', 'min_samples_leaf': 2, 'min_samples_split': 2}
# means -> %f stds-> (%f) params with: %r nan nan {'criterion': 'entropy', 'max_depth': 2, 'max_features': 'auto', 'min_samples_leaf': 2, 'min_samples_split': 5}
# means -> %f stds-> (%f) params with: %r nan nan {'criterion': 'entropy', 'max_depth': 2, 'max_features': 'auto', 'min_samples_leaf': 2, 'min_samples_split': 10}
# means -> %f stds-> (%f) params with: %r nan nan {'criterion': 'entropy', 'max_depth': 2, 'max_features': 'auto', 'min_samples_leaf': 4, 'min_samples_split': 2}
# means -> %f stds-> (%f) params with: %r nan nan {'criterion': 'entropy', 'max_depth': 2, 'max_features': 'auto', 'min_samples_leaf': 4, 'min_samples_split': 5}
# means -> %f stds-> (%f) params with: %r nan nan {'criterion': 'entropy', 'max_depth': 2, 'max_features': 'auto', 'min_samples_leaf': 4, 'min_samples_split': 10}
# means -> %f stds-> (%f) params with: %r 0.6971668156212761 0.07229638847560853 {'criterion': 'entropy', 'max_depth': 2, 'max_features': 'sqrt', 'min_samples_leaf': 1, 'min_samples_split': 2}
# means -> %f stds-> (%f) params with: %r 0.7146354674466472 0.049938627152187665 {'criterion': 'entropy', 'max_depth': 2, 'max_features': 'sqrt', 'min_samples_leaf': 1, 'min_samples_split': 5}
# means -> %f stds-> (%f) params with: %r 0.6897861147221319 0.062359416771397225 {'criterion': 'entropy', 'max_depth': 2, 'max_features': 'sqrt', 'min_samples_leaf': 1, 'min_samples_split': 10}
# means -> %f stds-> (%f) params with: %r 0.7216661250135413 0.06018024451758825 {'criterion': 'entropy', 'max_depth': 2, 'max_features': 'sqrt', 'min_samples_leaf': 2, 'min_samples_split': 2}
# means -> %f stds-> (%f) params with: %r 0.7081908108547287 0.0562272862016337 {'criterion': 'entropy', 'max_depth': 2, 'max_features': 'sqrt', 'min_samples_leaf': 2, 'min_samples_split': 5}
# means -> %f stds-> (%f) params with: %r 0.7146368215794605 0.06233149474404496 {'criterion': 'entropy', 'max_depth': 2, 'max_features': 'sqrt', 'min_samples_leaf': 2, 'min_samples_split': 10}
# means -> %f stds-> (%f) params with: %r 0.6992041084389558 0.059224524817072625 {'criterion': 'entropy', 'max_depth': 2, 'max_features': 'sqrt', 'min_samples_leaf': 4, 'min_samples_split': 2}
# means -> %f stds-> (%f) params with: %r 0.6844911168887444 0.08176164551039763 {'criterion': 'entropy', 'max_depth': 2, 'max_features': 'sqrt', 'min_samples_leaf': 4, 'min_samples_split': 5}
# means -> %f stds-> (%f) params with: %r 0.6748865913768822 0.059564449690634985 {'criterion': 'entropy', 'max_depth': 2, 'max_features': 'sqrt', 'min_samples_leaf': 4, 'min_samples_split': 10}
# means -> %f stds-> (%f) params with: %r 0.6761696322175279 0.06356709663159411 {'criterion': 'entropy', 'max_depth': 2, 'max_features': 'log2', 'min_samples_leaf': 1, 'min_samples_split': 2}
# means -> %f stds-> (%f) params with: %r 0.7074734589968584 0.05355712037368516 {'criterion': 'entropy', 'max_depth': 2, 'max_features': 'log2', 'min_samples_leaf': 1, 'min_samples_split': 5}
# means -> %f stds-> (%f) params with: %r 0.6919859034774131 0.06832015038296313 {'criterion': 'entropy', 'max_depth': 2, 'max_features': 'log2', 'min_samples_leaf': 1, 'min_samples_split': 10}
# means -> %f stds-> (%f) params with: %r 0.6933061829704257 0.059658137533553174 {'criterion': 'entropy', 'max_depth': 2, 'max_features': 'log2', 'min_samples_leaf': 2, 'min_samples_split': 2}
# means -> %f stds-> (%f) params with: %r 0.6969569250352075 0.05688605539275765 {'criterion': 'entropy', 'max_depth': 2, 'max_features': 'log2', 'min_samples_leaf': 2, 'min_samples_split': 5}
# means -> %f stds-> (%f) params with: %r 0.6855723919402015 0.06875912243135507 {'criterion': 'entropy', 'max_depth': 2, 'max_features': 'log2', 'min_samples_leaf': 2, 'min_samples_split': 10}
# means -> %f stds-> (%f) params with: %r 0.7089433701657458 0.06548278605265082 {'criterion': 'entropy', 'max_depth': 2, 'max_features': 'log2', 'min_samples_leaf': 4, 'min_samples_split': 2}
# means -> %f stds-> (%f) params with: %r 0.7177685922435272 0.06558978398510595 {'criterion': 'entropy', 'max_depth': 2, 'max_features': 'log2', 'min_samples_leaf': 4, 'min_samples_split': 5}
# means -> %f stds-> (%f) params with: %r 0.7104007556061098 0.05171030420316263 {'criterion': 'entropy', 'max_depth': 2, 'max_features': 'log2', 'min_samples_leaf': 4, 'min_samples_split': 10}
# means -> %f stds-> (%f) params with: %r nan nan {'criterion': 'entropy', 'max_depth': 4, 'max_features': 'auto', 'min_samples_leaf': 1, 'min_samples_split': 2}
# means -> %f stds-> (%f) params with: %r nan nan {'criterion': 'entropy', 'max_depth': 4, 'max_features': 'auto', 'min_samples_leaf': 1, 'min_samples_split': 5}
# means -> %f stds-> (%f) params with: %r nan nan {'criterion': 'entropy', 'max_depth': 4, 'max_features': 'auto', 'min_samples_leaf': 1, 'min_samples_split': 10}
# means -> %f stds-> (%f) params with: %r nan nan {'criterion': 'entropy', 'max_depth': 4, 'max_features': 'auto', 'min_samples_leaf': 2, 'min_samples_split': 2}
# means -> %f stds-> (%f) params with: %r nan nan {'criterion': 'entropy', 'max_depth': 4, 'max_features': 'auto', 'min_samples_leaf': 2, 'min_samples_split': 5}
# means -> %f stds-> (%f) params with: %r nan nan {'criterion': 'entropy', 'max_depth': 4, 'max_features': 'auto', 'min_samples_leaf': 2, 'min_samples_split': 10}
# means -> %f stds-> (%f) params with: %r nan nan {'criterion': 'entropy', 'max_depth': 4, 'max_features': 'auto', 'min_samples_leaf': 4, 'min_samples_split': 2}
# means -> %f stds-> (%f) params with: %r nan nan {'criterion': 'entropy', 'max_depth': 4, 'max_features': 'auto', 'min_samples_leaf': 4, 'min_samples_split': 5}
# means -> %f stds-> (%f) params with: %r nan nan {'criterion': 'entropy', 'max_depth': 4, 'max_features': 'auto', 'min_samples_leaf': 4, 'min_samples_split': 10}
# means -> %f stds-> (%f) params with: %r 0.7577276974325642 0.03720713537764075 {'criterion': 'entropy', 'max_depth': 4, 'max_features': 'sqrt', 'min_samples_leaf': 1, 'min_samples_split': 2}
# means -> %f stds-> (%f) params with: %r 0.747419022857762 0.03202517716516891 {'criterion': 'entropy', 'max_depth': 4, 'max_features': 'sqrt', 'min_samples_leaf': 1, 'min_samples_split': 5}
# means -> %f stds-> (%f) params with: %r 0.7583004956126096 0.042214793144415265 {'criterion': 'entropy', 'max_depth': 4, 'max_features': 'sqrt', 'min_samples_leaf': 1, 'min_samples_split': 10}
# means -> %f stds-> (%f) params with: %r 0.7575597849637092 0.039495768373151 {'criterion': 'entropy', 'max_depth': 4, 'max_features': 'sqrt', 'min_samples_leaf': 2, 'min_samples_split': 2}
# means -> %f stds-> (%f) params with: %r 0.749449883544578 0.03873699107809297 {'criterion': 'entropy', 'max_depth': 4, 'max_features': 'sqrt', 'min_samples_leaf': 2, 'min_samples_split': 5}
# means -> %f stds-> (%f) params with: %r 0.7476133409164771 0.05725399396454709 {'criterion': 'entropy', 'max_depth': 4, 'max_features': 'sqrt', 'min_samples_leaf': 2, 'min_samples_split': 10}
# means -> %f stds-> (%f) params with: %r 0.7708194534719965 0.034757291874186164 {'criterion': 'entropy', 'max_depth': 4, 'max_features': 'sqrt', 'min_samples_leaf': 4, 'min_samples_split': 2}
# means -> %f stds-> (%f) params with: %r 0.7678430695482612 0.03455387567879024 {'criterion': 'entropy', 'max_depth': 4, 'max_features': 'sqrt', 'min_samples_leaf': 4, 'min_samples_split': 5}
# means -> %f stds-> (%f) params with: %r 0.7360148548369624 0.04037104519542712 {'criterion': 'entropy', 'max_depth': 4, 'max_features': 'sqrt', 'min_samples_leaf': 4, 'min_samples_split': 10}
# means -> %f stds-> (%f) params with: %r 0.747793440580652 0.059864814988306446 {'criterion': 'entropy', 'max_depth': 4, 'max_features': 'log2', 'min_samples_leaf': 1, 'min_samples_split': 2}
# means -> %f stds-> (%f) params with: %r 0.7660004333225003 0.03252168613230476 {'criterion': 'entropy', 'max_depth': 4, 'max_features': 'log2', 'min_samples_leaf': 1, 'min_samples_split': 5}
# means -> %f stds-> (%f) params with: %r 0.7658338749864587 0.0335071874566577 {'criterion': 'entropy', 'max_depth': 4, 'max_features': 'log2', 'min_samples_leaf': 1, 'min_samples_split': 10}
# means -> %f stds-> (%f) params with: %r 0.749274861878453 0.031719540868690756 {'criterion': 'entropy', 'max_depth': 4, 'max_features': 'log2', 'min_samples_leaf': 2, 'min_samples_split': 2}
# means -> %f stds-> (%f) params with: %r 0.7707981258801864 0.024694418171370254 {'criterion': 'entropy', 'max_depth': 4, 'max_features': 'log2', 'min_samples_leaf': 2, 'min_samples_split': 5}
# means -> %f stds-> (%f) params with: %r 0.7573742687682807 0.039555853873635 {'criterion': 'entropy', 'max_depth': 4, 'max_features': 'log2', 'min_samples_leaf': 2, 'min_samples_split': 10}
# means -> %f stds-> (%f) params with: %r 0.7652678474704799 0.02963037512678779 {'criterion': 'entropy', 'max_depth': 4, 'max_features': 'log2', 'min_samples_leaf': 4, 'min_samples_split': 2}
# means -> %f stds-> (%f) params with: %r 0.7349108980608818 0.056542369789833666 {'criterion': 'entropy', 'max_depth': 4, 'max_features': 'log2', 'min_samples_leaf': 4, 'min_samples_split': 5}
# means -> %f stds-> (%f) params with: %r 0.7499935678691366 0.04677589379090136 {'criterion': 'entropy', 'max_depth': 4, 'max_features': 'log2', 'min_samples_leaf': 4, 'min_samples_split': 10}
# means -> %f stds-> (%f) params with: %r nan nan {'criterion': 'entropy', 'max_depth': 6, 'max_features': 'auto', 'min_samples_leaf': 1, 'min_samples_split': 2}
# means -> %f stds-> (%f) params with: %r nan nan {'criterion': 'entropy', 'max_depth': 6, 'max_features': 'auto', 'min_samples_leaf': 1, 'min_samples_split': 5}
# means -> %f stds-> (%f) params with: %r nan nan {'criterion': 'entropy', 'max_depth': 6, 'max_features': 'auto', 'min_samples_leaf': 1, 'min_samples_split': 10}
# means -> %f stds-> (%f) params with: %r nan nan {'criterion': 'entropy', 'max_depth': 6, 'max_features': 'auto', 'min_samples_leaf': 2, 'min_samples_split': 2}
# means -> %f stds-> (%f) params with: %r nan nan {'criterion': 'entropy', 'max_depth': 6, 'max_features': 'auto', 'min_samples_leaf': 2, 'min_samples_split': 5}
# means -> %f stds-> (%f) params with: %r nan nan {'criterion': 'entropy', 'max_depth': 6, 'max_features': 'auto', 'min_samples_leaf': 2, 'min_samples_split': 10}
# means -> %f stds-> (%f) params with: %r nan nan {'criterion': 'entropy', 'max_depth': 6, 'max_features': 'auto', 'min_samples_leaf': 4, 'min_samples_split': 2}
# means -> %f stds-> (%f) params with: %r nan nan {'criterion': 'entropy', 'max_depth': 6, 'max_features': 'auto', 'min_samples_leaf': 4, 'min_samples_split': 5}
# means -> %f stds-> (%f) params with: %r nan nan {'criterion': 'entropy', 'max_depth': 6, 'max_features': 'auto', 'min_samples_leaf': 4, 'min_samples_split': 10}
# means -> %f stds-> (%f) params with: %r 0.7917939551511213 0.0393808401901247 {'criterion': 'entropy', 'max_depth': 6, 'max_features': 'sqrt', 'min_samples_leaf': 1, 'min_samples_split': 2}
# means -> %f stds-> (%f) params with: %r 0.8092815648358792 0.029999017690046717 {'criterion': 'entropy', 'max_depth': 6, 'max_features': 'sqrt', 'min_samples_leaf': 1, 'min_samples_split': 5}
# means -> %f stds-> (%f) params with: %r 0.8030214088397789 0.030139790547820712 {'criterion': 'entropy', 'max_depth': 6, 'max_features': 'sqrt', 'min_samples_leaf': 1, 'min_samples_split': 10}
# means -> %f stds-> (%f) params with: %r 0.8153558661033473 0.02251729818020635 {'criterion': 'entropy', 'max_depth': 6, 'max_features': 'sqrt', 'min_samples_leaf': 2, 'min_samples_split': 2}
# means -> %f stds-> (%f) params with: %r 0.7855405698190878 0.04945691648075023 {'criterion': 'entropy', 'max_depth': 6, 'max_features': 'sqrt', 'min_samples_leaf': 2, 'min_samples_split': 5}
# means -> %f stds-> (%f) params with: %r 0.7953004820712816 0.04225465394654643 {'criterion': 'entropy', 'max_depth': 6, 'max_features': 'sqrt', 'min_samples_leaf': 2, 'min_samples_split': 10}
# means -> %f stds-> (%f) params with: %r 0.7951081952117863 0.028203360265092507 {'criterion': 'entropy', 'max_depth': 6, 'max_features': 'sqrt', 'min_samples_leaf': 4, 'min_samples_split': 2}
# means -> %f stds-> (%f) params with: %r 0.7995250379157188 0.02842327678509671 {'criterion': 'entropy', 'max_depth': 6, 'max_features': 'sqrt', 'min_samples_leaf': 4, 'min_samples_split': 5}
# means -> %f stds-> (%f) params with: %r 0.7984248050048748 0.032189007482008085 {'criterion': 'entropy', 'max_depth': 6, 'max_features': 'sqrt', 'min_samples_leaf': 4, 'min_samples_split': 10}
# means -> %f stds-> (%f) params with: %r 0.8009891940201495 0.021175473378127394 {'criterion': 'entropy', 'max_depth': 6, 'max_features': 'log2', 'min_samples_leaf': 1, 'min_samples_split': 2}
# means -> %f stds-> (%f) params with: %r 0.7921656646083848 0.03134339649381039 {'criterion': 'entropy', 'max_depth': 6, 'max_features': 'log2', 'min_samples_leaf': 1, 'min_samples_split': 5}
# means -> %f stds-> (%f) params with: %r 0.805972402773264 0.029348038364591454 {'criterion': 'entropy', 'max_depth': 6, 'max_features': 'log2', 'min_samples_leaf': 1, 'min_samples_split': 10}
# means -> %f stds-> (%f) params with: %r 0.8065242118947028 0.030102411951432095 {'criterion': 'entropy', 'max_depth': 6, 'max_features': 'log2', 'min_samples_leaf': 2, 'min_samples_split': 2}
# means -> %f stds-> (%f) params with: %r 0.80798701386632 0.024353390393341705 {'criterion': 'entropy', 'max_depth': 6, 'max_features': 'log2', 'min_samples_leaf': 2, 'min_samples_split': 5}
# means -> %f stds-> (%f) params with: %r 0.8065191338966526 0.02763145342955333 {'criterion': 'entropy', 'max_depth': 6, 'max_features': 'log2', 'min_samples_leaf': 2, 'min_samples_split': 10}
# means -> %f stds-> (%f) params with: %r 0.791985903477413 0.021588662701714056 {'criterion': 'entropy', 'max_depth': 6, 'max_features': 'log2', 'min_samples_leaf': 4, 'min_samples_split': 2}
# means -> %f stds-> (%f) params with: %r 0.7932740223161087 0.03811875853600339 {'criterion': 'entropy', 'max_depth': 6, 'max_features': 'log2', 'min_samples_leaf': 4, 'min_samples_split': 5}
# means -> %f stds-> (%f) params with: %r 0.7956762539269853 0.050983951900566066 {'criterion': 'entropy', 'max_depth': 6, 'max_features': 'log2', 'min_samples_leaf': 4, 'min_samples_split': 10}
# means -> %f stds-> (%f) params with: %r nan nan {'criterion': 'entropy', 'max_depth': 8, 'max_features': 'auto', 'min_samples_leaf': 1, 'min_samples_split': 2}
# means -> %f stds-> (%f) params with: %r nan nan {'criterion': 'entropy', 'max_depth': 8, 'max_features': 'auto', 'min_samples_leaf': 1, 'min_samples_split': 5}
# means -> %f stds-> (%f) params with: %r nan nan {'criterion': 'entropy', 'max_depth': 8, 'max_features': 'auto', 'min_samples_leaf': 1, 'min_samples_split': 10}
# means -> %f stds-> (%f) params with: %r nan nan {'criterion': 'entropy', 'max_depth': 8, 'max_features': 'auto', 'min_samples_leaf': 2, 'min_samples_split': 2}
# means -> %f stds-> (%f) params with: %r nan nan {'criterion': 'entropy', 'max_depth': 8, 'max_features': 'auto', 'min_samples_leaf': 2, 'min_samples_split': 5}
# means -> %f stds-> (%f) params with: %r nan nan {'criterion': 'entropy', 'max_depth': 8, 'max_features': 'auto', 'min_samples_leaf': 2, 'min_samples_split': 10}
# means -> %f stds-> (%f) params with: %r nan nan {'criterion': 'entropy', 'max_depth': 8, 'max_features': 'auto', 'min_samples_leaf': 4, 'min_samples_split': 2}
# means -> %f stds-> (%f) params with: %r nan nan {'criterion': 'entropy', 'max_depth': 8, 'max_features': 'auto', 'min_samples_leaf': 4, 'min_samples_split': 5}
# means -> %f stds-> (%f) params with: %r nan nan {'criterion': 'entropy', 'max_depth': 8, 'max_features': 'auto', 'min_samples_leaf': 4, 'min_samples_split': 10}
# means -> %f stds-> (%f) params with: %r 0.8332168779113855 0.01886346519509593 {'criterion': 'entropy', 'max_depth': 8, 'max_features': 'sqrt', 'min_samples_leaf': 1, 'min_samples_split': 2}
# means -> %f stds-> (%f) params with: %r 0.8238300292492688 0.015075787575218 {'criterion': 'entropy', 'max_depth': 8, 'max_features': 'sqrt', 'min_samples_leaf': 1, 'min_samples_split': 5}
# means -> %f stds-> (%f) params with: %r 0.8260382813346334 0.028432723185171864 {'criterion': 'entropy', 'max_depth': 8, 'max_features': 'sqrt', 'min_samples_leaf': 1, 'min_samples_split': 10}
# means -> %f stds-> (%f) params with: %r 0.8254827483479579 0.021674631740867773 {'criterion': 'entropy', 'max_depth': 8, 'max_features': 'sqrt', 'min_samples_leaf': 2, 'min_samples_split': 2}
# means -> %f stds-> (%f) params with: %r 0.8223591024807713 0.028388326173131046 {'criterion': 'entropy', 'max_depth': 8, 'max_features': 'sqrt', 'min_samples_leaf': 2, 'min_samples_split': 5}
# means -> %f stds-> (%f) params with: %r 0.8262234589968583 0.026666402973976117 {'criterion': 'entropy', 'max_depth': 8, 'max_features': 'sqrt', 'min_samples_leaf': 2, 'min_samples_split': 10}
# means -> %f stds-> (%f) params with: %r 0.8159120761564294 0.022083340493074553 {'criterion': 'entropy', 'max_depth': 8, 'max_features': 'sqrt', 'min_samples_leaf': 4, 'min_samples_split': 2}
# means -> %f stds-> (%f) params with: %r 0.8365365345033041 0.028192178250503373 {'criterion': 'entropy', 'max_depth': 8, 'max_features': 'sqrt', 'min_samples_leaf': 4, 'min_samples_split': 5}
# means -> %f stds-> (%f) params with: %r 0.8206969044523887 0.028039907138078402 {'criterion': 'entropy', 'max_depth': 8, 'max_features': 'sqrt', 'min_samples_leaf': 4, 'min_samples_split': 10}
# means -> %f stds-> (%f) params with: %r 0.8216150064998375 0.01737166758696388 {'criterion': 'entropy', 'max_depth': 8, 'max_features': 'log2', 'min_samples_leaf': 1, 'min_samples_split': 2}
# means -> %f stds-> (%f) params with: %r 0.8230937195320116 0.031186393382554137 {'criterion': 'entropy', 'max_depth': 8, 'max_features': 'log2', 'min_samples_leaf': 1, 'min_samples_split': 5}
# means -> %f stds-> (%f) params with: %r 0.8210645515112122 0.02674128199560763 {'criterion': 'entropy', 'max_depth': 8, 'max_features': 'log2', 'min_samples_leaf': 1, 'min_samples_split': 10}
# means -> %f stds-> (%f) params with: %r 0.8332206017766224 0.029175263318371662 {'criterion': 'entropy', 'max_depth': 8, 'max_features': 'log2', 'min_samples_leaf': 2, 'min_samples_split': 2}
# means -> %f stds-> (%f) params with: %r 0.8321163064673384 0.028106086374202633 {'criterion': 'entropy', 'max_depth': 8, 'max_features': 'log2', 'min_samples_leaf': 2, 'min_samples_split': 5}
# means -> %f stds-> (%f) params with: %r 0.8218056006933159 0.0357975114733001 {'criterion': 'entropy', 'max_depth': 8, 'max_features': 'log2', 'min_samples_leaf': 2, 'min_samples_split': 10}
# means -> %f stds-> (%f) params with: %r 0.8212558227710975 0.029806755969272444 {'criterion': 'entropy', 'max_depth': 8, 'max_features': 'log2', 'min_samples_leaf': 4, 'min_samples_split': 2}
# means -> %f stds-> (%f) params with: %r 0.8181281145054708 0.03485532223438854 {'criterion': 'entropy', 'max_depth': 8, 'max_features': 'log2', 'min_samples_leaf': 4, 'min_samples_split': 5}
# means -> %f stds-> (%f) params with: %r 0.8201525430614234 0.03235854848094938 {'criterion': 'entropy', 'max_depth': 8, 'max_features': 'log2', 'min_samples_leaf': 4, 'min_samples_split': 10}
# means -> %f stds-> (%f) params with: %r nan nan {'criterion': 'entropy', 'max_depth': 10, 'max_features': 'auto', 'min_samples_leaf': 1, 'min_samples_split': 2}
# means -> %f stds-> (%f) params with: %r nan nan {'criterion': 'entropy', 'max_depth': 10, 'max_features': 'auto', 'min_samples_leaf': 1, 'min_samples_split': 5}
# means -> %f stds-> (%f) params with: %r nan nan {'criterion': 'entropy', 'max_depth': 10, 'max_features': 'auto', 'min_samples_leaf': 1, 'min_samples_split': 10}
# means -> %f stds-> (%f) params with: %r nan nan {'criterion': 'entropy', 'max_depth': 10, 'max_features': 'auto', 'min_samples_leaf': 2, 'min_samples_split': 2}
# means -> %f stds-> (%f) params with: %r nan nan {'criterion': 'entropy', 'max_depth': 10, 'max_features': 'auto', 'min_samples_leaf': 2, 'min_samples_split': 5}
# means -> %f stds-> (%f) params with: %r nan nan {'criterion': 'entropy', 'max_depth': 10, 'max_features': 'auto', 'min_samples_leaf': 2, 'min_samples_split': 10}
# means -> %f stds-> (%f) params with: %r nan nan {'criterion': 'entropy', 'max_depth': 10, 'max_features': 'auto', 'min_samples_leaf': 4, 'min_samples_split': 2}
# means -> %f stds-> (%f) params with: %r nan nan {'criterion': 'entropy', 'max_depth': 10, 'max_features': 'auto', 'min_samples_leaf': 4, 'min_samples_split': 5}
# means -> %f stds-> (%f) params with: %r nan nan {'criterion': 'entropy', 'max_depth': 10, 'max_features': 'auto', 'min_samples_leaf': 4, 'min_samples_split': 10}
# means -> %f stds-> (%f) params with: %r 0.8519980229660925 0.027303346335835244 {'criterion': 'entropy', 'max_depth': 10, 'max_features': 'sqrt', 'min_samples_leaf': 1, 'min_samples_split': 2}
# means -> %f stds-> (%f) params with: %r 0.84757813346333 0.021749427103123928 {'criterion': 'entropy', 'max_depth': 10, 'max_features': 'sqrt', 'min_samples_leaf': 1, 'min_samples_split': 5}
# means -> %f stds-> (%f) params with: %r 0.8488679449680424 0.029842112366328145 {'criterion': 'entropy', 'max_depth': 10, 'max_features': 'sqrt', 'min_samples_leaf': 1, 'min_samples_split': 10}
# means -> %f stds-> (%f) params with: %r 0.8532902042032282 0.025189668552418786 {'criterion': 'entropy', 'max_depth': 10, 'max_features': 'sqrt', 'min_samples_leaf': 2, 'min_samples_split': 2}
# means -> %f stds-> (%f) params with: %r 0.8600909977250568 0.020477961446859597 {'criterion': 'entropy', 'max_depth': 10, 'max_features': 'sqrt', 'min_samples_leaf': 2, 'min_samples_split': 5}
# means -> %f stds-> (%f) params with: %r 0.853095886144513 0.02179812515305035 {'criterion': 'entropy', 'max_depth': 10, 'max_features': 'sqrt', 'min_samples_leaf': 2, 'min_samples_split': 10}
# means -> %f stds-> (%f) params with: %r 0.8577056927743472 0.02684931674690362 {'criterion': 'entropy', 'max_depth': 10, 'max_features': 'sqrt', 'min_samples_leaf': 4, 'min_samples_split': 2}
# means -> %f stds-> (%f) params with: %r 0.8540234671216552 0.029585448570657535 {'criterion': 'entropy', 'max_depth': 10, 'max_features': 'sqrt', 'min_samples_leaf': 4, 'min_samples_split': 5}
# means -> %f stds-> (%f) params with: %r 0.8558633950817895 0.026229345698707072 {'criterion': 'entropy', 'max_depth': 10, 'max_features': 'sqrt', 'min_samples_leaf': 4, 'min_samples_split': 10}
# means -> %f stds-> (%f) params with: %r 0.8531002870761565 0.026733231904044547 {'criterion': 'entropy', 'max_depth': 10, 'max_features': 'log2', 'min_samples_leaf': 1, 'min_samples_split': 2}
# means -> %f stds-> (%f) params with: %r 0.8499671622792763 0.02963972734576907 {'criterion': 'entropy', 'max_depth': 10, 'max_features': 'log2', 'min_samples_leaf': 1, 'min_samples_split': 5}
# means -> %f stds-> (%f) params with: %r 0.8472128561369299 0.026087296006714077 {'criterion': 'entropy', 'max_depth': 10, 'max_features': 'log2', 'min_samples_leaf': 1, 'min_samples_split': 10}
# means -> %f stds-> (%f) params with: %r 0.857154222186112 0.028396490681987033 {'criterion': 'entropy', 'max_depth': 10, 'max_features': 'log2', 'min_samples_leaf': 2, 'min_samples_split': 2}
# means -> %f stds-> (%f) params with: %r 0.8554994718882029 0.02970864673691425 {'criterion': 'entropy', 'max_depth': 10, 'max_features': 'log2', 'min_samples_leaf': 2, 'min_samples_split': 5}
# means -> %f stds-> (%f) params with: %r 0.8549385223702741 0.023186880704195625 {'criterion': 'entropy', 'max_depth': 10, 'max_features': 'log2', 'min_samples_leaf': 2, 'min_samples_split': 10}
# means -> %f stds-> (%f) params with: %r 0.8494261862203445 0.029028157772805357 {'criterion': 'entropy', 'max_depth': 10, 'max_features': 'log2', 'min_samples_leaf': 4, 'min_samples_split': 2}
# means -> %f stds-> (%f) params with: %r 0.8492369461596793 0.03057084499965907 {'criterion': 'entropy', 'max_depth': 10, 'max_features': 'log2', 'min_samples_leaf': 4, 'min_samples_split': 5}
# means -> %f stds-> (%f) params with: %r 0.8481285884519554 0.02180587887825289 {'criterion': 'entropy', 'max_depth': 10, 'max_features': 'log2', 'min_samples_leaf': 4, 'min_samples_split': 10}

# %%
clfModel_BestParam = tree.DecisionTreeClassifier(
    max_depth=best_params['max_depth'],
    min_samples_split=best_params['min_samples_split'],
    min_samples_leaf=best_params['min_samples_leaf'],
    max_features=best_params['max_features'],
    criterion=best_params['criterion']
)

# %%
clfModel_BestParam.fit(X_train_scaled, y_train_smote)
# Out:
# DecisionTreeClassifier(max_depth=10, max_features='sqrt', min_samples_leaf=2)

# %%
print("ตัวอย่างข้อมูลชุดเรียนรู้ ->",clfModel_BestParam.score(X_train_scaled, y_train_smote))
# Out:
# ตัวอย่างข้อมูลชุดเรียนรู้ -> 0.8948821796759941

# %%
plt.figure(figsize=(12, 6))
tree.plot_tree(clfModel_BestParam.fit(X_train_scaled,y_train_smote))
plt.show()

# %%
y_pred = clfModel_BestParam.predict(X_test_scaled)
print("ตัวอย่างข้อมูลชุดทดสอบ ->",accuracy_score(y_test, y_pred))
# Out:
# ตัวอย่างข้อมูลชุดทดสอบ -> 0.7902439024390244

# %%
pd.crosstab(y_test, y_pred)
# Out:
# col_0        0    1
# alzheimer
# 0          947  198
# 1           60   25

# %%
print("Classification Report:\n", classification_report(y_test, y_pred))
# Out:
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.94      0.83      0.88      1145
#            1       0.11      0.29      0.16        85
#
#     accuracy                           0.79      1230
#    macro avg       0.53      0.56      0.52      1230
# weighted avg       0.88      0.79      0.83      1230

# %%
plt.figure(figsize=(12, 6))
tree.plot_tree(clfModel_BestParam.fit(X_test_scaled,y_test))
plt.show()
