# %%
import pandas as pd
import numpy as np

# %%
dataSet = pd.read_csv("Alzheimer.csv")
dataSet
# Out:
#          HN         Education   age  hypertension  heart_disease  \
# 0     11046  Secondary School  67.0             0              1
# 1     51676          Bachelor  61.0             0              0
# 2     35112  Secondary School  80.0             0              1
# 3     67182          Bachelor  49.0             0              0
# 4      1665          Bachelor  79.0             1              0
# ...     ...               ...   ...           ...            ...
# 4095  68398  Secondary School  82.0             1              0
# 4096  14180          Bachelor  13.0             0              0
# 4097  44873          Bachelor  81.0             0              0
# 4098  19723          Bachelor  35.0             0              0
# 4099  44679          Bachelor  44.0             0              0
#
#      family history Occupation Triglycerides  Blood Sugar   BMI  \
# 0               Yes    Private        Normal       228.69  36.6
# 1               Yes  Freelance          High       202.21   NaN
# 2               Yes    Private          High       105.92  32.5
# 3               Yes    Private        Normal       171.23  34.4
# 4               Yes  Freelance          High       174.12  24.0
# ...             ...        ...           ...          ...   ...
# 4095            Yes  Freelance          High        71.97  28.3
# 4096             No     Farmer          High       103.08  18.6
# 4097            Yes  Freelance        Normal       125.20  40.0
# 4098            Yes  Freelance          High        82.99  30.6
# 4099            Yes    Officer        Normal        85.28  26.2
#
#        smoking_status  alzheimer
# 0     formerly smoked          1
# 1        never smoked          1
# 2        never smoked          1
# 3              smokes          1
# 4        never smoked          1
# ...               ...        ...
# 4095     never smoked          0
# 4096          Unknown          0
# 4097     never smoked          0
# 4098     never smoked          0
# 4099          Unknown          0
#
# [4100 rows x 12 columns]

# %% [markdown]
# # MARK: Data Processing

# %%
dataSet.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4100 entries, 0 to 4099
# Data columns (total 12 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   HN              4100 non-null   int64
#  1   Education       4100 non-null   object
#  2   age             4100 non-null   float64
#  3   hypertension    4100 non-null   int64
#  4   heart_disease   4100 non-null   int64
#  5   family history  4100 non-null   object
#  6   Occupation      4100 non-null   object
#  7   Triglycerides   4100 non-null   object
#  8   Blood Sugar     4100 non-null   float64
#  9   BMI             3936 non-null   float64
#  10  smoking_status  4100 non-null   object
#  11  alzheimer       4100 non-null   int64
# dtypes: float64(3), int64(4), object(5)
# memory usage: 384.5+ KB

# %%
dataSet.isna().sum()
# Out:
# HN                  0
# Education           0
# age                 0
# hypertension        0
# heart_disease       0
# family history      0
# Occupation          0
# Triglycerides       0
# Blood Sugar         0
# BMI               164
# smoking_status      0
# alzheimer           0
# dtype: int64

# %% [markdown]
# ### MARK: เลือกที่จะ drop ทิ้งเพราะว่า Null มีจำนวนไม่เยอะมาก ไม่มีผลต่อ data เท่าที่ควร และ ไม่สามารถหาค่า BMI มาแทนที่ได้เพราะไม่มี weight และ height ของผู้ป่วย

# %%
dataSet = dataSet.dropna()
dataSet.isna().sum()
# Out:
# HN                0
# Education         0
# age               0
# hypertension      0
# heart_disease     0
# family history    0
# Occupation        0
# Triglycerides     0
# Blood Sugar       0
# BMI               0
# smoking_status    0
# alzheimer         0
# dtype: int64

# %% [markdown]
# ### MARK: ตรวจสอบ Class Target จำนวนเหมาะสมกันหรือไม่

# %%
print("Target == 1 ->", len(dataSet.loc[dataSet["alzheimer"] == 1, "alzheimer"]))
# Out:
# Target == 1 -> 202

# %%
print("Target == 1 ->", len(dataSet.loc[dataSet["alzheimer"] == 0, "alzheimer"]))
# Out:
# Target == 1 -> 3734

# %% [markdown]
# ### MARK: ปรับข้อมูล เป็น 0,1 <- LabelEncoder

# %%
from sklearn.preprocessing import LabelEncoder

# %%
dataSet.head()
# Out:
#       HN         Education   age  hypertension  heart_disease family history  \
# 0  11046  Secondary School  67.0             0              1            Yes
# 2  35112  Secondary School  80.0             0              1            Yes
# 3  67182          Bachelor  49.0             0              0            Yes
# 4   1665          Bachelor  79.0             1              0            Yes
# 5  66889  Secondary School  81.0             0              0            Yes
#
#   Occupation Triglycerides  Blood Sugar   BMI   smoking_status  alzheimer
# 0    Private        Normal       228.69  36.6  formerly smoked          1
# 2    Private          High       105.92  32.5     never smoked          1
# 3    Private        Normal       171.23  34.4           smokes          1
# 4  Freelance          High       174.12  24.0     never smoked          1
# 5    Private        Normal       186.21  29.0  formerly smoked          1

# %%
label_encoder = LabelEncoder()

# %%
dataSet['Education'] = label_encoder.fit_transform(dataSet['Education'])
dataSet['family history'] = label_encoder.fit_transform(dataSet['family history'])
dataSet['Occupation'] = label_encoder.fit_transform(dataSet['Occupation'])
dataSet['Triglycerides'] = label_encoder.fit_transform(dataSet['Triglycerides'])
dataSet['smoking_status'] = label_encoder.fit_transform(dataSet['smoking_status'])
# Out:
# C:\Users\PP\AppData\Local\Temp\ipykernel_8448\447424765.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataSet['Education'] = label_encoder.fit_transform(dataSet['Education'])
# C:\Users\PP\AppData\Local\Temp\ipykernel_8448\447424765.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataSet['family history'] = label_encoder.fit_transform(dataSet['family history'])
# C:\Users\PP\AppData\Local\Temp\ipykernel_8448\447424765.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataSet['Occupation'] = label_encoder.fit_transform(dataSet['Occupation'])
# C:\Users\PP\AppData\Local\Temp\ipykernel_8448\447424765.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataSet['Triglycerides'] = label_encoder.fit_transform(dataSet['Triglycerides'])
# C:\Users\PP\AppData\Local\Temp\ipykernel_8448\447424765.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataSet['smoking_status'] = label_encoder.fit_transform(dataSet['smoking_status'])

# %%
dataSet
# Out:
#          HN  Education   age  hypertension  heart_disease  family history  \
# 0     11046          1  67.0             0              1               1
# 2     35112          1  80.0             0              1               1
# 3     67182          0  49.0             0              0               1
# 4      1665          0  79.0             1              0               1
# 5     66889          1  81.0             0              0               1
# ...     ...        ...   ...           ...            ...             ...
# 4095  68398          1  82.0             1              0               1
# 4096  14180          0  13.0             0              0               0
# 4097  44873          0  81.0             0              0               1
# 4098  19723          0  35.0             0              0               1
# 4099  44679          0  44.0             0              0               1
#
#       Occupation  Triglycerides  Blood Sugar   BMI  smoking_status  alzheimer
# 0              4              1       228.69  36.6               1          1
# 2              4              0       105.92  32.5               2          1
# 3              4              1       171.23  34.4               3          1
# 4              1              0       174.12  24.0               2          1
# 5              4              1       186.21  29.0               1          1
# ...          ...            ...          ...   ...             ...        ...
# 4095           1              0        71.97  28.3               2          0
# 4096           0              0       103.08  18.6               0          0
# 4097           1              1       125.20  40.0               2          0
# 4098           1              0        82.99  30.6               2          0
# 4099           3              1        85.28  26.2               0          0
#
# [3936 rows x 12 columns]

# %% [markdown]
# # MARK: แบ่งข้อมูล

# %%
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, classification_report
from sklearn import tree
from sklearn.tree import plot_tree
import matplotlib.pyplot as plt

# %% [markdown]
# ### MARK: train_test_split

# %%
X = dataSet.drop(['HN', 'alzheimer'], axis=1)#dataSet.drop('alzheimer', axis=1)
y = dataSet["alzheimer"]
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# %%
X_train.head()
# Out:
#       Education   age  hypertension  heart_disease  family history  \
# 2837          0  22.0             0              0               0
# 2069          1  46.0             0              0               1
# 1724          0  42.0             0              0               1
# 1826          0  54.0             0              0               1
# 514           1   9.0             0              0               0
#
#       Occupation  Triglycerides  Blood Sugar   BMI  smoking_status
# 2837           4              0        80.72  29.3               0
# 2069           4              0        78.44  23.9               2
# 1724           1              1       124.34  34.7               1
# 1826           3              0       102.61  32.4               0
# 514            0              1       122.22  17.7               0

# %%
X_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2755 entries, 2837 to 3323
# Data columns (total 10 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Education       2755 non-null   int32
#  1   age             2755 non-null   float64
#  2   hypertension    2755 non-null   int64
#  3   heart_disease   2755 non-null   int64
#  4   family history  2755 non-null   int32
#  5   Occupation      2755 non-null   int32
#  6   Triglycerides   2755 non-null   int32
#  7   Blood Sugar     2755 non-null   float64
#  8   BMI             2755 non-null   float64
#  9   smoking_status  2755 non-null   int32
# dtypes: float64(3), int32(5), int64(2)
# memory usage: 182.9 KB

# %%
y_train.info()
# Out:
# <class 'pandas.core.series.Series'>
# Int64Index: 2755 entries, 2837 to 3323
# Series name: alzheimer
# Non-Null Count  Dtype
# --------------  -----
# 2755 non-null   int64
# dtypes: int64(1)
# memory usage: 43.0 KB

# %% [markdown]
# ### SMOTE (Synthetic Minority Over-sampling Technique): วิธีการที่ใช้การสร้างตัวอย่างสัญญาณเทียบเท่าจากคลาสน้อยโดยการผสมคุณลักษณะของตัวอย่างในคลาสน้อย

# %%
from imblearn.over_sampling import SMOTE
from sklearn.preprocessing import StandardScaler

# %%
smote = SMOTE(random_state=42)
X_train_smote, y_train_smote = smote.fit_resample(X_train, y_train)

# %% [markdown]
# ## MARK: ทำ scaler

# %%
scaler = StandardScaler()

X_train_scaled = scaler.fit_transform(X_train_smote)
X_test_scaled = scaler.transform(X_test)

# %% [markdown]
# # MARK: Decision tree model Start (Default)

# %%
clfModel = tree.DecisionTreeClassifier(criterion="gini",class_weight='balanced',random_state=42)

# %%
clfModel.get_params()
# Out:
# {'ccp_alpha': 0.0,
#  'class_weight': 'balanced',
#  'criterion': 'gini',
#  'max_depth': None,
#  'max_features': None,
#  'max_leaf_nodes': None,
#  'min_impurity_decrease': 0.0,
#  'min_samples_leaf': 1,
#  'min_samples_split': 2,
#  'min_weight_fraction_leaf': 0.0,
#  'random_state': 42,
#  'splitter': 'best'}

# %%
clfModel.fit(X_train_scaled,y_train_smote)
# Out:
# DecisionTreeClassifier(class_weight='balanced', random_state=42)

# %%
print("ตัวอย่างข้อมูลชุดเรียนรู้ ->",clfModel.score(X_train_scaled,y_train_smote))
# อันเดียวกัน
# y_train_pred = clf.predict(X_train)
# accuracy_score(y_train, y_train_pred)
# Out:
# ตัวอย่างข้อมูลชุดเรียนรู้ -> 1.0

# %% [markdown]
# ### MARK: Visualize Decision Tree

# %%
plt.figure(figsize=(12, 6))
tree.plot_tree(clfModel.fit(X_train_scaled,y_train_smote))
plt.show()

# %% [markdown]
# ### MARK: Predict and Score Model

# %%
y_pred = clfModel.predict(X_test_scaled)
print("ตัวอย่างข้อมูลชุดทดสอบ ->",accuracy_score(y_test, y_pred))
# Out:
# ตัวอย่างข้อมูลชุดทดสอบ -> 0.8653683319220999

# %%
pd.crosstab(y_test, y_pred)
# Out:
# col_0         0    1
# alzheimer
# 0          1008  106
# 1            53   14

# %%
print("Classification Report:\n", classification_report(y_test, y_pred))
# Out:
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.95      0.90      0.93      1114
#            1       0.12      0.21      0.15        67
#
#     accuracy                           0.87      1181
#    macro avg       0.53      0.56      0.54      1181
# weighted avg       0.90      0.87      0.88      1181

# %%
plt.figure(figsize=(12, 6))
tree.plot_tree(clfModel.fit(X_test_scaled,y_test))
plt.show()

# %% [markdown]
# ## MARK: หา Best Parameter และ ลองทำ Pruning

# %%
from sklearn.model_selection import GridSearchCV

# %% [markdown]
# ### MARK: ค้นหา best_params และประเมิน best_accuracy

# %%
param_grid = {
    'max_depth': [2, 4, 6, 8, 10],
    'min_samples_split': [2, 5, 10],
    'min_samples_leaf': [1, 2, 4],
    'max_features': ['auto', 'sqrt', 'log2'],
    'criterion': ['gini', 'entropy']
}
treeModel = tree.DecisionTreeClassifier()
# สร้าง Grid Search
grid_search = GridSearchCV(treeModel, param_grid, cv=10, scoring='accuracy')

# %%
grid_search.fit(X_train_scaled,y_train_smote)
# Out:
# C:\Users\PP\anaconda3\envs\CallmeEnv\lib\site-packages\sklearn\model_selection\_validation.py:425: FitFailedWarning:
# 900 fits failed out of a total of 2700.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 900 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\Users\PP\anaconda3\envs\CallmeEnv\lib\site-packages\sklearn\model_selection\_validation.py", line 732, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\PP\anaconda3\envs\CallmeEnv\lib\site-packages\sklearn\base.py", line 1144, in wrapper
#     estimator._validate_params()
#   File "C:\Users\PP\anaconda3\envs\CallmeEnv\lib\site-packages\sklearn\base.py", line 637, in _validate_params
#     validate_parameter_constraints(
#   File "C:\Users\PP\anaconda3\envs\CallmeEnv\lib\site-packages\sklearn\utils\_param_validation.py", line 95, in validate_parameter_constraints
#     raise InvalidParameterError(
# sklearn.utils._param_validation.InvalidParameterError: The 'max_features' parameter of DecisionTreeClassifier must be an int in the range [1, inf), a float in the range (0.0, 1.0], a str among {'log2', 'sqrt'} or None. Got 'auto' instead.
#
#   warnings.warn(some_fits_failed_message, FitFailedWarning)
# C:\Users\PP\anaconda3\envs\CallmeEnv\lib\site-packages\sklearn\model_selection\_search.py:976: UserWarning: One or more of the test scores are non-finite: [       nan        nan        nan        nan        nan        nan
#         nan        nan        nan 0.74618321 0.70496183 0.7480916
#  0.69828244 0.7009542  0.68759542 0.71793893 0.70667939 0.69274809
#  0.70477099 0.68110687 0.70305344 0.75152672 0.68301527 0.69198473
#  0.72938931 0.71316794 0.72194656        nan        nan        nan
#         nan        nan        nan        nan        nan        nan
#  0.76812977 0.76660305 0.77328244 0.78912214 0.76679389 0.77137405
#  0.76049618 0.76450382 0.79179389 0.77805344 0.77423664 0.76583969
#  0.78320611 0.77061069 0.77519084 0.77958015 0.76774809 0.77366412
#         nan        nan        nan        nan        nan        nan
#         nan        nan        nan 0.80438931 0.80858779 0.79370229
#  0.80648855 0.81450382 0.81793893 0.81240458 0.80362595 0.80610687
#  0.81507634 0.79961832 0.80419847 0.80400763 0.79961832 0.81335878
#  0.81946565 0.80458015 0.80744275        nan        nan        nan
#         nan        nan        nan        nan        nan        nan
#  0.83759542 0.84446565 0.83740458 0.84541985 0.84923664 0.8389313
#  0.83320611 0.83912214 0.83377863 0.83339695 0.8471374  0.84007634
#  0.8360687  0.84198473 0.83244275 0.83339695 0.83148855 0.83282443
#         nan        nan        nan        nan        nan        nan
#         nan        nan        nan 0.86412214 0.8721374  0.87080153
#  0.8639313  0.8620229  0.85706107 0.85171756 0.85782443 0.86145038
#  0.8721374  0.85515267 0.85610687 0.87099237 0.86335878 0.85744275
#  0.86354962 0.85477099 0.85553435        nan        nan        nan
#         nan        nan        nan        nan        nan        nan
#  0.71145038 0.66717557 0.7471374  0.73053435 0.69580153 0.7120229
#  0.68416031 0.73587786 0.70954198 0.72194656 0.66087786 0.69847328
#  0.72614504 0.68396947 0.70534351 0.70400763 0.69675573 0.71278626
#         nan        nan        nan        nan        nan        nan
#         nan        nan        nan 0.77156489 0.76965649 0.77977099
#  0.77843511 0.75610687 0.77671756 0.75324427 0.74255725 0.76526718
#  0.73015267 0.75648855 0.76660305 0.7730916  0.76049618 0.77137405
#  0.76755725 0.77958015 0.77385496        nan        nan        nan
#         nan        nan        nan        nan        nan        nan
#  0.79828244 0.80839695 0.79122137 0.80553435 0.80896947 0.80839695
#  0.80019084 0.79751908 0.80648855 0.80171756 0.80782443 0.79751908
#  0.80477099 0.80667939 0.79618321 0.80267176 0.80229008 0.80248092
#         nan        nan        nan        nan        nan        nan
#         nan        nan        nan 0.83091603 0.83072519 0.83625954
#  0.83396947 0.82958015 0.83244275 0.82919847 0.8278626  0.82996183
#  0.82824427 0.82767176 0.82614504 0.84103053 0.83931298 0.82958015
#  0.8389313  0.83053435 0.83549618        nan        nan        nan
#         nan        nan        nan        nan        nan        nan
#  0.85935115 0.85553435 0.85877863 0.86145038 0.86526718 0.86221374
#  0.8519084  0.85076336 0.85076336 0.86125954 0.86278626 0.85667939
#  0.86087786 0.85324427 0.85477099 0.85324427 0.85496183 0.85916031]
#   warnings.warn(
# GridSearchCV(cv=10, estimator=DecisionTreeClassifier(),
#              param_grid={'criterion': ['gini', 'entropy'],
#                          'max_depth': [2, 4, 6, 8, 10],
#                          'max_features': ['auto', 'sqrt', 'log2'],
#                          'min_samples_leaf': [1, 2, 4],
#                          'min_samples_split': [2, 5, 10]},
#              scoring='accuracy')

# %%
best_params = grid_search.best_params_
print("Best Parameters:", best_params)
# Out:
# Best Parameters: {'criterion': 'gini', 'max_depth': 10, 'max_features': 'log2', 'min_samples_leaf': 1, 'min_samples_split': 2}

# %%
best_accuracy = grid_search.best_score_
print("Best Accuracy:", best_accuracy)
# Out:
# Best Accuracy: 0.8721374045801527

# %%
print("Best:",grid_search.best_score_,"using" , grid_search.best_params_)
means = grid_search.cv_results_["mean_test_score"]
stds = grid_search.cv_results_["std_test_score"]
params = grid_search.cv_results_["params"]
for means, stds, params in zip(means, stds, params):
    print("means -> %f stds-> (%f) params with: %r", means, stds, params)
# Out:
# Best: 0.8721374045801527 using {'criterion': 'gini', 'max_depth': 10, 'max_features': 'log2', 'min_samples_leaf': 1, 'min_samples_split': 2}
# means -> %f stds-> (%f) params with: %r nan nan {'criterion': 'gini', 'max_depth': 2, 'max_features': 'auto', 'min_samples_leaf': 1, 'min_samples_split': 2}
# means -> %f stds-> (%f) params with: %r nan nan {'criterion': 'gini', 'max_depth': 2, 'max_features': 'auto', 'min_samples_leaf': 1, 'min_samples_split': 5}
# means -> %f stds-> (%f) params with: %r nan nan {'criterion': 'gini', 'max_depth': 2, 'max_features': 'auto', 'min_samples_leaf': 1, 'min_samples_split': 10}
# means -> %f stds-> (%f) params with: %r nan nan {'criterion': 'gini', 'max_depth': 2, 'max_features': 'auto', 'min_samples_leaf': 2, 'min_samples_split': 2}
# means -> %f stds-> (%f) params with: %r nan nan {'criterion': 'gini', 'max_depth': 2, 'max_features': 'auto', 'min_samples_leaf': 2, 'min_samples_split': 5}
# means -> %f stds-> (%f) params with: %r nan nan {'criterion': 'gini', 'max_depth': 2, 'max_features': 'auto', 'min_samples_leaf': 2, 'min_samples_split': 10}
# means -> %f stds-> (%f) params with: %r nan nan {'criterion': 'gini', 'max_depth': 2, 'max_features': 'auto', 'min_samples_leaf': 4, 'min_samples_split': 2}
# means -> %f stds-> (%f) params with: %r nan nan {'criterion': 'gini', 'max_depth': 2, 'max_features': 'auto', 'min_samples_leaf': 4, 'min_samples_split': 5}
# means -> %f stds-> (%f) params with: %r nan nan {'criterion': 'gini', 'max_depth': 2, 'max_features': 'auto', 'min_samples_leaf': 4, 'min_samples_split': 10}
# means -> %f stds-> (%f) params with: %r 0.7461832061068703 0.05935697426026468 {'criterion': 'gini', 'max_depth': 2, 'max_features': 'sqrt', 'min_samples_leaf': 1, 'min_samples_split': 2}
# means -> %f stds-> (%f) params with: %r 0.7049618320610687 0.07630342821748831 {'criterion': 'gini', 'max_depth': 2, 'max_features': 'sqrt', 'min_samples_leaf': 1, 'min_samples_split': 5}
# means -> %f stds-> (%f) params with: %r 0.7480916030534353 0.05130713744704269 {'criterion': 'gini', 'max_depth': 2, 'max_features': 'sqrt', 'min_samples_leaf': 1, 'min_samples_split': 10}
# means -> %f stds-> (%f) params with: %r 0.6982824427480916 0.05701254031799379 {'criterion': 'gini', 'max_depth': 2, 'max_features': 'sqrt', 'min_samples_leaf': 2, 'min_samples_split': 2}
# means -> %f stds-> (%f) params with: %r 0.7009541984732826 0.07138552587595039 {'criterion': 'gini', 'max_depth': 2, 'max_features': 'sqrt', 'min_samples_leaf': 2, 'min_samples_split': 5}
# means -> %f stds-> (%f) params with: %r 0.6875954198473282 0.07019710734171725 {'criterion': 'gini', 'max_depth': 2, 'max_features': 'sqrt', 'min_samples_leaf': 2, 'min_samples_split': 10}
# means -> %f stds-> (%f) params with: %r 0.71793893129771 0.0709749219312721 {'criterion': 'gini', 'max_depth': 2, 'max_features': 'sqrt', 'min_samples_leaf': 4, 'min_samples_split': 2}
# means -> %f stds-> (%f) params with: %r 0.7066793893129771 0.07816067960387811 {'criterion': 'gini', 'max_depth': 2, 'max_features': 'sqrt', 'min_samples_leaf': 4, 'min_samples_split': 5}
# means -> %f stds-> (%f) params with: %r 0.6927480916030535 0.0600281094926219 {'criterion': 'gini', 'max_depth': 2, 'max_features': 'sqrt', 'min_samples_leaf': 4, 'min_samples_split': 10}
# means -> %f stds-> (%f) params with: %r 0.7047709923664123 0.06759093695937848 {'criterion': 'gini', 'max_depth': 2, 'max_features': 'log2', 'min_samples_leaf': 1, 'min_samples_split': 2}
# means -> %f stds-> (%f) params with: %r 0.6811068702290077 0.06341192703228737 {'criterion': 'gini', 'max_depth': 2, 'max_features': 'log2', 'min_samples_leaf': 1, 'min_samples_split': 5}
# means -> %f stds-> (%f) params with: %r 0.7030534351145039 0.07236927072655001 {'criterion': 'gini', 'max_depth': 2, 'max_features': 'log2', 'min_samples_leaf': 1, 'min_samples_split': 10}
# means -> %f stds-> (%f) params with: %r 0.7515267175572519 0.047008585607281966 {'criterion': 'gini', 'max_depth': 2, 'max_features': 'log2', 'min_samples_leaf': 2, 'min_samples_split': 2}
# means -> %f stds-> (%f) params with: %r 0.6830152671755725 0.0630490567394695 {'criterion': 'gini', 'max_depth': 2, 'max_features': 'log2', 'min_samples_leaf': 2, 'min_samples_split': 5}
# means -> %f stds-> (%f) params with: %r 0.6919847328244275 0.06733261483797826 {'criterion': 'gini', 'max_depth': 2, 'max_features': 'log2', 'min_samples_leaf': 2, 'min_samples_split': 10}
# means -> %f stds-> (%f) params with: %r 0.7293893129770993 0.07313319726152669 {'criterion': 'gini', 'max_depth': 2, 'max_features': 'log2', 'min_samples_leaf': 4, 'min_samples_split': 2}
# means -> %f stds-> (%f) params with: %r 0.7131679389312977 0.06169201225605995 {'criterion': 'gini', 'max_depth': 2, 'max_features': 'log2', 'min_samples_leaf': 4, 'min_samples_split': 5}
# means -> %f stds-> (%f) params with: %r 0.7219465648854962 0.07537104959355867 {'criterion': 'gini', 'max_depth': 2, 'max_features': 'log2', 'min_samples_leaf': 4, 'min_samples_split': 10}
# means -> %f stds-> (%f) params with: %r nan nan {'criterion': 'gini', 'max_depth': 4, 'max_features': 'auto', 'min_samples_leaf': 1, 'min_samples_split': 2}
# means -> %f stds-> (%f) params with: %r nan nan {'criterion': 'gini', 'max_depth': 4, 'max_features': 'auto', 'min_samples_leaf': 1, 'min_samples_split': 5}
# means -> %f stds-> (%f) params with: %r nan nan {'criterion': 'gini', 'max_depth': 4, 'max_features': 'auto', 'min_samples_leaf': 1, 'min_samples_split': 10}
# means -> %f stds-> (%f) params with: %r nan nan {'criterion': 'gini', 'max_depth': 4, 'max_features': 'auto', 'min_samples_leaf': 2, 'min_samples_split': 2}
# means -> %f stds-> (%f) params with: %r nan nan {'criterion': 'gini', 'max_depth': 4, 'max_features': 'auto', 'min_samples_leaf': 2, 'min_samples_split': 5}
# means -> %f stds-> (%f) params with: %r nan nan {'criterion': 'gini', 'max_depth': 4, 'max_features': 'auto', 'min_samples_leaf': 2, 'min_samples_split': 10}
# means -> %f stds-> (%f) params with: %r nan nan {'criterion': 'gini', 'max_depth': 4, 'max_features': 'auto', 'min_samples_leaf': 4, 'min_samples_split': 2}
# means -> %f stds-> (%f) params with: %r nan nan {'criterion': 'gini', 'max_depth': 4, 'max_features': 'auto', 'min_samples_leaf': 4, 'min_samples_split': 5}
# means -> %f stds-> (%f) params with: %r nan nan {'criterion': 'gini', 'max_depth': 4, 'max_features': 'auto', 'min_samples_leaf': 4, 'min_samples_split': 10}
# means -> %f stds-> (%f) params with: %r 0.7681297709923665 0.04878371773350549 {'criterion': 'gini', 'max_depth': 4, 'max_features': 'sqrt', 'min_samples_leaf': 1, 'min_samples_split': 2}
# means -> %f stds-> (%f) params with: %r 0.7666030534351145 0.04504827483957396 {'criterion': 'gini', 'max_depth': 4, 'max_features': 'sqrt', 'min_samples_leaf': 1, 'min_samples_split': 5}
# means -> %f stds-> (%f) params with: %r 0.7732824427480915 0.03317318715670344 {'criterion': 'gini', 'max_depth': 4, 'max_features': 'sqrt', 'min_samples_leaf': 1, 'min_samples_split': 10}
# means -> %f stds-> (%f) params with: %r 0.7891221374045801 0.023578551269081836 {'criterion': 'gini', 'max_depth': 4, 'max_features': 'sqrt', 'min_samples_leaf': 2, 'min_samples_split': 2}
# means -> %f stds-> (%f) params with: %r 0.766793893129771 0.036706763899005034 {'criterion': 'gini', 'max_depth': 4, 'max_features': 'sqrt', 'min_samples_leaf': 2, 'min_samples_split': 5}
# means -> %f stds-> (%f) params with: %r 0.7713740458015266 0.027914831302635956 {'criterion': 'gini', 'max_depth': 4, 'max_features': 'sqrt', 'min_samples_leaf': 2, 'min_samples_split': 10}
# means -> %f stds-> (%f) params with: %r 0.7604961832061069 0.04370395676677834 {'criterion': 'gini', 'max_depth': 4, 'max_features': 'sqrt', 'min_samples_leaf': 4, 'min_samples_split': 2}
# means -> %f stds-> (%f) params with: %r 0.7645038167938931 0.03764140636927981 {'criterion': 'gini', 'max_depth': 4, 'max_features': 'sqrt', 'min_samples_leaf': 4, 'min_samples_split': 5}
# means -> %f stds-> (%f) params with: %r 0.7917938931297709 0.017458442502541076 {'criterion': 'gini', 'max_depth': 4, 'max_features': 'sqrt', 'min_samples_leaf': 4, 'min_samples_split': 10}
# means -> %f stds-> (%f) params with: %r 0.7780534351145039 0.02099323384744943 {'criterion': 'gini', 'max_depth': 4, 'max_features': 'log2', 'min_samples_leaf': 1, 'min_samples_split': 2}
# means -> %f stds-> (%f) params with: %r 0.7742366412213741 0.026745487037261494 {'criterion': 'gini', 'max_depth': 4, 'max_features': 'log2', 'min_samples_leaf': 1, 'min_samples_split': 5}
# means -> %f stds-> (%f) params with: %r 0.7658396946564886 0.03621984568723522 {'criterion': 'gini', 'max_depth': 4, 'max_features': 'log2', 'min_samples_leaf': 1, 'min_samples_split': 10}
# means -> %f stds-> (%f) params with: %r 0.7832061068702292 0.019353064632194227 {'criterion': 'gini', 'max_depth': 4, 'max_features': 'log2', 'min_samples_leaf': 2, 'min_samples_split': 2}
# means -> %f stds-> (%f) params with: %r 0.7706106870229009 0.026468302973413457 {'criterion': 'gini', 'max_depth': 4, 'max_features': 'log2', 'min_samples_leaf': 2, 'min_samples_split': 5}
# means -> %f stds-> (%f) params with: %r 0.7751908396946565 0.036617358641867034 {'criterion': 'gini', 'max_depth': 4, 'max_features': 'log2', 'min_samples_leaf': 2, 'min_samples_split': 10}
# means -> %f stds-> (%f) params with: %r 0.7795801526717557 0.029158531779324932 {'criterion': 'gini', 'max_depth': 4, 'max_features': 'log2', 'min_samples_leaf': 4, 'min_samples_split': 2}
# means -> %f stds-> (%f) params with: %r 0.7677480916030535 0.034846408522765916 {'criterion': 'gini', 'max_depth': 4, 'max_features': 'log2', 'min_samples_leaf': 4, 'min_samples_split': 5}
# means -> %f stds-> (%f) params with: %r 0.7736641221374045 0.032276177688420074 {'criterion': 'gini', 'max_depth': 4, 'max_features': 'log2', 'min_samples_leaf': 4, 'min_samples_split': 10}
# means -> %f stds-> (%f) params with: %r nan nan {'criterion': 'gini', 'max_depth': 6, 'max_features': 'auto', 'min_samples_leaf': 1, 'min_samples_split': 2}
# means -> %f stds-> (%f) params with: %r nan nan {'criterion': 'gini', 'max_depth': 6, 'max_features': 'auto', 'min_samples_leaf': 1, 'min_samples_split': 5}
# means -> %f stds-> (%f) params with: %r nan nan {'criterion': 'gini', 'max_depth': 6, 'max_features': 'auto', 'min_samples_leaf': 1, 'min_samples_split': 10}
# means -> %f stds-> (%f) params with: %r nan nan {'criterion': 'gini', 'max_depth': 6, 'max_features': 'auto', 'min_samples_leaf': 2, 'min_samples_split': 2}
# means -> %f stds-> (%f) params with: %r nan nan {'criterion': 'gini', 'max_depth': 6, 'max_features': 'auto', 'min_samples_leaf': 2, 'min_samples_split': 5}
# means -> %f stds-> (%f) params with: %r nan nan {'criterion': 'gini', 'max_depth': 6, 'max_features': 'auto', 'min_samples_leaf': 2, 'min_samples_split': 10}
# means -> %f stds-> (%f) params with: %r nan nan {'criterion': 'gini', 'max_depth': 6, 'max_features': 'auto', 'min_samples_leaf': 4, 'min_samples_split': 2}
# means -> %f stds-> (%f) params with: %r nan nan {'criterion': 'gini', 'max_depth': 6, 'max_features': 'auto', 'min_samples_leaf': 4, 'min_samples_split': 5}
# means -> %f stds-> (%f) params with: %r nan nan {'criterion': 'gini', 'max_depth': 6, 'max_features': 'auto', 'min_samples_leaf': 4, 'min_samples_split': 10}
# means -> %f stds-> (%f) params with: %r 0.8043893129770993 0.034321976589863495 {'criterion': 'gini', 'max_depth': 6, 'max_features': 'sqrt', 'min_samples_leaf': 1, 'min_samples_split': 2}
# means -> %f stds-> (%f) params with: %r 0.8085877862595419 0.03383895074803575 {'criterion': 'gini', 'max_depth': 6, 'max_features': 'sqrt', 'min_samples_leaf': 1, 'min_samples_split': 5}
# means -> %f stds-> (%f) params with: %r 0.793702290076336 0.025367326481928368 {'criterion': 'gini', 'max_depth': 6, 'max_features': 'sqrt', 'min_samples_leaf': 1, 'min_samples_split': 10}
# means -> %f stds-> (%f) params with: %r 0.8064885496183207 0.017369557638141606 {'criterion': 'gini', 'max_depth': 6, 'max_features': 'sqrt', 'min_samples_leaf': 2, 'min_samples_split': 2}
# means -> %f stds-> (%f) params with: %r 0.8145038167938932 0.022203113850761822 {'criterion': 'gini', 'max_depth': 6, 'max_features': 'sqrt', 'min_samples_leaf': 2, 'min_samples_split': 5}
# means -> %f stds-> (%f) params with: %r 0.8179389312977099 0.021829258347830234 {'criterion': 'gini', 'max_depth': 6, 'max_features': 'sqrt', 'min_samples_leaf': 2, 'min_samples_split': 10}
# means -> %f stds-> (%f) params with: %r 0.8124045801526718 0.013028915411220067 {'criterion': 'gini', 'max_depth': 6, 'max_features': 'sqrt', 'min_samples_leaf': 4, 'min_samples_split': 2}
# means -> %f stds-> (%f) params with: %r 0.8036259541984734 0.029459245635781093 {'criterion': 'gini', 'max_depth': 6, 'max_features': 'sqrt', 'min_samples_leaf': 4, 'min_samples_split': 5}
# means -> %f stds-> (%f) params with: %r 0.8061068702290075 0.02429292616941919 {'criterion': 'gini', 'max_depth': 6, 'max_features': 'sqrt', 'min_samples_leaf': 4, 'min_samples_split': 10}
# means -> %f stds-> (%f) params with: %r 0.8150763358778625 0.023395576712946578 {'criterion': 'gini', 'max_depth': 6, 'max_features': 'log2', 'min_samples_leaf': 1, 'min_samples_split': 2}
# means -> %f stds-> (%f) params with: %r 0.799618320610687 0.02770792582119319 {'criterion': 'gini', 'max_depth': 6, 'max_features': 'log2', 'min_samples_leaf': 1, 'min_samples_split': 5}
# means -> %f stds-> (%f) params with: %r 0.8041984732824426 0.01914494076944192 {'criterion': 'gini', 'max_depth': 6, 'max_features': 'log2', 'min_samples_leaf': 1, 'min_samples_split': 10}
# means -> %f stds-> (%f) params with: %r 0.8040076335877864 0.022419400276766664 {'criterion': 'gini', 'max_depth': 6, 'max_features': 'log2', 'min_samples_leaf': 2, 'min_samples_split': 2}
# means -> %f stds-> (%f) params with: %r 0.799618320610687 0.03203606804235618 {'criterion': 'gini', 'max_depth': 6, 'max_features': 'log2', 'min_samples_leaf': 2, 'min_samples_split': 5}
# means -> %f stds-> (%f) params with: %r 0.8133587786259542 0.018060333075299206 {'criterion': 'gini', 'max_depth': 6, 'max_features': 'log2', 'min_samples_leaf': 2, 'min_samples_split': 10}
# means -> %f stds-> (%f) params with: %r 0.8194656488549619 0.022967460127221964 {'criterion': 'gini', 'max_depth': 6, 'max_features': 'log2', 'min_samples_leaf': 4, 'min_samples_split': 2}
# means -> %f stds-> (%f) params with: %r 0.8045801526717558 0.03080982606200086 {'criterion': 'gini', 'max_depth': 6, 'max_features': 'log2', 'min_samples_leaf': 4, 'min_samples_split': 5}
# means -> %f stds-> (%f) params with: %r 0.8074427480916029 0.021514160432610365 {'criterion': 'gini', 'max_depth': 6, 'max_features': 'log2', 'min_samples_leaf': 4, 'min_samples_split': 10}
# means -> %f stds-> (%f) params with: %r nan nan {'criterion': 'gini', 'max_depth': 8, 'max_features': 'auto', 'min_samples_leaf': 1, 'min_samples_split': 2}
# means -> %f stds-> (%f) params with: %r nan nan {'criterion': 'gini', 'max_depth': 8, 'max_features': 'auto', 'min_samples_leaf': 1, 'min_samples_split': 5}
# means -> %f stds-> (%f) params with: %r nan nan {'criterion': 'gini', 'max_depth': 8, 'max_features': 'auto', 'min_samples_leaf': 1, 'min_samples_split': 10}
# means -> %f stds-> (%f) params with: %r nan nan {'criterion': 'gini', 'max_depth': 8, 'max_features': 'auto', 'min_samples_leaf': 2, 'min_samples_split': 2}
# means -> %f stds-> (%f) params with: %r nan nan {'criterion': 'gini', 'max_depth': 8, 'max_features': 'auto', 'min_samples_leaf': 2, 'min_samples_split': 5}
# means -> %f stds-> (%f) params with: %r nan nan {'criterion': 'gini', 'max_depth': 8, 'max_features': 'auto', 'min_samples_leaf': 2, 'min_samples_split': 10}
# means -> %f stds-> (%f) params with: %r nan nan {'criterion': 'gini', 'max_depth': 8, 'max_features': 'auto', 'min_samples_leaf': 4, 'min_samples_split': 2}
# means -> %f stds-> (%f) params with: %r nan nan {'criterion': 'gini', 'max_depth': 8, 'max_features': 'auto', 'min_samples_leaf': 4, 'min_samples_split': 5}
# means -> %f stds-> (%f) params with: %r nan nan {'criterion': 'gini', 'max_depth': 8, 'max_features': 'auto', 'min_samples_leaf': 4, 'min_samples_split': 10}
# means -> %f stds-> (%f) params with: %r 0.8375954198473282 0.01892009795527345 {'criterion': 'gini', 'max_depth': 8, 'max_features': 'sqrt', 'min_samples_leaf': 1, 'min_samples_split': 2}
# means -> %f stds-> (%f) params with: %r 0.8444656488549619 0.025148153748685842 {'criterion': 'gini', 'max_depth': 8, 'max_features': 'sqrt', 'min_samples_leaf': 1, 'min_samples_split': 5}
# means -> %f stds-> (%f) params with: %r 0.8374045801526717 0.026918546080160987 {'criterion': 'gini', 'max_depth': 8, 'max_features': 'sqrt', 'min_samples_leaf': 1, 'min_samples_split': 10}
# means -> %f stds-> (%f) params with: %r 0.8454198473282443 0.02048306544274617 {'criterion': 'gini', 'max_depth': 8, 'max_features': 'sqrt', 'min_samples_leaf': 2, 'min_samples_split': 2}
# means -> %f stds-> (%f) params with: %r 0.8492366412213741 0.026360758244018335 {'criterion': 'gini', 'max_depth': 8, 'max_features': 'sqrt', 'min_samples_leaf': 2, 'min_samples_split': 5}
# means -> %f stds-> (%f) params with: %r 0.8389312977099237 0.024797413543176758 {'criterion': 'gini', 'max_depth': 8, 'max_features': 'sqrt', 'min_samples_leaf': 2, 'min_samples_split': 10}
# means -> %f stds-> (%f) params with: %r 0.833206106870229 0.03084526818353413 {'criterion': 'gini', 'max_depth': 8, 'max_features': 'sqrt', 'min_samples_leaf': 4, 'min_samples_split': 2}
# means -> %f stds-> (%f) params with: %r 0.8391221374045802 0.02179335837100108 {'criterion': 'gini', 'max_depth': 8, 'max_features': 'sqrt', 'min_samples_leaf': 4, 'min_samples_split': 5}
# means -> %f stds-> (%f) params with: %r 0.8337786259541986 0.021000172039441697 {'criterion': 'gini', 'max_depth': 8, 'max_features': 'sqrt', 'min_samples_leaf': 4, 'min_samples_split': 10}
# means -> %f stds-> (%f) params with: %r 0.8333969465648854 0.022805942372922137 {'criterion': 'gini', 'max_depth': 8, 'max_features': 'log2', 'min_samples_leaf': 1, 'min_samples_split': 2}
# means -> %f stds-> (%f) params with: %r 0.8471374045801527 0.024698077797850774 {'criterion': 'gini', 'max_depth': 8, 'max_features': 'log2', 'min_samples_leaf': 1, 'min_samples_split': 5}
# means -> %f stds-> (%f) params with: %r 0.8400763358778626 0.020156864009940302 {'criterion': 'gini', 'max_depth': 8, 'max_features': 'log2', 'min_samples_leaf': 1, 'min_samples_split': 10}
# means -> %f stds-> (%f) params with: %r 0.8360687022900762 0.01426710205463029 {'criterion': 'gini', 'max_depth': 8, 'max_features': 'log2', 'min_samples_leaf': 2, 'min_samples_split': 2}
# means -> %f stds-> (%f) params with: %r 0.8419847328244275 0.021418302055875114 {'criterion': 'gini', 'max_depth': 8, 'max_features': 'log2', 'min_samples_leaf': 2, 'min_samples_split': 5}
# means -> %f stds-> (%f) params with: %r 0.832442748091603 0.023633321496813315 {'criterion': 'gini', 'max_depth': 8, 'max_features': 'log2', 'min_samples_leaf': 2, 'min_samples_split': 10}
# means -> %f stds-> (%f) params with: %r 0.8333969465648856 0.02212506236622884 {'criterion': 'gini', 'max_depth': 8, 'max_features': 'log2', 'min_samples_leaf': 4, 'min_samples_split': 2}
# means -> %f stds-> (%f) params with: %r 0.8314885496183206 0.016351075544574017 {'criterion': 'gini', 'max_depth': 8, 'max_features': 'log2', 'min_samples_leaf': 4, 'min_samples_split': 5}
# means -> %f stds-> (%f) params with: %r 0.832824427480916 0.03004376893764036 {'criterion': 'gini', 'max_depth': 8, 'max_features': 'log2', 'min_samples_leaf': 4, 'min_samples_split': 10}
# means -> %f stds-> (%f) params with: %r nan nan {'criterion': 'gini', 'max_depth': 10, 'max_features': 'auto', 'min_samples_leaf': 1, 'min_samples_split': 2}
# means -> %f stds-> (%f) params with: %r nan nan {'criterion': 'gini', 'max_depth': 10, 'max_features': 'auto', 'min_samples_leaf': 1, 'min_samples_split': 5}
# means -> %f stds-> (%f) params with: %r nan nan {'criterion': 'gini', 'max_depth': 10, 'max_features': 'auto', 'min_samples_leaf': 1, 'min_samples_split': 10}
# means -> %f stds-> (%f) params with: %r nan nan {'criterion': 'gini', 'max_depth': 10, 'max_features': 'auto', 'min_samples_leaf': 2, 'min_samples_split': 2}
# means -> %f stds-> (%f) params with: %r nan nan {'criterion': 'gini', 'max_depth': 10, 'max_features': 'auto', 'min_samples_leaf': 2, 'min_samples_split': 5}
# means -> %f stds-> (%f) params with: %r nan nan {'criterion': 'gini', 'max_depth': 10, 'max_features': 'auto', 'min_samples_leaf': 2, 'min_samples_split': 10}
# means -> %f stds-> (%f) params with: %r nan nan {'criterion': 'gini', 'max_depth': 10, 'max_features': 'auto', 'min_samples_leaf': 4, 'min_samples_split': 2}
# means -> %f stds-> (%f) params with: %r nan nan {'criterion': 'gini', 'max_depth': 10, 'max_features': 'auto', 'min_samples_leaf': 4, 'min_samples_split': 5}
# means -> %f stds-> (%f) params with: %r nan nan {'criterion': 'gini', 'max_depth': 10, 'max_features': 'auto', 'min_samples_leaf': 4, 'min_samples_split': 10}
# means -> %f stds-> (%f) params with: %r 0.86412213740458 0.02114448699918249 {'criterion': 'gini', 'max_depth': 10, 'max_features': 'sqrt', 'min_samples_leaf': 1, 'min_samples_split': 2}
# means -> %f stds-> (%f) params with: %r 0.8721374045801525 0.019648149124020988 {'criterion': 'gini', 'max_depth': 10, 'max_features': 'sqrt', 'min_samples_leaf': 1, 'min_samples_split': 5}
# means -> %f stds-> (%f) params with: %r 0.8708015267175574 0.021062512919835137 {'criterion': 'gini', 'max_depth': 10, 'max_features': 'sqrt', 'min_samples_leaf': 1, 'min_samples_split': 10}
# means -> %f stds-> (%f) params with: %r 0.8639312977099237 0.02421559463651518 {'criterion': 'gini', 'max_depth': 10, 'max_features': 'sqrt', 'min_samples_leaf': 2, 'min_samples_split': 2}
# means -> %f stds-> (%f) params with: %r 0.8620229007633586 0.025957706318852976 {'criterion': 'gini', 'max_depth': 10, 'max_features': 'sqrt', 'min_samples_leaf': 2, 'min_samples_split': 5}
# means -> %f stds-> (%f) params with: %r 0.8570610687022902 0.02411612762125284 {'criterion': 'gini', 'max_depth': 10, 'max_features': 'sqrt', 'min_samples_leaf': 2, 'min_samples_split': 10}
# means -> %f stds-> (%f) params with: %r 0.8517175572519082 0.029528395991039274 {'criterion': 'gini', 'max_depth': 10, 'max_features': 'sqrt', 'min_samples_leaf': 4, 'min_samples_split': 2}
# means -> %f stds-> (%f) params with: %r 0.857824427480916 0.03027381693161401 {'criterion': 'gini', 'max_depth': 10, 'max_features': 'sqrt', 'min_samples_leaf': 4, 'min_samples_split': 5}
# means -> %f stds-> (%f) params with: %r 0.8614503816793894 0.018447398432968793 {'criterion': 'gini', 'max_depth': 10, 'max_features': 'sqrt', 'min_samples_leaf': 4, 'min_samples_split': 10}
# means -> %f stds-> (%f) params with: %r 0.8721374045801527 0.02028653781056229 {'criterion': 'gini', 'max_depth': 10, 'max_features': 'log2', 'min_samples_leaf': 1, 'min_samples_split': 2}
# means -> %f stds-> (%f) params with: %r 0.8551526717557252 0.02805343511450382 {'criterion': 'gini', 'max_depth': 10, 'max_features': 'log2', 'min_samples_leaf': 1, 'min_samples_split': 5}
# means -> %f stds-> (%f) params with: %r 0.8561068702290076 0.018248905477682306 {'criterion': 'gini', 'max_depth': 10, 'max_features': 'log2', 'min_samples_leaf': 1, 'min_samples_split': 10}
# means -> %f stds-> (%f) params with: %r 0.8709923664122139 0.015625564496533375 {'criterion': 'gini', 'max_depth': 10, 'max_features': 'log2', 'min_samples_leaf': 2, 'min_samples_split': 2}
# means -> %f stds-> (%f) params with: %r 0.8633587786259541 0.02933225352189442 {'criterion': 'gini', 'max_depth': 10, 'max_features': 'log2', 'min_samples_leaf': 2, 'min_samples_split': 5}
# means -> %f stds-> (%f) params with: %r 0.857442748091603 0.027378014511164055 {'criterion': 'gini', 'max_depth': 10, 'max_features': 'log2', 'min_samples_leaf': 2, 'min_samples_split': 10}
# means -> %f stds-> (%f) params with: %r 0.8635496183206106 0.016576709819258746 {'criterion': 'gini', 'max_depth': 10, 'max_features': 'log2', 'min_samples_leaf': 4, 'min_samples_split': 2}
# means -> %f stds-> (%f) params with: %r 0.8547709923664122 0.03175574812829471 {'criterion': 'gini', 'max_depth': 10, 'max_features': 'log2', 'min_samples_leaf': 4, 'min_samples_split': 5}
# means -> %f stds-> (%f) params with: %r 0.8555343511450383 0.0269354528047361 {'criterion': 'gini', 'max_depth': 10, 'max_features': 'log2', 'min_samples_leaf': 4, 'min_samples_split': 10}
# means -> %f stds-> (%f) params with: %r nan nan {'criterion': 'entropy', 'max_depth': 2, 'max_features': 'auto', 'min_samples_leaf': 1, 'min_samples_split': 2}
# means -> %f stds-> (%f) params with: %r nan nan {'criterion': 'entropy', 'max_depth': 2, 'max_features': 'auto', 'min_samples_leaf': 1, 'min_samples_split': 5}
# means -> %f stds-> (%f) params with: %r nan nan {'criterion': 'entropy', 'max_depth': 2, 'max_features': 'auto', 'min_samples_leaf': 1, 'min_samples_split': 10}
# means -> %f stds-> (%f) params with: %r nan nan {'criterion': 'entropy', 'max_depth': 2, 'max_features': 'auto', 'min_samples_leaf': 2, 'min_samples_split': 2}
# means -> %f stds-> (%f) params with: %r nan nan {'criterion': 'entropy', 'max_depth': 2, 'max_features': 'auto', 'min_samples_leaf': 2, 'min_samples_split': 5}
# means -> %f stds-> (%f) params with: %r nan nan {'criterion': 'entropy', 'max_depth': 2, 'max_features': 'auto', 'min_samples_leaf': 2, 'min_samples_split': 10}
# means -> %f stds-> (%f) params with: %r nan nan {'criterion': 'entropy', 'max_depth': 2, 'max_features': 'auto', 'min_samples_leaf': 4, 'min_samples_split': 2}
# means -> %f stds-> (%f) params with: %r nan nan {'criterion': 'entropy', 'max_depth': 2, 'max_features': 'auto', 'min_samples_leaf': 4, 'min_samples_split': 5}
# means -> %f stds-> (%f) params with: %r nan nan {'criterion': 'entropy', 'max_depth': 2, 'max_features': 'auto', 'min_samples_leaf': 4, 'min_samples_split': 10}
# means -> %f stds-> (%f) params with: %r 0.7114503816793893 0.0608105229516166 {'criterion': 'entropy', 'max_depth': 2, 'max_features': 'sqrt', 'min_samples_leaf': 1, 'min_samples_split': 2}
# means -> %f stds-> (%f) params with: %r 0.6671755725190839 0.05438897816958689 {'criterion': 'entropy', 'max_depth': 2, 'max_features': 'sqrt', 'min_samples_leaf': 1, 'min_samples_split': 5}
# means -> %f stds-> (%f) params with: %r 0.7471374045801527 0.051880675691693495 {'criterion': 'entropy', 'max_depth': 2, 'max_features': 'sqrt', 'min_samples_leaf': 1, 'min_samples_split': 10}
# means -> %f stds-> (%f) params with: %r 0.7305343511450382 0.05487960345905468 {'criterion': 'entropy', 'max_depth': 2, 'max_features': 'sqrt', 'min_samples_leaf': 2, 'min_samples_split': 2}
# means -> %f stds-> (%f) params with: %r 0.6958015267175572 0.05058656005572689 {'criterion': 'entropy', 'max_depth': 2, 'max_features': 'sqrt', 'min_samples_leaf': 2, 'min_samples_split': 5}
# means -> %f stds-> (%f) params with: %r 0.7120229007633587 0.05379818042032183 {'criterion': 'entropy', 'max_depth': 2, 'max_features': 'sqrt', 'min_samples_leaf': 2, 'min_samples_split': 10}
# means -> %f stds-> (%f) params with: %r 0.6841603053435115 0.06288595069416486 {'criterion': 'entropy', 'max_depth': 2, 'max_features': 'sqrt', 'min_samples_leaf': 4, 'min_samples_split': 2}
# means -> %f stds-> (%f) params with: %r 0.7358778625954199 0.046481905791314726 {'criterion': 'entropy', 'max_depth': 2, 'max_features': 'sqrt', 'min_samples_leaf': 4, 'min_samples_split': 5}
# means -> %f stds-> (%f) params with: %r 0.7095419847328244 0.06182027971824026 {'criterion': 'entropy', 'max_depth': 2, 'max_features': 'sqrt', 'min_samples_leaf': 4, 'min_samples_split': 10}
# means -> %f stds-> (%f) params with: %r 0.7219465648854962 0.06660305343511452 {'criterion': 'entropy', 'max_depth': 2, 'max_features': 'log2', 'min_samples_leaf': 1, 'min_samples_split': 2}
# means -> %f stds-> (%f) params with: %r 0.6608778625954199 0.03974829391387226 {'criterion': 'entropy', 'max_depth': 2, 'max_features': 'log2', 'min_samples_leaf': 1, 'min_samples_split': 5}
# means -> %f stds-> (%f) params with: %r 0.6984732824427481 0.06088354564394959 {'criterion': 'entropy', 'max_depth': 2, 'max_features': 'log2', 'min_samples_leaf': 1, 'min_samples_split': 10}
# means -> %f stds-> (%f) params with: %r 0.726145038167939 0.06084315457515544 {'criterion': 'entropy', 'max_depth': 2, 'max_features': 'log2', 'min_samples_leaf': 2, 'min_samples_split': 2}
# means -> %f stds-> (%f) params with: %r 0.683969465648855 0.05605751581151368 {'criterion': 'entropy', 'max_depth': 2, 'max_features': 'log2', 'min_samples_leaf': 2, 'min_samples_split': 5}
# means -> %f stds-> (%f) params with: %r 0.7053435114503815 0.051499851633344654 {'criterion': 'entropy', 'max_depth': 2, 'max_features': 'log2', 'min_samples_leaf': 2, 'min_samples_split': 10}
# means -> %f stds-> (%f) params with: %r 0.7040076335877862 0.055844338272792185 {'criterion': 'entropy', 'max_depth': 2, 'max_features': 'log2', 'min_samples_leaf': 4, 'min_samples_split': 2}
# means -> %f stds-> (%f) params with: %r 0.6967557251908396 0.055510737090119146 {'criterion': 'entropy', 'max_depth': 2, 'max_features': 'log2', 'min_samples_leaf': 4, 'min_samples_split': 5}
# means -> %f stds-> (%f) params with: %r 0.7127862595419847 0.05573858722170585 {'criterion': 'entropy', 'max_depth': 2, 'max_features': 'log2', 'min_samples_leaf': 4, 'min_samples_split': 10}
# means -> %f stds-> (%f) params with: %r nan nan {'criterion': 'entropy', 'max_depth': 4, 'max_features': 'auto', 'min_samples_leaf': 1, 'min_samples_split': 2}
# means -> %f stds-> (%f) params with: %r nan nan {'criterion': 'entropy', 'max_depth': 4, 'max_features': 'auto', 'min_samples_leaf': 1, 'min_samples_split': 5}
# means -> %f stds-> (%f) params with: %r nan nan {'criterion': 'entropy', 'max_depth': 4, 'max_features': 'auto', 'min_samples_leaf': 1, 'min_samples_split': 10}
# means -> %f stds-> (%f) params with: %r nan nan {'criterion': 'entropy', 'max_depth': 4, 'max_features': 'auto', 'min_samples_leaf': 2, 'min_samples_split': 2}
# means -> %f stds-> (%f) params with: %r nan nan {'criterion': 'entropy', 'max_depth': 4, 'max_features': 'auto', 'min_samples_leaf': 2, 'min_samples_split': 5}
# means -> %f stds-> (%f) params with: %r nan nan {'criterion': 'entropy', 'max_depth': 4, 'max_features': 'auto', 'min_samples_leaf': 2, 'min_samples_split': 10}
# means -> %f stds-> (%f) params with: %r nan nan {'criterion': 'entropy', 'max_depth': 4, 'max_features': 'auto', 'min_samples_leaf': 4, 'min_samples_split': 2}
# means -> %f stds-> (%f) params with: %r nan nan {'criterion': 'entropy', 'max_depth': 4, 'max_features': 'auto', 'min_samples_leaf': 4, 'min_samples_split': 5}
# means -> %f stds-> (%f) params with: %r nan nan {'criterion': 'entropy', 'max_depth': 4, 'max_features': 'auto', 'min_samples_leaf': 4, 'min_samples_split': 10}
# means -> %f stds-> (%f) params with: %r 0.7715648854961832 0.02834531648045672 {'criterion': 'entropy', 'max_depth': 4, 'max_features': 'sqrt', 'min_samples_leaf': 1, 'min_samples_split': 2}
# means -> %f stds-> (%f) params with: %r 0.7696564885496182 0.044331120415371954 {'criterion': 'entropy', 'max_depth': 4, 'max_features': 'sqrt', 'min_samples_leaf': 1, 'min_samples_split': 5}
# means -> %f stds-> (%f) params with: %r 0.7797709923664122 0.023219788052297918 {'criterion': 'entropy', 'max_depth': 4, 'max_features': 'sqrt', 'min_samples_leaf': 1, 'min_samples_split': 10}
# means -> %f stds-> (%f) params with: %r 0.7784351145038167 0.018233931399934983 {'criterion': 'entropy', 'max_depth': 4, 'max_features': 'sqrt', 'min_samples_leaf': 2, 'min_samples_split': 2}
# means -> %f stds-> (%f) params with: %r 0.7561068702290077 0.032608467631827814 {'criterion': 'entropy', 'max_depth': 4, 'max_features': 'sqrt', 'min_samples_leaf': 2, 'min_samples_split': 5}
# means -> %f stds-> (%f) params with: %r 0.7767175572519084 0.03607829348628108 {'criterion': 'entropy', 'max_depth': 4, 'max_features': 'sqrt', 'min_samples_leaf': 2, 'min_samples_split': 10}
# means -> %f stds-> (%f) params with: %r 0.7532442748091602 0.042673479734117586 {'criterion': 'entropy', 'max_depth': 4, 'max_features': 'sqrt', 'min_samples_leaf': 4, 'min_samples_split': 2}
# means -> %f stds-> (%f) params with: %r 0.742557251908397 0.04228251441197109 {'criterion': 'entropy', 'max_depth': 4, 'max_features': 'sqrt', 'min_samples_leaf': 4, 'min_samples_split': 5}
# means -> %f stds-> (%f) params with: %r 0.7652671755725191 0.03197917567275329 {'criterion': 'entropy', 'max_depth': 4, 'max_features': 'sqrt', 'min_samples_leaf': 4, 'min_samples_split': 10}
# means -> %f stds-> (%f) params with: %r 0.7301526717557253 0.06902067869672915 {'criterion': 'entropy', 'max_depth': 4, 'max_features': 'log2', 'min_samples_leaf': 1, 'min_samples_split': 2}
# means -> %f stds-> (%f) params with: %r 0.7564885496183207 0.03350527686619045 {'criterion': 'entropy', 'max_depth': 4, 'max_features': 'log2', 'min_samples_leaf': 1, 'min_samples_split': 5}
# means -> %f stds-> (%f) params with: %r 0.7666030534351146 0.0388493562146634 {'criterion': 'entropy', 'max_depth': 4, 'max_features': 'log2', 'min_samples_leaf': 1, 'min_samples_split': 10}
# means -> %f stds-> (%f) params with: %r 0.773091603053435 0.03140980206486098 {'criterion': 'entropy', 'max_depth': 4, 'max_features': 'log2', 'min_samples_leaf': 2, 'min_samples_split': 2}
# means -> %f stds-> (%f) params with: %r 0.7604961832061069 0.04025993929408205 {'criterion': 'entropy', 'max_depth': 4, 'max_features': 'log2', 'min_samples_leaf': 2, 'min_samples_split': 5}
# means -> %f stds-> (%f) params with: %r 0.7713740458015266 0.036056078407998605 {'criterion': 'entropy', 'max_depth': 4, 'max_features': 'log2', 'min_samples_leaf': 2, 'min_samples_split': 10}
# means -> %f stds-> (%f) params with: %r 0.767557251908397 0.03254138575121183 {'criterion': 'entropy', 'max_depth': 4, 'max_features': 'log2', 'min_samples_leaf': 4, 'min_samples_split': 2}
# means -> %f stds-> (%f) params with: %r 0.7795801526717556 0.02274517758885923 {'criterion': 'entropy', 'max_depth': 4, 'max_features': 'log2', 'min_samples_leaf': 4, 'min_samples_split': 5}
# means -> %f stds-> (%f) params with: %r 0.773854961832061 0.036591987438033866 {'criterion': 'entropy', 'max_depth': 4, 'max_features': 'log2', 'min_samples_leaf': 4, 'min_samples_split': 10}
# means -> %f stds-> (%f) params with: %r nan nan {'criterion': 'entropy', 'max_depth': 6, 'max_features': 'auto', 'min_samples_leaf': 1, 'min_samples_split': 2}
# means -> %f stds-> (%f) params with: %r nan nan {'criterion': 'entropy', 'max_depth': 6, 'max_features': 'auto', 'min_samples_leaf': 1, 'min_samples_split': 5}
# means -> %f stds-> (%f) params with: %r nan nan {'criterion': 'entropy', 'max_depth': 6, 'max_features': 'auto', 'min_samples_leaf': 1, 'min_samples_split': 10}
# means -> %f stds-> (%f) params with: %r nan nan {'criterion': 'entropy', 'max_depth': 6, 'max_features': 'auto', 'min_samples_leaf': 2, 'min_samples_split': 2}
# means -> %f stds-> (%f) params with: %r nan nan {'criterion': 'entropy', 'max_depth': 6, 'max_features': 'auto', 'min_samples_leaf': 2, 'min_samples_split': 5}
# means -> %f stds-> (%f) params with: %r nan nan {'criterion': 'entropy', 'max_depth': 6, 'max_features': 'auto', 'min_samples_leaf': 2, 'min_samples_split': 10}
# means -> %f stds-> (%f) params with: %r nan nan {'criterion': 'entropy', 'max_depth': 6, 'max_features': 'auto', 'min_samples_leaf': 4, 'min_samples_split': 2}
# means -> %f stds-> (%f) params with: %r nan nan {'criterion': 'entropy', 'max_depth': 6, 'max_features': 'auto', 'min_samples_leaf': 4, 'min_samples_split': 5}
# means -> %f stds-> (%f) params with: %r nan nan {'criterion': 'entropy', 'max_depth': 6, 'max_features': 'auto', 'min_samples_leaf': 4, 'min_samples_split': 10}
# means -> %f stds-> (%f) params with: %r 0.7982824427480916 0.021422552646731596 {'criterion': 'entropy', 'max_depth': 6, 'max_features': 'sqrt', 'min_samples_leaf': 1, 'min_samples_split': 2}
# means -> %f stds-> (%f) params with: %r 0.8083969465648855 0.021912519228102768 {'criterion': 'entropy', 'max_depth': 6, 'max_features': 'sqrt', 'min_samples_leaf': 1, 'min_samples_split': 5}
# means -> %f stds-> (%f) params with: %r 0.7912213740458015 0.026460045820514515 {'criterion': 'entropy', 'max_depth': 6, 'max_features': 'sqrt', 'min_samples_leaf': 1, 'min_samples_split': 10}
# means -> %f stds-> (%f) params with: %r 0.8055343511450381 0.01880424771030079 {'criterion': 'entropy', 'max_depth': 6, 'max_features': 'sqrt', 'min_samples_leaf': 2, 'min_samples_split': 2}
# means -> %f stds-> (%f) params with: %r 0.8089694656488551 0.029766710398658067 {'criterion': 'entropy', 'max_depth': 6, 'max_features': 'sqrt', 'min_samples_leaf': 2, 'min_samples_split': 5}
# means -> %f stds-> (%f) params with: %r 0.8083969465648855 0.025563972594870765 {'criterion': 'entropy', 'max_depth': 6, 'max_features': 'sqrt', 'min_samples_leaf': 2, 'min_samples_split': 10}
# means -> %f stds-> (%f) params with: %r 0.8001908396946564 0.02802226029157818 {'criterion': 'entropy', 'max_depth': 6, 'max_features': 'sqrt', 'min_samples_leaf': 4, 'min_samples_split': 2}
# means -> %f stds-> (%f) params with: %r 0.7975190839694657 0.02553902899905014 {'criterion': 'entropy', 'max_depth': 6, 'max_features': 'sqrt', 'min_samples_leaf': 4, 'min_samples_split': 5}
# means -> %f stds-> (%f) params with: %r 0.8064885496183207 0.036770208714889584 {'criterion': 'entropy', 'max_depth': 6, 'max_features': 'sqrt', 'min_samples_leaf': 4, 'min_samples_split': 10}
# means -> %f stds-> (%f) params with: %r 0.8017175572519084 0.03563595971226187 {'criterion': 'entropy', 'max_depth': 6, 'max_features': 'log2', 'min_samples_leaf': 1, 'min_samples_split': 2}
# means -> %f stds-> (%f) params with: %r 0.807824427480916 0.02162559851832007 {'criterion': 'entropy', 'max_depth': 6, 'max_features': 'log2', 'min_samples_leaf': 1, 'min_samples_split': 5}
# means -> %f stds-> (%f) params with: %r 0.7975190839694657 0.025223348212111484 {'criterion': 'entropy', 'max_depth': 6, 'max_features': 'log2', 'min_samples_leaf': 1, 'min_samples_split': 10}
# means -> %f stds-> (%f) params with: %r 0.8047709923664123 0.02363717377177358 {'criterion': 'entropy', 'max_depth': 6, 'max_features': 'log2', 'min_samples_leaf': 2, 'min_samples_split': 2}
# means -> %f stds-> (%f) params with: %r 0.8066793893129771 0.027550405146353492 {'criterion': 'entropy', 'max_depth': 6, 'max_features': 'log2', 'min_samples_leaf': 2, 'min_samples_split': 5}
# means -> %f stds-> (%f) params with: %r 0.7961832061068702 0.031064106792940173 {'criterion': 'entropy', 'max_depth': 6, 'max_features': 'log2', 'min_samples_leaf': 2, 'min_samples_split': 10}
# means -> %f stds-> (%f) params with: %r 0.8026717557251908 0.02293572395049405 {'criterion': 'entropy', 'max_depth': 6, 'max_features': 'log2', 'min_samples_leaf': 4, 'min_samples_split': 2}
# means -> %f stds-> (%f) params with: %r 0.8022900763358779 0.014811914436589501 {'criterion': 'entropy', 'max_depth': 6, 'max_features': 'log2', 'min_samples_leaf': 4, 'min_samples_split': 5}
# means -> %f stds-> (%f) params with: %r 0.8024809160305344 0.026364211995522715 {'criterion': 'entropy', 'max_depth': 6, 'max_features': 'log2', 'min_samples_leaf': 4, 'min_samples_split': 10}
# means -> %f stds-> (%f) params with: %r nan nan {'criterion': 'entropy', 'max_depth': 8, 'max_features': 'auto', 'min_samples_leaf': 1, 'min_samples_split': 2}
# means -> %f stds-> (%f) params with: %r nan nan {'criterion': 'entropy', 'max_depth': 8, 'max_features': 'auto', 'min_samples_leaf': 1, 'min_samples_split': 5}
# means -> %f stds-> (%f) params with: %r nan nan {'criterion': 'entropy', 'max_depth': 8, 'max_features': 'auto', 'min_samples_leaf': 1, 'min_samples_split': 10}
# means -> %f stds-> (%f) params with: %r nan nan {'criterion': 'entropy', 'max_depth': 8, 'max_features': 'auto', 'min_samples_leaf': 2, 'min_samples_split': 2}
# means -> %f stds-> (%f) params with: %r nan nan {'criterion': 'entropy', 'max_depth': 8, 'max_features': 'auto', 'min_samples_leaf': 2, 'min_samples_split': 5}
# means -> %f stds-> (%f) params with: %r nan nan {'criterion': 'entropy', 'max_depth': 8, 'max_features': 'auto', 'min_samples_leaf': 2, 'min_samples_split': 10}
# means -> %f stds-> (%f) params with: %r nan nan {'criterion': 'entropy', 'max_depth': 8, 'max_features': 'auto', 'min_samples_leaf': 4, 'min_samples_split': 2}
# means -> %f stds-> (%f) params with: %r nan nan {'criterion': 'entropy', 'max_depth': 8, 'max_features': 'auto', 'min_samples_leaf': 4, 'min_samples_split': 5}
# means -> %f stds-> (%f) params with: %r nan nan {'criterion': 'entropy', 'max_depth': 8, 'max_features': 'auto', 'min_samples_leaf': 4, 'min_samples_split': 10}
# means -> %f stds-> (%f) params with: %r 0.830916030534351 0.023593220550420763 {'criterion': 'entropy', 'max_depth': 8, 'max_features': 'sqrt', 'min_samples_leaf': 1, 'min_samples_split': 2}
# means -> %f stds-> (%f) params with: %r 0.8307251908396948 0.022419400276766675 {'criterion': 'entropy', 'max_depth': 8, 'max_features': 'sqrt', 'min_samples_leaf': 1, 'min_samples_split': 5}
# means -> %f stds-> (%f) params with: %r 0.8362595419847327 0.02471797688349951 {'criterion': 'entropy', 'max_depth': 8, 'max_features': 'sqrt', 'min_samples_leaf': 1, 'min_samples_split': 10}
# means -> %f stds-> (%f) params with: %r 0.833969465648855 0.028434474094945306 {'criterion': 'entropy', 'max_depth': 8, 'max_features': 'sqrt', 'min_samples_leaf': 2, 'min_samples_split': 2}
# means -> %f stds-> (%f) params with: %r 0.8295801526717558 0.032082076904839836 {'criterion': 'entropy', 'max_depth': 8, 'max_features': 'sqrt', 'min_samples_leaf': 2, 'min_samples_split': 5}
# means -> %f stds-> (%f) params with: %r 0.8324427480916032 0.021988840795166536 {'criterion': 'entropy', 'max_depth': 8, 'max_features': 'sqrt', 'min_samples_leaf': 2, 'min_samples_split': 10}
# means -> %f stds-> (%f) params with: %r 0.8291984732824427 0.026556905224078834 {'criterion': 'entropy', 'max_depth': 8, 'max_features': 'sqrt', 'min_samples_leaf': 4, 'min_samples_split': 2}
# means -> %f stds-> (%f) params with: %r 0.8278625954198473 0.023008651714658858 {'criterion': 'entropy', 'max_depth': 8, 'max_features': 'sqrt', 'min_samples_leaf': 4, 'min_samples_split': 5}
# means -> %f stds-> (%f) params with: %r 0.8299618320610687 0.029986132995402176 {'criterion': 'entropy', 'max_depth': 8, 'max_features': 'sqrt', 'min_samples_leaf': 4, 'min_samples_split': 10}
# means -> %f stds-> (%f) params with: %r 0.8282442748091603 0.02556112313015758 {'criterion': 'entropy', 'max_depth': 8, 'max_features': 'log2', 'min_samples_leaf': 1, 'min_samples_split': 2}
# means -> %f stds-> (%f) params with: %r 0.8276717557251908 0.038197030897646 {'criterion': 'entropy', 'max_depth': 8, 'max_features': 'log2', 'min_samples_leaf': 1, 'min_samples_split': 5}
# means -> %f stds-> (%f) params with: %r 0.8261450381679388 0.02734340596089974 {'criterion': 'entropy', 'max_depth': 8, 'max_features': 'log2', 'min_samples_leaf': 1, 'min_samples_split': 10}
# means -> %f stds-> (%f) params with: %r 0.8410305343511449 0.01996168610283363 {'criterion': 'entropy', 'max_depth': 8, 'max_features': 'log2', 'min_samples_leaf': 2, 'min_samples_split': 2}
# means -> %f stds-> (%f) params with: %r 0.8393129770992367 0.020515045267750692 {'criterion': 'entropy', 'max_depth': 8, 'max_features': 'log2', 'min_samples_leaf': 2, 'min_samples_split': 5}
# means -> %f stds-> (%f) params with: %r 0.8295801526717558 0.026013767517611634 {'criterion': 'entropy', 'max_depth': 8, 'max_features': 'log2', 'min_samples_leaf': 2, 'min_samples_split': 10}
# means -> %f stds-> (%f) params with: %r 0.8389312977099237 0.029922300950411655 {'criterion': 'entropy', 'max_depth': 8, 'max_features': 'log2', 'min_samples_leaf': 4, 'min_samples_split': 2}
# means -> %f stds-> (%f) params with: %r 0.8305343511450382 0.0400926902290342 {'criterion': 'entropy', 'max_depth': 8, 'max_features': 'log2', 'min_samples_leaf': 4, 'min_samples_split': 5}
# means -> %f stds-> (%f) params with: %r 0.8354961832061069 0.021889238105251403 {'criterion': 'entropy', 'max_depth': 8, 'max_features': 'log2', 'min_samples_leaf': 4, 'min_samples_split': 10}
# means -> %f stds-> (%f) params with: %r nan nan {'criterion': 'entropy', 'max_depth': 10, 'max_features': 'auto', 'min_samples_leaf': 1, 'min_samples_split': 2}
# means -> %f stds-> (%f) params with: %r nan nan {'criterion': 'entropy', 'max_depth': 10, 'max_features': 'auto', 'min_samples_leaf': 1, 'min_samples_split': 5}
# means -> %f stds-> (%f) params with: %r nan nan {'criterion': 'entropy', 'max_depth': 10, 'max_features': 'auto', 'min_samples_leaf': 1, 'min_samples_split': 10}
# means -> %f stds-> (%f) params with: %r nan nan {'criterion': 'entropy', 'max_depth': 10, 'max_features': 'auto', 'min_samples_leaf': 2, 'min_samples_split': 2}
# means -> %f stds-> (%f) params with: %r nan nan {'criterion': 'entropy', 'max_depth': 10, 'max_features': 'auto', 'min_samples_leaf': 2, 'min_samples_split': 5}
# means -> %f stds-> (%f) params with: %r nan nan {'criterion': 'entropy', 'max_depth': 10, 'max_features': 'auto', 'min_samples_leaf': 2, 'min_samples_split': 10}
# means -> %f stds-> (%f) params with: %r nan nan {'criterion': 'entropy', 'max_depth': 10, 'max_features': 'auto', 'min_samples_leaf': 4, 'min_samples_split': 2}
# means -> %f stds-> (%f) params with: %r nan nan {'criterion': 'entropy', 'max_depth': 10, 'max_features': 'auto', 'min_samples_leaf': 4, 'min_samples_split': 5}
# means -> %f stds-> (%f) params with: %r nan nan {'criterion': 'entropy', 'max_depth': 10, 'max_features': 'auto', 'min_samples_leaf': 4, 'min_samples_split': 10}
# means -> %f stds-> (%f) params with: %r 0.859351145038168 0.03411763294892262 {'criterion': 'entropy', 'max_depth': 10, 'max_features': 'sqrt', 'min_samples_leaf': 1, 'min_samples_split': 2}
# means -> %f stds-> (%f) params with: %r 0.8555343511450382 0.018893129770992365 {'criterion': 'entropy', 'max_depth': 10, 'max_features': 'sqrt', 'min_samples_leaf': 1, 'min_samples_split': 5}
# means -> %f stds-> (%f) params with: %r 0.8587786259541985 0.026921251869591368 {'criterion': 'entropy', 'max_depth': 10, 'max_features': 'sqrt', 'min_samples_leaf': 1, 'min_samples_split': 10}
# means -> %f stds-> (%f) params with: %r 0.8614503816793894 0.027697408483246908 {'criterion': 'entropy', 'max_depth': 10, 'max_features': 'sqrt', 'min_samples_leaf': 2, 'min_samples_split': 2}
# means -> %f stds-> (%f) params with: %r 0.8652671755725191 0.022712329079102037 {'criterion': 'entropy', 'max_depth': 10, 'max_features': 'sqrt', 'min_samples_leaf': 2, 'min_samples_split': 5}
# means -> %f stds-> (%f) params with: %r 0.8622137404580152 0.02283387177274201 {'criterion': 'entropy', 'max_depth': 10, 'max_features': 'sqrt', 'min_samples_leaf': 2, 'min_samples_split': 10}
# means -> %f stds-> (%f) params with: %r 0.8519083969465647 0.025549722093403917 {'criterion': 'entropy', 'max_depth': 10, 'max_features': 'sqrt', 'min_samples_leaf': 4, 'min_samples_split': 2}
# means -> %f stds-> (%f) params with: %r 0.8507633587786259 0.019307847129682053 {'criterion': 'entropy', 'max_depth': 10, 'max_features': 'sqrt', 'min_samples_leaf': 4, 'min_samples_split': 5}
# means -> %f stds-> (%f) params with: %r 0.8507633587786259 0.023494218925973122 {'criterion': 'entropy', 'max_depth': 10, 'max_features': 'sqrt', 'min_samples_leaf': 4, 'min_samples_split': 10}
# means -> %f stds-> (%f) params with: %r 0.8612595419847329 0.022821906215261156 {'criterion': 'entropy', 'max_depth': 10, 'max_features': 'log2', 'min_samples_leaf': 1, 'min_samples_split': 2}
# means -> %f stds-> (%f) params with: %r 0.8627862595419847 0.030812781129200748 {'criterion': 'entropy', 'max_depth': 10, 'max_features': 'log2', 'min_samples_leaf': 1, 'min_samples_split': 5}
# means -> %f stds-> (%f) params with: %r 0.8566793893129772 0.028998215626610827 {'criterion': 'entropy', 'max_depth': 10, 'max_features': 'log2', 'min_samples_leaf': 1, 'min_samples_split': 10}
# means -> %f stds-> (%f) params with: %r 0.8608778625954198 0.02814416444294618 {'criterion': 'entropy', 'max_depth': 10, 'max_features': 'log2', 'min_samples_leaf': 2, 'min_samples_split': 2}
# means -> %f stds-> (%f) params with: %r 0.8532442748091602 0.026172883149650262 {'criterion': 'entropy', 'max_depth': 10, 'max_features': 'log2', 'min_samples_leaf': 2, 'min_samples_split': 5}
# means -> %f stds-> (%f) params with: %r 0.8547709923664122 0.02245835387210296 {'criterion': 'entropy', 'max_depth': 10, 'max_features': 'log2', 'min_samples_leaf': 2, 'min_samples_split': 10}
# means -> %f stds-> (%f) params with: %r 0.8532442748091602 0.02188341395452259 {'criterion': 'entropy', 'max_depth': 10, 'max_features': 'log2', 'min_samples_leaf': 4, 'min_samples_split': 2}
# means -> %f stds-> (%f) params with: %r 0.8549618320610687 0.022564322524973205 {'criterion': 'entropy', 'max_depth': 10, 'max_features': 'log2', 'min_samples_leaf': 4, 'min_samples_split': 5}
# means -> %f stds-> (%f) params with: %r 0.8591603053435115 0.026066215387731094 {'criterion': 'entropy', 'max_depth': 10, 'max_features': 'log2', 'min_samples_leaf': 4, 'min_samples_split': 10}

# %%
clfModel_BestParam = tree.DecisionTreeClassifier(
    max_depth=best_params['max_depth'],
    min_samples_split=best_params['min_samples_split'],
    min_samples_leaf=best_params['min_samples_leaf'],
    max_features=best_params['max_features'],
    criterion=best_params['criterion']
)

# %%
clfModel_BestParam.fit(X_train_scaled, y_train_smote)
# Out:
# DecisionTreeClassifier(max_depth=10, max_features='log2')

# %%
print("ตัวอย่างข้อมูลชุดเรียนรู้ ->",clfModel_BestParam.score(X_train_scaled, y_train_smote))
# Out:
# ตัวอย่างข้อมูลชุดเรียนรู้ -> 0.9194656488549618

# %%
plt.figure(figsize=(12, 6))
tree.plot_tree(clfModel_BestParam.fit(X_train_scaled,y_train_smote))
plt.show()

# %%
y_pred = clfModel_BestParam.predict(X_test_scaled)
print("ตัวอย่างข้อมูลชุดทดสอบ ->",accuracy_score(y_test, y_pred))
# Out:
# ตัวอย่างข้อมูลชุดทดสอบ -> 0.7747671464860287

# %%
pd.crosstab(y_test, y_pred)
# Out:
# col_0        0    1
# alzheimer
# 0          884  230
# 1           36   31

# %%
print("Classification Report:\n", classification_report(y_test, y_pred))
# Out:
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.96      0.79      0.87      1114
#            1       0.12      0.46      0.19        67
#
#     accuracy                           0.77      1181
#    macro avg       0.54      0.63      0.53      1181
# weighted avg       0.91      0.77      0.83      1181

# %%
plt.figure(figsize=(12, 6))
tree.plot_tree(clfModel_BestParam.fit(X_test_scaled,y_test))
plt.show()
