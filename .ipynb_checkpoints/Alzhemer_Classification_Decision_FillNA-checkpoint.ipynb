# %%
import pandas as pd
import numpy as np

# %%
dataSet = pd.read_csv("Alzheimer.csv")
dataSet
# Out:
#          HN         Education   age  hypertension  heart_disease  \
# 0     11046  Secondary School  67.0             0              1
# 1     51676          Bachelor  61.0             0              0
# 2     35112  Secondary School  80.0             0              1
# 3     67182          Bachelor  49.0             0              0
# 4      1665          Bachelor  79.0             1              0
# ...     ...               ...   ...           ...            ...
# 4095  68398  Secondary School  82.0             1              0
# 4096  14180          Bachelor  13.0             0              0
# 4097  44873          Bachelor  81.0             0              0
# 4098  19723          Bachelor  35.0             0              0
# 4099  44679          Bachelor  44.0             0              0
#
#      family history Occupation Triglycerides  Blood Sugar   BMI  \
# 0               Yes    Private        Normal       228.69  36.6
# 1               Yes  Freelance          High       202.21   NaN
# 2               Yes    Private          High       105.92  32.5
# 3               Yes    Private        Normal       171.23  34.4
# 4               Yes  Freelance          High       174.12  24.0
# ...             ...        ...           ...          ...   ...
# 4095            Yes  Freelance          High        71.97  28.3
# 4096             No     Farmer          High       103.08  18.6
# 4097            Yes  Freelance        Normal       125.20  40.0
# 4098            Yes  Freelance          High        82.99  30.6
# 4099            Yes    Officer        Normal        85.28  26.2
#
#        smoking_status  alzheimer
# 0     formerly smoked          1
# 1        never smoked          1
# 2        never smoked          1
# 3              smokes          1
# 4        never smoked          1
# ...               ...        ...
# 4095     never smoked          0
# 4096          Unknown          0
# 4097     never smoked          0
# 4098     never smoked          0
# 4099          Unknown          0
#
# [4100 rows x 12 columns]

# %% [markdown]
# # MARK: Data Processing

# %%
dataSet.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4100 entries, 0 to 4099
# Data columns (total 12 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   HN              4100 non-null   int64
#  1   Education       4100 non-null   object
#  2   age             4100 non-null   float64
#  3   hypertension    4100 non-null   int64
#  4   heart_disease   4100 non-null   int64
#  5   family history  4100 non-null   object
#  6   Occupation      4100 non-null   object
#  7   Triglycerides   4100 non-null   object
#  8   Blood Sugar     4100 non-null   float64
#  9   BMI             3936 non-null   float64
#  10  smoking_status  4100 non-null   object
#  11  alzheimer       4100 non-null   int64
# dtypes: float64(3), int64(4), object(5)
# memory usage: 384.5+ KB

# %%
dataSet.isna().sum()
# Out:
# HN                  0
# Education           0
# age                 0
# hypertension        0
# heart_disease       0
# family history      0
# Occupation          0
# Triglycerides       0
# Blood Sugar         0
# BMI               164
# smoking_status      0
# alzheimer           0
# dtype: int64

# %%
dataSet[(dataSet['BMI'].isna()) & (dataSet['alzheimer'] == 1)]
# Out:
#         HN         Education    age  hypertension  heart_disease  \
# 1    51676          Bachelor  61.00             0              0
# 8    27466          Bachelor  59.00             0              0
# 13   38213  Secondary School  78.00             0              1
# 19   25226  Secondary School  57.00             0              1
# 27   61843  Secondary School  58.00             0              0
# 29   69160  Secondary School  59.00             0              0
# 43    1845          Bachelor  63.00             0              0
# 46   37937          Bachelor  75.00             0              1
# 49    8752          Bachelor  63.00             0              0
# 54    7356  Secondary School  75.00             0              0
# 60   70676          Bachelor  76.00             0              0
# 68   45805          Bachelor  51.00             0              0
# 71   26015          Bachelor  66.00             0              0
# 74   70042  Secondary School  58.00             0              0
# 95    2346  Secondary School  58.00             0              0
# 102  36706          Bachelor  76.00             0              0
# 114  14164          Bachelor  72.00             0              0
# 116   3352  Secondary School  78.00             1              0
# 119  48796          Bachelor  75.00             0              0
# 123  31563          Bachelor  38.00             0              0
# 136  41241  Secondary School  65.00             0              0
# 140  11933          Bachelor  79.00             0              0
# 150  50931          Bachelor  76.00             0              0
# 151  16590  Secondary School  71.00             0              1
# 152  69768          Bachelor   1.32             0              0
# 157  43364  Secondary School  79.00             1              0
# 160  28939  Secondary School  64.00             0              0
# 161  60739          Bachelor  79.00             1              1
# 164  40899          Bachelor  78.00             0              0
# 168  33486          Bachelor  80.00             0              0
# 173   8003          Bachelor  77.00             0              0
# 179  66955  Secondary School  61.00             0              1
# 188  18937  Secondary School  79.00             0              0
# 190  54695  Secondary School  74.00             0              0
# 208  25904          Bachelor  76.00             1              1
# 217  39105  Secondary School  74.00             0              0
# 237  34060  Secondary School  71.00             1              0
#
#     family history Occupation Triglycerides  Blood Sugar  BMI  \
# 1              Yes  Freelance          High       202.21  NaN
# 8              Yes    Private          High        76.15  NaN
# 13             Yes    Private        Normal       219.84  NaN
# 19              No    Officer        Normal       217.08  NaN
# 27             Yes    Private          High       189.84  NaN
# 29             Yes    Private          High       211.78  NaN
# 43             Yes    Private        Normal        90.90  NaN
# 46              No  Freelance        Normal       109.78  NaN
# 49             Yes    Officer        Normal       197.54  NaN
# 54             Yes    Private        Normal       104.72  NaN
# 60             Yes    Officer          High        62.57  NaN
# 68             Yes    Private        Normal       165.31  NaN
# 71             Yes  Freelance        Normal       101.45  NaN
# 74             Yes    Private        Normal        71.20  NaN
# 95             Yes    Private        Normal        82.30  NaN
# 102            Yes  Freelance        Normal       106.41  NaN
# 114            Yes    Private        Normal       219.91  NaN
# 116            Yes  Freelance        Normal        93.13  NaN
# 119            Yes    Officer        Normal        62.48  NaN
# 123            Yes    Private          High       101.45  NaN
# 136            Yes  Freelance        Normal        68.43  NaN
# 140            Yes    Private          High       169.67  NaN
# 150            Yes    Private        Normal        57.92  NaN
# 151            Yes    Private        Normal        81.76  NaN
# 152             No     Farmer        Normal        70.37  NaN
# 157            Yes    Private          High        75.02  NaN
# 160            Yes  Freelance          High       111.98  NaN
# 161             No  Freelance          High        60.94  NaN
# 164            Yes  Freelance          High        60.67  NaN
# 168            Yes    Officer        Normal       110.66  NaN
# 173             No    Private        Normal        81.32  NaN
# 179            Yes    Private        Normal       209.86  NaN
# 188            Yes    Private          High       114.77  NaN
# 190            Yes    Private        Normal       167.13  NaN
# 208            Yes  Freelance        Normal       199.86  NaN
# 217            Yes  Freelance          High        60.98  NaN
# 237            Yes  Freelance          High        87.80  NaN
#
#       smoking_status  alzheimer
# 1       never smoked          1
# 8            Unknown          1
# 13           Unknown          1
# 19           Unknown          1
# 27           Unknown          1
# 29   formerly smoked          1
# 43   formerly smoked          1
# 46           Unknown          1
# 49      never smoked          1
# 54           Unknown          1
# 60   formerly smoked          1
# 68      never smoked          1
# 71           Unknown          1
# 74           Unknown          1
# 95            smokes          1
# 102  formerly smoked          1
# 114          Unknown          1
# 116  formerly smoked          1
# 119          Unknown          1
# 123  formerly smoked          1
# 136  formerly smoked          1
# 140          Unknown          1
# 150  formerly smoked          1
# 151           smokes          1
# 152          Unknown          1
# 157     never smoked          1
# 160  formerly smoked          1
# 161     never smoked          1
# 164  formerly smoked          1
# 168          Unknown          1
# 173          Unknown          1
# 179          Unknown          1
# 188  formerly smoked          1
# 190          Unknown          1
# 208           smokes          1
# 217     never smoked          1
# 237          Unknown          1

# %%
len(dataSet[(dataSet['BMI'].isna()) & (dataSet['alzheimer'] == 1)])
# Out:
# 37

# %%
len(dataSet[(dataSet['BMI'].isna() == False) & (dataSet['alzheimer'] == 1)])
# Out:
# 202

# %% [markdown]
# ## สร้าง contingency table ระหว่างแต่ละ feature และ class target (ตารางสรุปความถี่ของ Feature)

# %%
from scipy.stats import chi2_contingency

# %%
contingency_tables = {}
for feature in dataSet.columns:
    if feature != 'alzheimer':
        contingency_table = pd.crosstab(dataSet[feature], dataSet['alzheimer'])
        contingency_tables[feature] = contingency_table

# %% [markdown]
# ## ทดสอบ Chi-Square และแสดงผลลัพธ์

# %%
chi_square_results = {}
for feature, contingency_table in contingency_tables.items():
    chi2, p, _, _ = chi2_contingency(contingency_table)
    chi_square_results[feature] = {'Chi-Square': chi2, 'p-value': p}

# %%
for feature, result in chi_square_results.items():
    print(f"Feature: {feature}")
    print(f"Chi-Square: {result['Chi-Square']:.4f}")
    print(f"p-value: {result['p-value']:.4f}")
    print("")
# Out:
# Feature: HN
# Chi-Square: 4100.0000
# p-value: 0.4927
#
# Feature: Education
# Chi-Square: 0.2922
# p-value: 0.5888
#
# Feature: age
# Chi-Square: 452.2064
# p-value: 0.0000
#
# Feature: hypertension
# Chi-Square: 69.4811
# p-value: 0.0000
#
# Feature: heart_disease
# Chi-Square: 83.7128
# p-value: 0.0000
#
# Feature: family history
# Chi-Square: 61.6582
# p-value: 0.0000
#
# Feature: Occupation
# Chi-Square: 54.1797
# p-value: 0.0000
#
# Feature: Triglycerides
# Chi-Square: 0.7793
# p-value: 0.3774
#
# Feature: Blood Sugar
# Chi-Square: 3462.4151
# p-value: 0.0700
#
# Feature: BMI
# Chi-Square: 415.8287
# p-value: 0.3574
#
# Feature: smoking_status
# Chi-Square: 29.5588
# p-value: 0.0000

# %%
sorted_results = sorted(chi_square_results.items(), key=lambda x: x[1]['Chi-Square'], reverse=True)

features = [item[0] for item in sorted_results]
chi_square_values = [item[1]['Chi-Square'] for item in sorted_results]

plt.figure(figsize=(12, 6))
plt.barh(features, chi_square_values)
plt.xlabel('Chi-Square Value')
plt.ylabel('Feature')
plt.title('Chi-Square Test Results for Features vs. Alzheimer')
plt.gca().invert_yaxis()  # กลับขั้น Feature เพื่อเรียงจากมากไปน้อย
plt.show()

# %% [markdown]
# ### MARK: จากการตรวจสอบ พิจารณา Top 5 ความสัมพันธ์ระหว่าง Feature กับ Class พบว่า BMI ค่อนข้างมีผลกับ Class จึดตัดสินใจแก้ไข BMI None ด้วยค่าเฉลี่ย

# %%
average_bmi = dataSet['BMI'].mean()
dataSet['BMI'].fillna(average_bmi, inplace=True)

# %%
dataSet.isna().sum()
# Out:
# HN                0
# Education         0
# age               0
# hypertension      0
# heart_disease     0
# family history    0
# Occupation        0
# Triglycerides     0
# Blood Sugar       0
# BMI               0
# smoking_status    0
# alzheimer         0
# dtype: int64

# %% [markdown]
# ### MARK: ตรวจสอบ Class Target จำนวนเหมาะสมกันหรือไม่

# %%
print("Target == 1 ->", len(dataSet.loc[dataSet["alzheimer"] == 1, "alzheimer"]))
# Out:
# Target == 1 -> 239

# %%
print("Target == 1 ->", len(dataSet.loc[dataSet["alzheimer"] == 0, "alzheimer"]))
# Out:
# Target == 1 -> 3861

# %% [markdown]
# ### MARK: ปรับข้อมูล เป็น 0,1 <- LabelEncoder

# %%
from sklearn.preprocessing import LabelEncoder

# %%
dataSet.head()
# Out:
#       HN         Education   age  hypertension  heart_disease family history  \
# 0  11046  Secondary School  67.0             0              1            Yes
# 1  51676          Bachelor  61.0             0              0            Yes
# 2  35112  Secondary School  80.0             0              1            Yes
# 3  67182          Bachelor  49.0             0              0            Yes
# 4   1665          Bachelor  79.0             1              0            Yes
#
#   Occupation Triglycerides  Blood Sugar        BMI   smoking_status  alzheimer
# 0    Private        Normal       228.69  36.600000  formerly smoked          1
# 1  Freelance          High       202.21  28.680056     never smoked          1
# 2    Private          High       105.92  32.500000     never smoked          1
# 3    Private        Normal       171.23  34.400000           smokes          1
# 4  Freelance          High       174.12  24.000000     never smoked          1

# %%
label_encoder = LabelEncoder()

# %%
dataSet['Education'] = label_encoder.fit_transform(dataSet['Education'])
dataSet['family history'] = label_encoder.fit_transform(dataSet['family history'])
dataSet['Occupation'] = label_encoder.fit_transform(dataSet['Occupation'])
dataSet['Triglycerides'] = label_encoder.fit_transform(dataSet['Triglycerides'])
dataSet['smoking_status'] = label_encoder.fit_transform(dataSet['smoking_status'])

# %%
dataSet
# Out:
#          HN  Education   age  hypertension  heart_disease  family history  \
# 0     11046          1  67.0             0              1               1
# 1     51676          0  61.0             0              0               1
# 2     35112          1  80.0             0              1               1
# 3     67182          0  49.0             0              0               1
# 4      1665          0  79.0             1              0               1
# ...     ...        ...   ...           ...            ...             ...
# 4095  68398          1  82.0             1              0               1
# 4096  14180          0  13.0             0              0               0
# 4097  44873          0  81.0             0              0               1
# 4098  19723          0  35.0             0              0               1
# 4099  44679          0  44.0             0              0               1
#
#       Occupation  Triglycerides  Blood Sugar        BMI  smoking_status  \
# 0              4              1       228.69  36.600000               1
# 1              1              0       202.21  28.680056               2
# 2              4              0       105.92  32.500000               2
# 3              4              1       171.23  34.400000               3
# 4              1              0       174.12  24.000000               2
# ...          ...            ...          ...        ...             ...
# 4095           1              0        71.97  28.300000               2
# 4096           0              0       103.08  18.600000               0
# 4097           1              1       125.20  40.000000               2
# 4098           1              0        82.99  30.600000               2
# 4099           3              1        85.28  26.200000               0
#
#       alzheimer
# 0             1
# 1             1
# 2             1
# 3             1
# 4             1
# ...         ...
# 4095          0
# 4096          0
# 4097          0
# 4098          0
# 4099          0
#
# [4100 rows x 12 columns]

# %% [markdown]
# # MARK: แบ่งข้อมูล

# %%
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, classification_report
from sklearn import tree
from sklearn.tree import plot_tree
import matplotlib.pyplot as plt

# %% [markdown]
# ### MARK: train_test_split

# %%
X = dataSet.drop(['HN', 'alzheimer'], axis=1)#dataSet.drop('alzheimer', axis=1)
y = dataSet["alzheimer"]
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# %%
X_train.head()
# Out:
#       Education   age  hypertension  heart_disease  family history  \
# 4002          1  12.0             0              0               0
# 1334          0  35.0             0              0               1
# 765           0  23.0             0              0               0
# 2157          1  60.0             0              0               1
# 3694          1  57.0             0              0               1
#
#       Occupation  Triglycerides  Blood Sugar   BMI  smoking_status
# 4002           0              1        69.25  18.6               0
# 1334           3              0        89.11  24.4               2
# 765            4              1        79.39  27.6               2
# 2157           4              0        70.52  26.5               1
# 3694           4              1       134.76  29.1               0

# %%
X_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2870 entries, 4002 to 860
# Data columns (total 10 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Education       2870 non-null   int32
#  1   age             2870 non-null   float64
#  2   hypertension    2870 non-null   int64
#  3   heart_disease   2870 non-null   int64
#  4   family history  2870 non-null   int32
#  5   Occupation      2870 non-null   int32
#  6   Triglycerides   2870 non-null   int32
#  7   Blood Sugar     2870 non-null   float64
#  8   BMI             2870 non-null   float64
#  9   smoking_status  2870 non-null   int32
# dtypes: float64(3), int32(5), int64(2)
# memory usage: 190.6 KB

# %%
y_train.info()
# Out:
# <class 'pandas.core.series.Series'>
# Int64Index: 2870 entries, 4002 to 860
# Series name: alzheimer
# Non-Null Count  Dtype
# --------------  -----
# 2870 non-null   int64
# dtypes: int64(1)
# memory usage: 44.8 KB

# %% [markdown]
# ### SMOTE (Synthetic Minority Over-sampling Technique): วิธีการที่ใช้การสร้างตัวอย่างสัญญาณเทียบเท่าจากคลาสน้อยโดยการผสมคุณลักษณะของตัวอย่างในคลาสน้อย

# %%
from imblearn.over_sampling import SMOTE
from sklearn.preprocessing import StandardScaler

# %%
smote = SMOTE(random_state=42)
X_train_smote, y_train_smote = smote.fit_resample(X_train, y_train)

# %% [markdown]
# ## MARK: ทำ scaler

# %%
scaler = StandardScaler()

X_train_scaled = scaler.fit_transform(X_train_smote)
X_test_scaled = scaler.transform(X_test)

# %% [markdown]
# # MARK: Decision tree model Start (Default)

# %%
clfModel = tree.DecisionTreeClassifier(criterion="gini",class_weight='balanced',random_state=42)

# %%
clfModel.get_params()
# Out:
# {'ccp_alpha': 0.0,
#  'class_weight': 'balanced',
#  'criterion': 'gini',
#  'max_depth': None,
#  'max_features': None,
#  'max_leaf_nodes': None,
#  'min_impurity_decrease': 0.0,
#  'min_samples_leaf': 1,
#  'min_samples_split': 2,
#  'min_weight_fraction_leaf': 0.0,
#  'random_state': 42,
#  'splitter': 'best'}

# %%
clfModel.fit(X_train_scaled,y_train_smote)
# Out:
# DecisionTreeClassifier(class_weight='balanced', random_state=42)

# %%
print("ตัวอย่างข้อมูลชุดเรียนรู้ ->",clfModel.score(X_train_scaled,y_train_smote))
# Out:
# ตัวอย่างข้อมูลชุดเรียนรู้ -> 1.0

# %%
# อันเดียวกัน
# y_train_pred = clf.predict(X_train)
# accuracy_score(y_train, y_train_pred)

# %% [markdown]
# ### MARK: Visualize Decision Tree

# %%
plt.figure(figsize=(12, 6))
tree.plot_tree(clfModel.fit(X_train_scaled,y_train_smote))
plt.show()

# %% [markdown]
# ### MARK: Predict and Score Model

# %%
y_pred = clfModel.predict(X_test_scaled)
print("ตัวอย่างข้อมูลชุดทดสอบ ->",accuracy_score(y_test, y_pred))
# Out:
# ตัวอย่างข้อมูลชุดทดสอบ -> 0.8455284552845529

# %%
pd.crosstab(y_test, y_pred)
# Out:
# col_0         0    1
# alzheimer
# 0          1020  125
# 1            65   20

# %%
print("Classification Report:\n", classification_report(y_test, y_pred))
# Out:
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.94      0.89      0.91      1145
#            1       0.14      0.24      0.17        85
#
#     accuracy                           0.85      1230
#    macro avg       0.54      0.56      0.54      1230
# weighted avg       0.88      0.85      0.86      1230

# %%
plt.figure(figsize=(12, 6))
tree.plot_tree(clfModel.fit(X_test_scaled,y_test))
plt.show()

# %% [markdown]
# ## MARK: หา Best Parameter และ ลองทำ Pruning

# %%
from sklearn.model_selection import GridSearchCV

# %% [markdown]
# ### MARK: ค้นหา best_params และประเมิน best_accuracy

# %%
param_grid = {
    'max_depth': [2, 4, 6, 8, 10],
    'min_samples_split': [2, 5, 10],
    'min_samples_leaf': [1, 2, 4],
    'max_features': ['auto', 'sqrt', 'log2'],
    'criterion': ['gini', 'entropy']
}
treeModel = tree.DecisionTreeClassifier()
# สร้าง Grid Search
grid_search = GridSearchCV(treeModel, param_grid, cv=10, scoring='accuracy')

# %%
grid_search.fit(X_train_scaled,y_train_smote)
# Out:
# C:\Users\PP\anaconda3\envs\CallmeEnv\lib\site-packages\sklearn\model_selection\_validation.py:425: FitFailedWarning:
# 900 fits failed out of a total of 2700.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 900 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\Users\PP\anaconda3\envs\CallmeEnv\lib\site-packages\sklearn\model_selection\_validation.py", line 732, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\PP\anaconda3\envs\CallmeEnv\lib\site-packages\sklearn\base.py", line 1144, in wrapper
#     estimator._validate_params()
#   File "C:\Users\PP\anaconda3\envs\CallmeEnv\lib\site-packages\sklearn\base.py", line 637, in _validate_params
#     validate_parameter_constraints(
#   File "C:\Users\PP\anaconda3\envs\CallmeEnv\lib\site-packages\sklearn\utils\_param_validation.py", line 95, in validate_parameter_constraints
#     raise InvalidParameterError(
# sklearn.utils._param_validation.InvalidParameterError: The 'max_features' parameter of DecisionTreeClassifier must be an int in the range [1, inf), a float in the range (0.0, 1.0], a str among {'sqrt', 'log2'} or None. Got 'auto' instead.
#
#   warnings.warn(some_fits_failed_message, FitFailedWarning)
# C:\Users\PP\anaconda3\envs\CallmeEnv\lib\site-packages\sklearn\model_selection\_search.py:976: UserWarning: One or more of the test scores are non-finite: [       nan        nan        nan        nan        nan        nan
#         nan        nan        nan 0.70360809 0.7072876  0.74483568
#  0.69237149 0.73746987 0.70707534 0.70048478 0.73933113 0.72276399
#  0.6622048  0.70252241 0.70178102 0.69072554 0.68983182 0.69824911
#  0.70854864 0.700673   0.71725707        nan        nan        nan
#         nan        nan        nan        nan        nan        nan
#  0.76306569 0.74855616 0.78221922 0.73508084 0.76655834 0.7822199
#  0.76600754 0.76306603 0.77541064 0.76638873 0.74874303 0.77245694
#  0.73971875 0.76860342 0.75865968 0.78112068 0.74799013 0.77817138
#         nan        nan        nan        nan        nan        nan
#         nan        nan        nan 0.8118595  0.78571898 0.79159727
#  0.80191644 0.80726492 0.81093699 0.80504922 0.80412807 0.8085483
#  0.79676802 0.8118666  0.80467954 0.81461956 0.81370518 0.80376923
#  0.79970954 0.80320049 0.80486134        nan        nan        nan
#         nan        nan        nan        nan        nan        nan
#  0.83155976 0.83377038 0.83561031 0.82898047 0.82917513 0.83634831
#  0.82677087 0.83653383 0.83524131 0.83137323 0.83983791 0.83340307
#  0.83413837 0.83045952 0.84094559 0.83782262 0.83782364 0.83193248
#         nan        nan        nan        nan        nan        nan
#         nan        nan        nan 0.85881236 0.85641893 0.85641385
#  0.84555607 0.86340625 0.86065127 0.86562026 0.85438874 0.85549643
#  0.85310164 0.85751882 0.85475707 0.85402245 0.85310198 0.85788478
#  0.84942314 0.84776839 0.8578841         nan        nan        nan
#         nan        nan        nan        nan        nan        nan
#  0.7054839  0.70469173 0.69424798 0.6999306  0.70104945 0.72034585
#  0.69168901 0.6798549  0.67583584 0.72881899 0.70398894 0.71021659
#  0.67693573 0.71541342 0.72884608 0.69461292 0.71445232 0.71300915
#         nan        nan        nan        nan        nan        nan
#         nan        nan        nan 0.71427628 0.7557185  0.76803976
#  0.75055215 0.76786609 0.74393518 0.74317077 0.76066752 0.76031104
#  0.76693208 0.7536873  0.7616144  0.7557053  0.75809873 0.7516561
#  0.76474244 0.76692666 0.76583997        nan        nan        nan
#         nan        nan        nan        nan        nan        nan
#  0.79400525 0.79270529 0.79474495 0.79437155 0.80449775 0.79270766
#  0.7873805  0.80339718 0.81241097 0.79583773 0.80706654 0.79141818
#  0.78865541 0.79989133 0.79731306 0.79235998 0.79069068 0.7969532
#         nan        nan        nan        nan        nan        nan
#         nan        nan        nan 0.83248497 0.83008748 0.82953431
#  0.82216614 0.8264083  0.82162178 0.8194142  0.8321136  0.81627668
#  0.82751327 0.82843002 0.80947317 0.83009019 0.82640864 0.8256686
#  0.8267729  0.82382766 0.8262238         nan        nan        nan
#         nan        nan        nan        nan        nan        nan
#  0.84574464 0.85476147 0.85310435 0.84334444 0.84812825 0.8543901
#  0.84316197 0.86083577 0.85255491 0.84646978 0.85383727 0.85457595
#  0.85475775 0.8547591  0.84794781 0.8505227  0.86175557 0.84960324]
#   warnings.warn(
# GridSearchCV(cv=10, estimator=DecisionTreeClassifier(),
#              param_grid={'criterion': ['gini', 'entropy'],
#                          'max_depth': [2, 4, 6, 8, 10],
#                          'max_features': ['auto', 'sqrt', 'log2'],
#                          'min_samples_leaf': [1, 2, 4],
#                          'min_samples_split': [2, 5, 10]},
#              scoring='accuracy')

# %%
best_params = grid_search.best_params_
print("Best Parameters:", best_params)
# best_params = {'criterion': 'gini', 'max_depth': 10, 'max_features': 'log2', 'min_samples_leaf': 4, 'min_samples_split': 5}

# %%
best_accuracy = grid_search.best_score_
print("Best Accuracy:", best_accuracy)
# Out:
# Best Accuracy: 0.8656202605351533

# %%
print("Best:",grid_search.best_score_,"using" , grid_search.best_params_)
means = grid_search.cv_results_["mean_test_score"]
stds = grid_search.cv_results_["std_test_score"]
params = grid_search.cv_results_["params"]
for means, stds, params in zip(means, stds, params):
    print("means -> %f stds-> (%f) params with: %r", means, stds, params)
# Out:
# Best: 0.8656202605351533 using {'criterion': 'gini', 'max_depth': 10, 'max_features': 'sqrt', 'min_samples_leaf': 4, 'min_samples_split': 2}
# means -> %f stds-> (%f) params with: %r nan nan {'criterion': 'gini', 'max_depth': 2, 'max_features': 'auto', 'min_samples_leaf': 1, 'min_samples_split': 2}
# means -> %f stds-> (%f) params with: %r nan nan {'criterion': 'gini', 'max_depth': 2, 'max_features': 'auto', 'min_samples_leaf': 1, 'min_samples_split': 5}
# means -> %f stds-> (%f) params with: %r nan nan {'criterion': 'gini', 'max_depth': 2, 'max_features': 'auto', 'min_samples_leaf': 1, 'min_samples_split': 10}
# means -> %f stds-> (%f) params with: %r nan nan {'criterion': 'gini', 'max_depth': 2, 'max_features': 'auto', 'min_samples_leaf': 2, 'min_samples_split': 2}
# means -> %f stds-> (%f) params with: %r nan nan {'criterion': 'gini', 'max_depth': 2, 'max_features': 'auto', 'min_samples_leaf': 2, 'min_samples_split': 5}
# means -> %f stds-> (%f) params with: %r nan nan {'criterion': 'gini', 'max_depth': 2, 'max_features': 'auto', 'min_samples_leaf': 2, 'min_samples_split': 10}
# means -> %f stds-> (%f) params with: %r nan nan {'criterion': 'gini', 'max_depth': 2, 'max_features': 'auto', 'min_samples_leaf': 4, 'min_samples_split': 2}
# means -> %f stds-> (%f) params with: %r nan nan {'criterion': 'gini', 'max_depth': 2, 'max_features': 'auto', 'min_samples_leaf': 4, 'min_samples_split': 5}
# means -> %f stds-> (%f) params with: %r nan nan {'criterion': 'gini', 'max_depth': 2, 'max_features': 'auto', 'min_samples_leaf': 4, 'min_samples_split': 10}
# means -> %f stds-> (%f) params with: %r 0.7036080868811613 0.05897491118439173 {'criterion': 'gini', 'max_depth': 2, 'max_features': 'sqrt', 'min_samples_leaf': 1, 'min_samples_split': 2}
# means -> %f stds-> (%f) params with: %r 0.7072876042682266 0.0613809522623736 {'criterion': 'gini', 'max_depth': 2, 'max_features': 'sqrt', 'min_samples_leaf': 1, 'min_samples_split': 5}
# means -> %f stds-> (%f) params with: %r 0.7448356759831004 0.054778062449102015 {'criterion': 'gini', 'max_depth': 2, 'max_features': 'sqrt', 'min_samples_leaf': 1, 'min_samples_split': 10}
# means -> %f stds-> (%f) params with: %r 0.6923714927960135 0.07025513496404727 {'criterion': 'gini', 'max_depth': 2, 'max_features': 'sqrt', 'min_samples_leaf': 2, 'min_samples_split': 2}
# means -> %f stds-> (%f) params with: %r 0.737469870544903 0.054482871399931014 {'criterion': 'gini', 'max_depth': 2, 'max_features': 'sqrt', 'min_samples_leaf': 2, 'min_samples_split': 5}
# means -> %f stds-> (%f) params with: %r 0.7070753439497347 0.08096932694085807 {'criterion': 'gini', 'max_depth': 2, 'max_features': 'sqrt', 'min_samples_leaf': 2, 'min_samples_split': 10}
# means -> %f stds-> (%f) params with: %r 0.7004847795471779 0.06482472159319284 {'criterion': 'gini', 'max_depth': 2, 'max_features': 'sqrt', 'min_samples_leaf': 4, 'min_samples_split': 2}
# means -> %f stds-> (%f) params with: %r 0.7393311260968476 0.05444057915841616 {'criterion': 'gini', 'max_depth': 2, 'max_features': 'sqrt', 'min_samples_leaf': 4, 'min_samples_split': 5}
# means -> %f stds-> (%f) params with: %r 0.7227639881919619 0.05766469785364327 {'criterion': 'gini', 'max_depth': 2, 'max_features': 'sqrt', 'min_samples_leaf': 4, 'min_samples_split': 10}
# means -> %f stds-> (%f) params with: %r 0.6622047990466905 0.06240876709191862 {'criterion': 'gini', 'max_depth': 2, 'max_features': 'log2', 'min_samples_leaf': 1, 'min_samples_split': 2}
# means -> %f stds-> (%f) params with: %r 0.7025224108980609 0.060942428123589416 {'criterion': 'gini', 'max_depth': 2, 'max_features': 'log2', 'min_samples_leaf': 1, 'min_samples_split': 5}
# means -> %f stds-> (%f) params with: %r 0.7017810231827537 0.06667807134955915 {'criterion': 'gini', 'max_depth': 2, 'max_features': 'log2', 'min_samples_leaf': 1, 'min_samples_split': 10}
# means -> %f stds-> (%f) params with: %r 0.6907255443613909 0.06830085979225486 {'criterion': 'gini', 'max_depth': 2, 'max_features': 'log2', 'min_samples_leaf': 2, 'min_samples_split': 2}
# means -> %f stds-> (%f) params with: %r 0.6898318167045826 0.07907637322351596 {'criterion': 'gini', 'max_depth': 2, 'max_features': 'log2', 'min_samples_leaf': 2, 'min_samples_split': 5}
# means -> %f stds-> (%f) params with: %r 0.6982491062723432 0.06588112924494824 {'criterion': 'gini', 'max_depth': 2, 'max_features': 'log2', 'min_samples_leaf': 2, 'min_samples_split': 10}
# means -> %f stds-> (%f) params with: %r 0.7085486404506554 0.07442727868788739 {'criterion': 'gini', 'max_depth': 2, 'max_features': 'log2', 'min_samples_leaf': 4, 'min_samples_split': 2}
# means -> %f stds-> (%f) params with: %r 0.7006730040082332 0.07024978394740676 {'criterion': 'gini', 'max_depth': 2, 'max_features': 'log2', 'min_samples_leaf': 4, 'min_samples_split': 5}
# means -> %f stds-> (%f) params with: %r 0.7172570685732855 0.06947611419038735 {'criterion': 'gini', 'max_depth': 2, 'max_features': 'log2', 'min_samples_leaf': 4, 'min_samples_split': 10}
# means -> %f stds-> (%f) params with: %r nan nan {'criterion': 'gini', 'max_depth': 4, 'max_features': 'auto', 'min_samples_leaf': 1, 'min_samples_split': 2}
# means -> %f stds-> (%f) params with: %r nan nan {'criterion': 'gini', 'max_depth': 4, 'max_features': 'auto', 'min_samples_leaf': 1, 'min_samples_split': 5}
# means -> %f stds-> (%f) params with: %r nan nan {'criterion': 'gini', 'max_depth': 4, 'max_features': 'auto', 'min_samples_leaf': 1, 'min_samples_split': 10}
# means -> %f stds-> (%f) params with: %r nan nan {'criterion': 'gini', 'max_depth': 4, 'max_features': 'auto', 'min_samples_leaf': 2, 'min_samples_split': 2}
# means -> %f stds-> (%f) params with: %r nan nan {'criterion': 'gini', 'max_depth': 4, 'max_features': 'auto', 'min_samples_leaf': 2, 'min_samples_split': 5}
# means -> %f stds-> (%f) params with: %r nan nan {'criterion': 'gini', 'max_depth': 4, 'max_features': 'auto', 'min_samples_leaf': 2, 'min_samples_split': 10}
# means -> %f stds-> (%f) params with: %r nan nan {'criterion': 'gini', 'max_depth': 4, 'max_features': 'auto', 'min_samples_leaf': 4, 'min_samples_split': 2}
# means -> %f stds-> (%f) params with: %r nan nan {'criterion': 'gini', 'max_depth': 4, 'max_features': 'auto', 'min_samples_leaf': 4, 'min_samples_split': 5}
# means -> %f stds-> (%f) params with: %r nan nan {'criterion': 'gini', 'max_depth': 4, 'max_features': 'auto', 'min_samples_leaf': 4, 'min_samples_split': 10}
# means -> %f stds-> (%f) params with: %r 0.7630656889827755 0.028750955867201396 {'criterion': 'gini', 'max_depth': 4, 'max_features': 'sqrt', 'min_samples_leaf': 1, 'min_samples_split': 2}
# means -> %f stds-> (%f) params with: %r 0.7485561558877694 0.04881913322702952 {'criterion': 'gini', 'max_depth': 4, 'max_features': 'sqrt', 'min_samples_leaf': 1, 'min_samples_split': 5}
# means -> %f stds-> (%f) params with: %r 0.7822192205611526 0.0315212516278525 {'criterion': 'gini', 'max_depth': 4, 'max_features': 'sqrt', 'min_samples_leaf': 1, 'min_samples_split': 10}
# means -> %f stds-> (%f) params with: %r 0.7350808417289568 0.039813298811573965 {'criterion': 'gini', 'max_depth': 4, 'max_features': 'sqrt', 'min_samples_leaf': 2, 'min_samples_split': 2}
# means -> %f stds-> (%f) params with: %r 0.7665583360415991 0.039175924639247656 {'criterion': 'gini', 'max_depth': 4, 'max_features': 'sqrt', 'min_samples_leaf': 2, 'min_samples_split': 5}
# means -> %f stds-> (%f) params with: %r 0.7822198976275593 0.027631740161233594 {'criterion': 'gini', 'max_depth': 4, 'max_features': 'sqrt', 'min_samples_leaf': 2, 'min_samples_split': 10}
# means -> %f stds-> (%f) params with: %r 0.7660075425197703 0.038600236326697256 {'criterion': 'gini', 'max_depth': 4, 'max_features': 'sqrt', 'min_samples_leaf': 4, 'min_samples_split': 2}
# means -> %f stds-> (%f) params with: %r 0.7630660275159787 0.027006836685846917 {'criterion': 'gini', 'max_depth': 4, 'max_features': 'sqrt', 'min_samples_leaf': 4, 'min_samples_split': 5}
# means -> %f stds-> (%f) params with: %r 0.7754106407756473 0.03715639188300151 {'criterion': 'gini', 'max_depth': 4, 'max_features': 'sqrt', 'min_samples_leaf': 4, 'min_samples_split': 10}
# means -> %f stds-> (%f) params with: %r 0.7663887309067273 0.02792573327624399 {'criterion': 'gini', 'max_depth': 4, 'max_features': 'log2', 'min_samples_leaf': 1, 'min_samples_split': 2}
# means -> %f stds-> (%f) params with: %r 0.7487430262160112 0.05098427862243772 {'criterion': 'gini', 'max_depth': 4, 'max_features': 'log2', 'min_samples_leaf': 1, 'min_samples_split': 5}
# means -> %f stds-> (%f) params with: %r 0.7724569385765356 0.03573409571967163 {'criterion': 'gini', 'max_depth': 4, 'max_features': 'log2', 'min_samples_leaf': 1, 'min_samples_split': 10}
# means -> %f stds-> (%f) params with: %r 0.739718746614668 0.06335285564217216 {'criterion': 'gini', 'max_depth': 4, 'max_features': 'log2', 'min_samples_leaf': 2, 'min_samples_split': 2}
# means -> %f stds-> (%f) params with: %r 0.7686034151229552 0.03838758773225157 {'criterion': 'gini', 'max_depth': 4, 'max_features': 'log2', 'min_samples_leaf': 2, 'min_samples_split': 5}
# means -> %f stds-> (%f) params with: %r 0.7586596793413498 0.035114181439561354 {'criterion': 'gini', 'max_depth': 4, 'max_features': 'log2', 'min_samples_leaf': 2, 'min_samples_split': 10}
# means -> %f stds-> (%f) params with: %r 0.7811206803163253 0.029203017276892604 {'criterion': 'gini', 'max_depth': 4, 'max_features': 'log2', 'min_samples_leaf': 4, 'min_samples_split': 2}
# means -> %f stds-> (%f) params with: %r 0.7479901283717906 0.030014004888639582 {'criterion': 'gini', 'max_depth': 4, 'max_features': 'log2', 'min_samples_leaf': 4, 'min_samples_split': 5}
# means -> %f stds-> (%f) params with: %r 0.778171379048857 0.030154588395663783 {'criterion': 'gini', 'max_depth': 4, 'max_features': 'log2', 'min_samples_leaf': 4, 'min_samples_split': 10}
# means -> %f stds-> (%f) params with: %r nan nan {'criterion': 'gini', 'max_depth': 6, 'max_features': 'auto', 'min_samples_leaf': 1, 'min_samples_split': 2}
# means -> %f stds-> (%f) params with: %r nan nan {'criterion': 'gini', 'max_depth': 6, 'max_features': 'auto', 'min_samples_leaf': 1, 'min_samples_split': 5}
# means -> %f stds-> (%f) params with: %r nan nan {'criterion': 'gini', 'max_depth': 6, 'max_features': 'auto', 'min_samples_leaf': 1, 'min_samples_split': 10}
# means -> %f stds-> (%f) params with: %r nan nan {'criterion': 'gini', 'max_depth': 6, 'max_features': 'auto', 'min_samples_leaf': 2, 'min_samples_split': 2}
# means -> %f stds-> (%f) params with: %r nan nan {'criterion': 'gini', 'max_depth': 6, 'max_features': 'auto', 'min_samples_leaf': 2, 'min_samples_split': 5}
# means -> %f stds-> (%f) params with: %r nan nan {'criterion': 'gini', 'max_depth': 6, 'max_features': 'auto', 'min_samples_leaf': 2, 'min_samples_split': 10}
# means -> %f stds-> (%f) params with: %r nan nan {'criterion': 'gini', 'max_depth': 6, 'max_features': 'auto', 'min_samples_leaf': 4, 'min_samples_split': 2}
# means -> %f stds-> (%f) params with: %r nan nan {'criterion': 'gini', 'max_depth': 6, 'max_features': 'auto', 'min_samples_leaf': 4, 'min_samples_split': 5}
# means -> %f stds-> (%f) params with: %r nan nan {'criterion': 'gini', 'max_depth': 6, 'max_features': 'auto', 'min_samples_leaf': 4, 'min_samples_split': 10}
# means -> %f stds-> (%f) params with: %r 0.8118594951792872 0.030299439524246807 {'criterion': 'gini', 'max_depth': 6, 'max_features': 'sqrt', 'min_samples_leaf': 1, 'min_samples_split': 2}
# means -> %f stds-> (%f) params with: %r 0.7857189768172462 0.029888646654241062 {'criterion': 'gini', 'max_depth': 6, 'max_features': 'sqrt', 'min_samples_leaf': 1, 'min_samples_split': 5}
# means -> %f stds-> (%f) params with: %r 0.7915972673599827 0.02990749060618031 {'criterion': 'gini', 'max_depth': 6, 'max_features': 'sqrt', 'min_samples_leaf': 1, 'min_samples_split': 10}
# means -> %f stds-> (%f) params with: %r 0.8019164364640883 0.022480243165482285 {'criterion': 'gini', 'max_depth': 6, 'max_features': 'sqrt', 'min_samples_leaf': 2, 'min_samples_split': 2}
# means -> %f stds-> (%f) params with: %r 0.807264922543603 0.03626010882665968 {'criterion': 'gini', 'max_depth': 6, 'max_features': 'sqrt', 'min_samples_leaf': 2, 'min_samples_split': 5}
# means -> %f stds-> (%f) params with: %r 0.810936992200195 0.025484335872798195 {'criterion': 'gini', 'max_depth': 6, 'max_features': 'sqrt', 'min_samples_leaf': 2, 'min_samples_split': 10}
# means -> %f stds-> (%f) params with: %r 0.8050492227277651 0.020237221802753017 {'criterion': 'gini', 'max_depth': 6, 'max_features': 'sqrt', 'min_samples_leaf': 4, 'min_samples_split': 2}
# means -> %f stds-> (%f) params with: %r 0.8041280738814864 0.02632135151911683 {'criterion': 'gini', 'max_depth': 6, 'max_features': 'sqrt', 'min_samples_leaf': 4, 'min_samples_split': 5}
# means -> %f stds-> (%f) params with: %r 0.808548301917452 0.028708523043299492 {'criterion': 'gini', 'max_depth': 6, 'max_features': 'sqrt', 'min_samples_leaf': 4, 'min_samples_split': 10}
# means -> %f stds-> (%f) params with: %r 0.7967680235077456 0.03328872803593367 {'criterion': 'gini', 'max_depth': 6, 'max_features': 'log2', 'min_samples_leaf': 1, 'min_samples_split': 2}
# means -> %f stds-> (%f) params with: %r 0.8118666043765573 0.03678210344651336 {'criterion': 'gini', 'max_depth': 6, 'max_features': 'log2', 'min_samples_leaf': 1, 'min_samples_split': 5}
# means -> %f stds-> (%f) params with: %r 0.8046795444697216 0.025312746693351037 {'criterion': 'gini', 'max_depth': 6, 'max_features': 'log2', 'min_samples_leaf': 1, 'min_samples_split': 10}
# means -> %f stds-> (%f) params with: %r 0.8146195563860903 0.029257723997852078 {'criterion': 'gini', 'max_depth': 6, 'max_features': 'log2', 'min_samples_leaf': 2, 'min_samples_split': 2}
# means -> %f stds-> (%f) params with: %r 0.8137051782038782 0.031298280937448957 {'criterion': 'gini', 'max_depth': 6, 'max_features': 'log2', 'min_samples_leaf': 2, 'min_samples_split': 5}
# means -> %f stds-> (%f) params with: %r 0.8037692286859496 0.02543967897270024 {'criterion': 'gini', 'max_depth': 6, 'max_features': 'log2', 'min_samples_leaf': 2, 'min_samples_split': 10}
# means -> %f stds-> (%f) params with: %r 0.7997095385115373 0.03166182867105347 {'criterion': 'gini', 'max_depth': 6, 'max_features': 'log2', 'min_samples_leaf': 4, 'min_samples_split': 2}
# means -> %f stds-> (%f) params with: %r 0.803200492904344 0.023306004594826762 {'criterion': 'gini', 'max_depth': 6, 'max_features': 'log2', 'min_samples_leaf': 4, 'min_samples_split': 5}
# means -> %f stds-> (%f) params with: %r 0.8048613367999135 0.034149364891141606 {'criterion': 'gini', 'max_depth': 6, 'max_features': 'log2', 'min_samples_leaf': 4, 'min_samples_split': 10}
# means -> %f stds-> (%f) params with: %r nan nan {'criterion': 'gini', 'max_depth': 8, 'max_features': 'auto', 'min_samples_leaf': 1, 'min_samples_split': 2}
# means -> %f stds-> (%f) params with: %r nan nan {'criterion': 'gini', 'max_depth': 8, 'max_features': 'auto', 'min_samples_leaf': 1, 'min_samples_split': 5}
# means -> %f stds-> (%f) params with: %r nan nan {'criterion': 'gini', 'max_depth': 8, 'max_features': 'auto', 'min_samples_leaf': 1, 'min_samples_split': 10}
# means -> %f stds-> (%f) params with: %r nan nan {'criterion': 'gini', 'max_depth': 8, 'max_features': 'auto', 'min_samples_leaf': 2, 'min_samples_split': 2}
# means -> %f stds-> (%f) params with: %r nan nan {'criterion': 'gini', 'max_depth': 8, 'max_features': 'auto', 'min_samples_leaf': 2, 'min_samples_split': 5}
# means -> %f stds-> (%f) params with: %r nan nan {'criterion': 'gini', 'max_depth': 8, 'max_features': 'auto', 'min_samples_leaf': 2, 'min_samples_split': 10}
# means -> %f stds-> (%f) params with: %r nan nan {'criterion': 'gini', 'max_depth': 8, 'max_features': 'auto', 'min_samples_leaf': 4, 'min_samples_split': 2}
# means -> %f stds-> (%f) params with: %r nan nan {'criterion': 'gini', 'max_depth': 8, 'max_features': 'auto', 'min_samples_leaf': 4, 'min_samples_split': 5}
# means -> %f stds-> (%f) params with: %r nan nan {'criterion': 'gini', 'max_depth': 8, 'max_features': 'auto', 'min_samples_leaf': 4, 'min_samples_split': 10}
# means -> %f stds-> (%f) params with: %r 0.8315597578810531 0.021162681950430112 {'criterion': 'gini', 'max_depth': 8, 'max_features': 'sqrt', 'min_samples_leaf': 1, 'min_samples_split': 2}
# means -> %f stds-> (%f) params with: %r 0.8337703796988409 0.027905735718414888 {'criterion': 'gini', 'max_depth': 8, 'max_features': 'sqrt', 'min_samples_leaf': 1, 'min_samples_split': 5}
# means -> %f stds-> (%f) params with: %r 0.835610307658975 0.024531879820447734 {'criterion': 'gini', 'max_depth': 8, 'max_features': 'sqrt', 'min_samples_leaf': 1, 'min_samples_split': 10}
# means -> %f stds-> (%f) params with: %r 0.8289804734048316 0.025185676369777414 {'criterion': 'gini', 'max_depth': 8, 'max_features': 'sqrt', 'min_samples_leaf': 2, 'min_samples_split': 2}
# means -> %f stds-> (%f) params with: %r 0.8291751299967501 0.03601973830675421 {'criterion': 'gini', 'max_depth': 8, 'max_features': 'sqrt', 'min_samples_leaf': 2, 'min_samples_split': 5}
# means -> %f stds-> (%f) params with: %r 0.8363483100422489 0.021673540541510286 {'criterion': 'gini', 'max_depth': 8, 'max_features': 'sqrt', 'min_samples_leaf': 2, 'min_samples_split': 10}
# means -> %f stds-> (%f) params with: %r 0.8267708671866536 0.027921017024375556 {'criterion': 'gini', 'max_depth': 8, 'max_features': 'sqrt', 'min_samples_leaf': 4, 'min_samples_split': 2}
# means -> %f stds-> (%f) params with: %r 0.8365338262376774 0.026474784065798555 {'criterion': 'gini', 'max_depth': 8, 'max_features': 'sqrt', 'min_samples_leaf': 4, 'min_samples_split': 5}
# means -> %f stds-> (%f) params with: %r 0.8352413064673383 0.024615385356412178 {'criterion': 'gini', 'max_depth': 8, 'max_features': 'sqrt', 'min_samples_leaf': 4, 'min_samples_split': 10}
# means -> %f stds-> (%f) params with: %r 0.8313732260860146 0.024591282673485666 {'criterion': 'gini', 'max_depth': 8, 'max_features': 'log2', 'min_samples_leaf': 1, 'min_samples_split': 2}
# means -> %f stds-> (%f) params with: %r 0.8398379103022424 0.023256987255051022 {'criterion': 'gini', 'max_depth': 8, 'max_features': 'log2', 'min_samples_leaf': 1, 'min_samples_split': 5}
# means -> %f stds-> (%f) params with: %r 0.8334030711732205 0.016840526175010334 {'criterion': 'gini', 'max_depth': 8, 'max_features': 'log2', 'min_samples_leaf': 1, 'min_samples_split': 10}
# means -> %f stds-> (%f) params with: %r 0.8341383652908678 0.01931482907909302 {'criterion': 'gini', 'max_depth': 8, 'max_features': 'log2', 'min_samples_leaf': 2, 'min_samples_split': 2}
# means -> %f stds-> (%f) params with: %r 0.8304595249702091 0.03601320043650636 {'criterion': 'gini', 'max_depth': 8, 'max_features': 'log2', 'min_samples_leaf': 2, 'min_samples_split': 5}
# means -> %f stds-> (%f) params with: %r 0.8409455909435598 0.02538155599629657 {'criterion': 'gini', 'max_depth': 8, 'max_features': 'log2', 'min_samples_leaf': 2, 'min_samples_split': 10}
# means -> %f stds-> (%f) params with: %r 0.8378226221427798 0.02612151796276203 {'criterion': 'gini', 'max_depth': 8, 'max_features': 'log2', 'min_samples_leaf': 4, 'min_samples_split': 2}
# means -> %f stds-> (%f) params with: %r 0.8378236377423898 0.031063070161461568 {'criterion': 'gini', 'max_depth': 8, 'max_features': 'log2', 'min_samples_leaf': 4, 'min_samples_split': 5}
# means -> %f stds-> (%f) params with: %r 0.8319324829379265 0.03323323863660167 {'criterion': 'gini', 'max_depth': 8, 'max_features': 'log2', 'min_samples_leaf': 4, 'min_samples_split': 10}
# means -> %f stds-> (%f) params with: %r nan nan {'criterion': 'gini', 'max_depth': 10, 'max_features': 'auto', 'min_samples_leaf': 1, 'min_samples_split': 2}
# means -> %f stds-> (%f) params with: %r nan nan {'criterion': 'gini', 'max_depth': 10, 'max_features': 'auto', 'min_samples_leaf': 1, 'min_samples_split': 5}
# means -> %f stds-> (%f) params with: %r nan nan {'criterion': 'gini', 'max_depth': 10, 'max_features': 'auto', 'min_samples_leaf': 1, 'min_samples_split': 10}
# means -> %f stds-> (%f) params with: %r nan nan {'criterion': 'gini', 'max_depth': 10, 'max_features': 'auto', 'min_samples_leaf': 2, 'min_samples_split': 2}
# means -> %f stds-> (%f) params with: %r nan nan {'criterion': 'gini', 'max_depth': 10, 'max_features': 'auto', 'min_samples_leaf': 2, 'min_samples_split': 5}
# means -> %f stds-> (%f) params with: %r nan nan {'criterion': 'gini', 'max_depth': 10, 'max_features': 'auto', 'min_samples_leaf': 2, 'min_samples_split': 10}
# means -> %f stds-> (%f) params with: %r nan nan {'criterion': 'gini', 'max_depth': 10, 'max_features': 'auto', 'min_samples_leaf': 4, 'min_samples_split': 2}
# means -> %f stds-> (%f) params with: %r nan nan {'criterion': 'gini', 'max_depth': 10, 'max_features': 'auto', 'min_samples_leaf': 4, 'min_samples_split': 5}
# means -> %f stds-> (%f) params with: %r nan nan {'criterion': 'gini', 'max_depth': 10, 'max_features': 'auto', 'min_samples_leaf': 4, 'min_samples_split': 10}
# means -> %f stds-> (%f) params with: %r 0.8588123578160545 0.028501891069398017 {'criterion': 'gini', 'max_depth': 10, 'max_features': 'sqrt', 'min_samples_leaf': 1, 'min_samples_split': 2}
# means -> %f stds-> (%f) params with: %r 0.856418928068465 0.03065596771856933 {'criterion': 'gini', 'max_depth': 10, 'max_features': 'sqrt', 'min_samples_leaf': 1, 'min_samples_split': 5}
# means -> %f stds-> (%f) params with: %r 0.856413850070415 0.025902464037990854 {'criterion': 'gini', 'max_depth': 10, 'max_features': 'sqrt', 'min_samples_leaf': 1, 'min_samples_split': 10}
# means -> %f stds-> (%f) params with: %r 0.8455560746398005 0.02910418392558374 {'criterion': 'gini', 'max_depth': 10, 'max_features': 'sqrt', 'min_samples_leaf': 2, 'min_samples_split': 2}
# means -> %f stds-> (%f) params with: %r 0.8634062533853321 0.022721352155077736 {'criterion': 'gini', 'max_depth': 10, 'max_features': 'sqrt', 'min_samples_leaf': 2, 'min_samples_split': 5}
# means -> %f stds-> (%f) params with: %r 0.860651270176579 0.02841984146088075 {'criterion': 'gini', 'max_depth': 10, 'max_features': 'sqrt', 'min_samples_leaf': 2, 'min_samples_split': 10}
# means -> %f stds-> (%f) params with: %r 0.8656202605351533 0.03327788497127322 {'criterion': 'gini', 'max_depth': 10, 'max_features': 'sqrt', 'min_samples_leaf': 4, 'min_samples_split': 2}
# means -> %f stds-> (%f) params with: %r 0.8543887444480556 0.01871118010367184 {'criterion': 'gini', 'max_depth': 10, 'max_features': 'sqrt', 'min_samples_leaf': 4, 'min_samples_split': 5}
# means -> %f stds-> (%f) params with: %r 0.8554964250893727 0.03421264725727898 {'criterion': 'gini', 'max_depth': 10, 'max_features': 'sqrt', 'min_samples_leaf': 4, 'min_samples_split': 10}
# means -> %f stds-> (%f) params with: %r 0.8531016412089697 0.021311779736756842 {'criterion': 'gini', 'max_depth': 10, 'max_features': 'log2', 'min_samples_leaf': 1, 'min_samples_split': 2}
# means -> %f stds-> (%f) params with: %r 0.8575188224461054 0.02432194327590706 {'criterion': 'gini', 'max_depth': 10, 'max_features': 'log2', 'min_samples_leaf': 1, 'min_samples_split': 5}
# means -> %f stds-> (%f) params with: %r 0.8547570685732856 0.02725976058087852 {'criterion': 'gini', 'max_depth': 10, 'max_features': 'log2', 'min_samples_leaf': 1, 'min_samples_split': 10}
# means -> %f stds-> (%f) params with: %r 0.8540224515220454 0.02569167713808185 {'criterion': 'gini', 'max_depth': 10, 'max_features': 'log2', 'min_samples_leaf': 2, 'min_samples_split': 2}
# means -> %f stds-> (%f) params with: %r 0.853101979742173 0.02797699336084112 {'criterion': 'gini', 'max_depth': 10, 'max_features': 'log2', 'min_samples_leaf': 2, 'min_samples_split': 5}
# means -> %f stds-> (%f) params with: %r 0.8578847768389124 0.027120367072018946 {'criterion': 'gini', 'max_depth': 10, 'max_features': 'log2', 'min_samples_leaf': 2, 'min_samples_split': 10}
# means -> %f stds-> (%f) params with: %r 0.8494231394215145 0.03756679555029034 {'criterion': 'gini', 'max_depth': 10, 'max_features': 'log2', 'min_samples_leaf': 4, 'min_samples_split': 2}
# means -> %f stds-> (%f) params with: %r 0.8477683891236053 0.037252986704745195 {'criterion': 'gini', 'max_depth': 10, 'max_features': 'log2', 'min_samples_leaf': 4, 'min_samples_split': 5}
# means -> %f stds-> (%f) params with: %r 0.8578840997725058 0.0252263448749197 {'criterion': 'gini', 'max_depth': 10, 'max_features': 'log2', 'min_samples_leaf': 4, 'min_samples_split': 10}
# means -> %f stds-> (%f) params with: %r nan nan {'criterion': 'entropy', 'max_depth': 2, 'max_features': 'auto', 'min_samples_leaf': 1, 'min_samples_split': 2}
# means -> %f stds-> (%f) params with: %r nan nan {'criterion': 'entropy', 'max_depth': 2, 'max_features': 'auto', 'min_samples_leaf': 1, 'min_samples_split': 5}
# means -> %f stds-> (%f) params with: %r nan nan {'criterion': 'entropy', 'max_depth': 2, 'max_features': 'auto', 'min_samples_leaf': 1, 'min_samples_split': 10}
# means -> %f stds-> (%f) params with: %r nan nan {'criterion': 'entropy', 'max_depth': 2, 'max_features': 'auto', 'min_samples_leaf': 2, 'min_samples_split': 2}
# means -> %f stds-> (%f) params with: %r nan nan {'criterion': 'entropy', 'max_depth': 2, 'max_features': 'auto', 'min_samples_leaf': 2, 'min_samples_split': 5}
# means -> %f stds-> (%f) params with: %r nan nan {'criterion': 'entropy', 'max_depth': 2, 'max_features': 'auto', 'min_samples_leaf': 2, 'min_samples_split': 10}
# means -> %f stds-> (%f) params with: %r nan nan {'criterion': 'entropy', 'max_depth': 2, 'max_features': 'auto', 'min_samples_leaf': 4, 'min_samples_split': 2}
# means -> %f stds-> (%f) params with: %r nan nan {'criterion': 'entropy', 'max_depth': 2, 'max_features': 'auto', 'min_samples_leaf': 4, 'min_samples_split': 5}
# means -> %f stds-> (%f) params with: %r nan nan {'criterion': 'entropy', 'max_depth': 2, 'max_features': 'auto', 'min_samples_leaf': 4, 'min_samples_split': 10}
# means -> %f stds-> (%f) params with: %r 0.7054838993608492 0.06631467686608651 {'criterion': 'entropy', 'max_depth': 2, 'max_features': 'sqrt', 'min_samples_leaf': 1, 'min_samples_split': 2}
# means -> %f stds-> (%f) params with: %r 0.7046917316650416 0.0664704719414384 {'criterion': 'entropy', 'max_depth': 2, 'max_features': 'sqrt', 'min_samples_leaf': 1, 'min_samples_split': 5}
# means -> %f stds-> (%f) params with: %r 0.694247982342108 0.07018238192038481 {'criterion': 'entropy', 'max_depth': 2, 'max_features': 'sqrt', 'min_samples_leaf': 1, 'min_samples_split': 10}
# means -> %f stds-> (%f) params with: %r 0.6999306006933159 0.07077859893327704 {'criterion': 'entropy', 'max_depth': 2, 'max_features': 'sqrt', 'min_samples_leaf': 2, 'min_samples_split': 2}
# means -> %f stds-> (%f) params with: %r 0.7010494529303434 0.0683808808364992 {'criterion': 'entropy', 'max_depth': 2, 'max_features': 'sqrt', 'min_samples_leaf': 2, 'min_samples_split': 5}
# means -> %f stds-> (%f) params with: %r 0.7203458455205286 0.06122233663065575 {'criterion': 'entropy', 'max_depth': 2, 'max_features': 'sqrt', 'min_samples_leaf': 2, 'min_samples_split': 10}
# means -> %f stds-> (%f) params with: %r 0.6916890098580868 0.07877799933546319 {'criterion': 'entropy', 'max_depth': 2, 'max_features': 'sqrt', 'min_samples_leaf': 4, 'min_samples_split': 2}
# means -> %f stds-> (%f) params with: %r 0.6798549046690501 0.06767774394271613 {'criterion': 'entropy', 'max_depth': 2, 'max_features': 'sqrt', 'min_samples_leaf': 4, 'min_samples_split': 5}
# means -> %f stds-> (%f) params with: %r 0.675835838479038 0.061693386181666185 {'criterion': 'entropy', 'max_depth': 2, 'max_features': 'sqrt', 'min_samples_leaf': 4, 'min_samples_split': 10}
# means -> %f stds-> (%f) params with: %r 0.7288189930668401 0.050624110433282854 {'criterion': 'entropy', 'max_depth': 2, 'max_features': 'log2', 'min_samples_leaf': 1, 'min_samples_split': 2}
# means -> %f stds-> (%f) params with: %r 0.7039889367349149 0.06047261030610447 {'criterion': 'entropy', 'max_depth': 2, 'max_features': 'log2', 'min_samples_leaf': 1, 'min_samples_split': 5}
# means -> %f stds-> (%f) params with: %r 0.7102165935434949 0.051098008425037304 {'criterion': 'entropy', 'max_depth': 2, 'max_features': 'log2', 'min_samples_leaf': 1, 'min_samples_split': 10}
# means -> %f stds-> (%f) params with: %r 0.6769357328566786 0.06990105576501159 {'criterion': 'entropy', 'max_depth': 2, 'max_features': 'log2', 'min_samples_leaf': 2, 'min_samples_split': 2}
# means -> %f stds-> (%f) params with: %r 0.7154134167479147 0.06405883956011711 {'criterion': 'entropy', 'max_depth': 2, 'max_features': 'log2', 'min_samples_leaf': 2, 'min_samples_split': 5}
# means -> %f stds-> (%f) params with: %r 0.728846075723107 0.05267664017937917 {'criterion': 'entropy', 'max_depth': 2, 'max_features': 'log2', 'min_samples_leaf': 2, 'min_samples_split': 10}
# means -> %f stds-> (%f) params with: %r 0.694612921135305 0.0687760173395373 {'criterion': 'entropy', 'max_depth': 2, 'max_features': 'log2', 'min_samples_leaf': 4, 'min_samples_split': 2}
# means -> %f stds-> (%f) params with: %r 0.7144523209836421 0.06001207383171975 {'criterion': 'entropy', 'max_depth': 2, 'max_features': 'log2', 'min_samples_leaf': 4, 'min_samples_split': 5}
# means -> %f stds-> (%f) params with: %r 0.7130091539378183 0.06779883479423222 {'criterion': 'entropy', 'max_depth': 2, 'max_features': 'log2', 'min_samples_leaf': 4, 'min_samples_split': 10}
# means -> %f stds-> (%f) params with: %r nan nan {'criterion': 'entropy', 'max_depth': 4, 'max_features': 'auto', 'min_samples_leaf': 1, 'min_samples_split': 2}
# means -> %f stds-> (%f) params with: %r nan nan {'criterion': 'entropy', 'max_depth': 4, 'max_features': 'auto', 'min_samples_leaf': 1, 'min_samples_split': 5}
# means -> %f stds-> (%f) params with: %r nan nan {'criterion': 'entropy', 'max_depth': 4, 'max_features': 'auto', 'min_samples_leaf': 1, 'min_samples_split': 10}
# means -> %f stds-> (%f) params with: %r nan nan {'criterion': 'entropy', 'max_depth': 4, 'max_features': 'auto', 'min_samples_leaf': 2, 'min_samples_split': 2}
# means -> %f stds-> (%f) params with: %r nan nan {'criterion': 'entropy', 'max_depth': 4, 'max_features': 'auto', 'min_samples_leaf': 2, 'min_samples_split': 5}
# means -> %f stds-> (%f) params with: %r nan nan {'criterion': 'entropy', 'max_depth': 4, 'max_features': 'auto', 'min_samples_leaf': 2, 'min_samples_split': 10}
# means -> %f stds-> (%f) params with: %r nan nan {'criterion': 'entropy', 'max_depth': 4, 'max_features': 'auto', 'min_samples_leaf': 4, 'min_samples_split': 2}
# means -> %f stds-> (%f) params with: %r nan nan {'criterion': 'entropy', 'max_depth': 4, 'max_features': 'auto', 'min_samples_leaf': 4, 'min_samples_split': 5}
# means -> %f stds-> (%f) params with: %r nan nan {'criterion': 'entropy', 'max_depth': 4, 'max_features': 'auto', 'min_samples_leaf': 4, 'min_samples_split': 10}
# means -> %f stds-> (%f) params with: %r 0.7142762837179071 0.044656218821368845 {'criterion': 'entropy', 'max_depth': 4, 'max_features': 'sqrt', 'min_samples_leaf': 1, 'min_samples_split': 2}
# means -> %f stds-> (%f) params with: %r 0.7557185028707616 0.036168124367888396 {'criterion': 'entropy', 'max_depth': 4, 'max_features': 'sqrt', 'min_samples_leaf': 1, 'min_samples_split': 5}
# means -> %f stds-> (%f) params with: %r 0.7680397573393998 0.03679347250029696 {'criterion': 'entropy', 'max_depth': 4, 'max_features': 'sqrt', 'min_samples_leaf': 1, 'min_samples_split': 10}
# means -> %f stds-> (%f) params with: %r 0.750552147654642 0.02517266696914599 {'criterion': 'entropy', 'max_depth': 4, 'max_features': 'sqrt', 'min_samples_leaf': 2, 'min_samples_split': 2}
# means -> %f stds-> (%f) params with: %r 0.7678660898060883 0.03143782614268179 {'criterion': 'entropy', 'max_depth': 4, 'max_features': 'sqrt', 'min_samples_leaf': 2, 'min_samples_split': 5}
# means -> %f stds-> (%f) params with: %r 0.7439351776622252 0.035536761227731854 {'criterion': 'entropy', 'max_depth': 4, 'max_features': 'sqrt', 'min_samples_leaf': 2, 'min_samples_split': 10}
# means -> %f stds-> (%f) params with: %r 0.7431707696890912 0.04456234976810846 {'criterion': 'entropy', 'max_depth': 4, 'max_features': 'sqrt', 'min_samples_leaf': 4, 'min_samples_split': 2}
# means -> %f stds-> (%f) params with: %r 0.7606675197703391 0.039645710726749946 {'criterion': 'entropy', 'max_depth': 4, 'max_features': 'sqrt', 'min_samples_leaf': 4, 'min_samples_split': 5}
# means -> %f stds-> (%f) params with: %r 0.7603110443072257 0.036654809141968336 {'criterion': 'entropy', 'max_depth': 4, 'max_features': 'sqrt', 'min_samples_leaf': 4, 'min_samples_split': 10}
# means -> %f stds-> (%f) params with: %r 0.7669320766980826 0.04094718047094204 {'criterion': 'entropy', 'max_depth': 4, 'max_features': 'log2', 'min_samples_leaf': 1, 'min_samples_split': 2}
# means -> %f stds-> (%f) params with: %r 0.7536873036507421 0.04514647517251979 {'criterion': 'entropy', 'max_depth': 4, 'max_features': 'log2', 'min_samples_leaf': 1, 'min_samples_split': 5}
# means -> %f stds-> (%f) params with: %r 0.7616143971400715 0.03593588483625808 {'criterion': 'entropy', 'max_depth': 4, 'max_features': 'log2', 'min_samples_leaf': 1, 'min_samples_split': 10}
# means -> %f stds-> (%f) params with: %r 0.7557053000758315 0.02626256982533221 {'criterion': 'entropy', 'max_depth': 4, 'max_features': 'log2', 'min_samples_leaf': 2, 'min_samples_split': 2}
# means -> %f stds-> (%f) params with: %r 0.7580987298234212 0.019168150926086557 {'criterion': 'entropy', 'max_depth': 4, 'max_features': 'log2', 'min_samples_leaf': 2, 'min_samples_split': 5}
# means -> %f stds-> (%f) params with: %r 0.7516561044307226 0.04436514806999804 {'criterion': 'entropy', 'max_depth': 4, 'max_features': 'log2', 'min_samples_leaf': 2, 'min_samples_split': 10}
# means -> %f stds-> (%f) params with: %r 0.7647424439389015 0.0328771976697851 {'criterion': 'entropy', 'max_depth': 4, 'max_features': 'log2', 'min_samples_leaf': 4, 'min_samples_split': 2}
# means -> %f stds-> (%f) params with: %r 0.7669266601668292 0.047920506153170575 {'criterion': 'entropy', 'max_depth': 4, 'max_features': 'log2', 'min_samples_leaf': 4, 'min_samples_split': 5}
# means -> %f stds-> (%f) params with: %r 0.7658399685841186 0.01996760168573414 {'criterion': 'entropy', 'max_depth': 4, 'max_features': 'log2', 'min_samples_leaf': 4, 'min_samples_split': 10}
# means -> %f stds-> (%f) params with: %r nan nan {'criterion': 'entropy', 'max_depth': 6, 'max_features': 'auto', 'min_samples_leaf': 1, 'min_samples_split': 2}
# means -> %f stds-> (%f) params with: %r nan nan {'criterion': 'entropy', 'max_depth': 6, 'max_features': 'auto', 'min_samples_leaf': 1, 'min_samples_split': 5}
# means -> %f stds-> (%f) params with: %r nan nan {'criterion': 'entropy', 'max_depth': 6, 'max_features': 'auto', 'min_samples_leaf': 1, 'min_samples_split': 10}
# means -> %f stds-> (%f) params with: %r nan nan {'criterion': 'entropy', 'max_depth': 6, 'max_features': 'auto', 'min_samples_leaf': 2, 'min_samples_split': 2}
# means -> %f stds-> (%f) params with: %r nan nan {'criterion': 'entropy', 'max_depth': 6, 'max_features': 'auto', 'min_samples_leaf': 2, 'min_samples_split': 5}
# means -> %f stds-> (%f) params with: %r nan nan {'criterion': 'entropy', 'max_depth': 6, 'max_features': 'auto', 'min_samples_leaf': 2, 'min_samples_split': 10}
# means -> %f stds-> (%f) params with: %r nan nan {'criterion': 'entropy', 'max_depth': 6, 'max_features': 'auto', 'min_samples_leaf': 4, 'min_samples_split': 2}
# means -> %f stds-> (%f) params with: %r nan nan {'criterion': 'entropy', 'max_depth': 6, 'max_features': 'auto', 'min_samples_leaf': 4, 'min_samples_split': 5}
# means -> %f stds-> (%f) params with: %r nan nan {'criterion': 'entropy', 'max_depth': 6, 'max_features': 'auto', 'min_samples_leaf': 4, 'min_samples_split': 10}
# means -> %f stds-> (%f) params with: %r 0.7940052540353159 0.03328868132984879 {'criterion': 'entropy', 'max_depth': 6, 'max_features': 'sqrt', 'min_samples_leaf': 1, 'min_samples_split': 2}
# means -> %f stds-> (%f) params with: %r 0.7927052865345033 0.026329069690843282 {'criterion': 'entropy', 'max_depth': 6, 'max_features': 'sqrt', 'min_samples_leaf': 1, 'min_samples_split': 5}
# means -> %f stds-> (%f) params with: %r 0.7947449490846062 0.034897847670419806 {'criterion': 'entropy', 'max_depth': 6, 'max_features': 'sqrt', 'min_samples_leaf': 1, 'min_samples_split': 10}
# means -> %f stds-> (%f) params with: %r 0.794371546961326 0.022319732295154323 {'criterion': 'entropy', 'max_depth': 6, 'max_features': 'sqrt', 'min_samples_leaf': 2, 'min_samples_split': 2}
# means -> %f stds-> (%f) params with: %r 0.80449775213953 0.029691038755639713 {'criterion': 'entropy', 'max_depth': 6, 'max_features': 'sqrt', 'min_samples_leaf': 2, 'min_samples_split': 5}
# means -> %f stds-> (%f) params with: %r 0.7927076562669266 0.023101624224955482 {'criterion': 'entropy', 'max_depth': 6, 'max_features': 'sqrt', 'min_samples_leaf': 2, 'min_samples_split': 10}
# means -> %f stds-> (%f) params with: %r 0.7873804977792223 0.038991104966121876 {'criterion': 'entropy', 'max_depth': 6, 'max_features': 'sqrt', 'min_samples_leaf': 4, 'min_samples_split': 2}
# means -> %f stds-> (%f) params with: %r 0.8033971806954826 0.036049709872298885 {'criterion': 'entropy', 'max_depth': 6, 'max_features': 'sqrt', 'min_samples_leaf': 4, 'min_samples_split': 5}
# means -> %f stds-> (%f) params with: %r 0.8124109657675225 0.024049613113635793 {'criterion': 'entropy', 'max_depth': 6, 'max_features': 'sqrt', 'min_samples_leaf': 4, 'min_samples_split': 10}
# means -> %f stds-> (%f) params with: %r 0.7958377342649767 0.01765256882057675 {'criterion': 'entropy', 'max_depth': 6, 'max_features': 'log2', 'min_samples_leaf': 1, 'min_samples_split': 2}
# means -> %f stds-> (%f) params with: %r 0.8070665420864479 0.03450395948768748 {'criterion': 'entropy', 'max_depth': 6, 'max_features': 'log2', 'min_samples_leaf': 1, 'min_samples_split': 5}
# means -> %f stds-> (%f) params with: %r 0.7914181832954177 0.045166671053230065 {'criterion': 'entropy', 'max_depth': 6, 'max_features': 'log2', 'min_samples_leaf': 1, 'min_samples_split': 10}
# means -> %f stds-> (%f) params with: %r 0.7886554138229878 0.030083536580476005 {'criterion': 'entropy', 'max_depth': 6, 'max_features': 'log2', 'min_samples_leaf': 2, 'min_samples_split': 2}
# means -> %f stds-> (%f) params with: %r 0.799891330841729 0.01949451587716148 {'criterion': 'entropy', 'max_depth': 6, 'max_features': 'log2', 'min_samples_leaf': 2, 'min_samples_split': 5}
# means -> %f stds-> (%f) params with: %r 0.7973130619651176 0.019509664129031143 {'criterion': 'entropy', 'max_depth': 6, 'max_features': 'log2', 'min_samples_leaf': 2, 'min_samples_split': 10}
# means -> %f stds-> (%f) params with: %r 0.7923599826671001 0.030537170557277164 {'criterion': 'entropy', 'max_depth': 6, 'max_features': 'log2', 'min_samples_leaf': 4, 'min_samples_split': 2}
# means -> %f stds-> (%f) params with: %r 0.7906906754414472 0.02948659305890779 {'criterion': 'entropy', 'max_depth': 6, 'max_features': 'log2', 'min_samples_leaf': 4, 'min_samples_split': 5}
# means -> %f stds-> (%f) params with: %r 0.7969532011699709 0.02820488079078428 {'criterion': 'entropy', 'max_depth': 6, 'max_features': 'log2', 'min_samples_leaf': 4, 'min_samples_split': 10}
# means -> %f stds-> (%f) params with: %r nan nan {'criterion': 'entropy', 'max_depth': 8, 'max_features': 'auto', 'min_samples_leaf': 1, 'min_samples_split': 2}
# means -> %f stds-> (%f) params with: %r nan nan {'criterion': 'entropy', 'max_depth': 8, 'max_features': 'auto', 'min_samples_leaf': 1, 'min_samples_split': 5}
# means -> %f stds-> (%f) params with: %r nan nan {'criterion': 'entropy', 'max_depth': 8, 'max_features': 'auto', 'min_samples_leaf': 1, 'min_samples_split': 10}
# means -> %f stds-> (%f) params with: %r nan nan {'criterion': 'entropy', 'max_depth': 8, 'max_features': 'auto', 'min_samples_leaf': 2, 'min_samples_split': 2}
# means -> %f stds-> (%f) params with: %r nan nan {'criterion': 'entropy', 'max_depth': 8, 'max_features': 'auto', 'min_samples_leaf': 2, 'min_samples_split': 5}
# means -> %f stds-> (%f) params with: %r nan nan {'criterion': 'entropy', 'max_depth': 8, 'max_features': 'auto', 'min_samples_leaf': 2, 'min_samples_split': 10}
# means -> %f stds-> (%f) params with: %r nan nan {'criterion': 'entropy', 'max_depth': 8, 'max_features': 'auto', 'min_samples_leaf': 4, 'min_samples_split': 2}
# means -> %f stds-> (%f) params with: %r nan nan {'criterion': 'entropy', 'max_depth': 8, 'max_features': 'auto', 'min_samples_leaf': 4, 'min_samples_split': 5}
# means -> %f stds-> (%f) params with: %r nan nan {'criterion': 'entropy', 'max_depth': 8, 'max_features': 'auto', 'min_samples_leaf': 4, 'min_samples_split': 10}
# means -> %f stds-> (%f) params with: %r 0.8324849691257719 0.0356919109911466 {'criterion': 'entropy', 'max_depth': 8, 'max_features': 'sqrt', 'min_samples_leaf': 1, 'min_samples_split': 2}
# means -> %f stds-> (%f) params with: %r 0.8300874769797423 0.024887302176857598 {'criterion': 'entropy', 'max_depth': 8, 'max_features': 'sqrt', 'min_samples_leaf': 1, 'min_samples_split': 5}
# means -> %f stds-> (%f) params with: %r 0.8295343137254901 0.02548274200669967 {'criterion': 'entropy', 'max_depth': 8, 'max_features': 'sqrt', 'min_samples_leaf': 1, 'min_samples_split': 10}
# means -> %f stds-> (%f) params with: %r 0.8221661385548694 0.020600742642048482 {'criterion': 'entropy', 'max_depth': 8, 'max_features': 'sqrt', 'min_samples_leaf': 2, 'min_samples_split': 2}
# means -> %f stds-> (%f) params with: %r 0.82640829812588 0.023927209360606 {'criterion': 'entropy', 'max_depth': 8, 'max_features': 'sqrt', 'min_samples_leaf': 2, 'min_samples_split': 5}
# means -> %f stds-> (%f) params with: %r 0.8216217771639043 0.029116635075977636 {'criterion': 'entropy', 'max_depth': 8, 'max_features': 'sqrt', 'min_samples_leaf': 2, 'min_samples_split': 10}
# means -> %f stds-> (%f) params with: %r 0.8194142021449464 0.0320785086010033 {'criterion': 'entropy', 'max_depth': 8, 'max_features': 'sqrt', 'min_samples_leaf': 4, 'min_samples_split': 2}
# means -> %f stds-> (%f) params with: %r 0.8321135982017116 0.029025141145004416 {'criterion': 'entropy', 'max_depth': 8, 'max_features': 'sqrt', 'min_samples_leaf': 4, 'min_samples_split': 5}
# means -> %f stds-> (%f) params with: %r 0.8162766764164229 0.030302806637697247 {'criterion': 'entropy', 'max_depth': 8, 'max_features': 'sqrt', 'min_samples_leaf': 4, 'min_samples_split': 10}
# means -> %f stds-> (%f) params with: %r 0.8275132705015709 0.027261283314772882 {'criterion': 'entropy', 'max_depth': 8, 'max_features': 'log2', 'min_samples_leaf': 1, 'min_samples_split': 2}
# means -> %f stds-> (%f) params with: %r 0.8284300184162063 0.022116072336896674 {'criterion': 'entropy', 'max_depth': 8, 'max_features': 'log2', 'min_samples_leaf': 1, 'min_samples_split': 5}
# means -> %f stds-> (%f) params with: %r 0.8094731746289676 0.02732261659524801 {'criterion': 'entropy', 'max_depth': 8, 'max_features': 'log2', 'min_samples_leaf': 1, 'min_samples_split': 10}
# means -> %f stds-> (%f) params with: %r 0.8300901852453689 0.025526558648976967 {'criterion': 'entropy', 'max_depth': 8, 'max_features': 'log2', 'min_samples_leaf': 2, 'min_samples_split': 2}
# means -> %f stds-> (%f) params with: %r 0.8264086366590835 0.029388625589560822 {'criterion': 'entropy', 'max_depth': 8, 'max_features': 'log2', 'min_samples_leaf': 2, 'min_samples_split': 5}
# means -> %f stds-> (%f) params with: %r 0.8256686030765896 0.020095342609947255 {'criterion': 'entropy', 'max_depth': 8, 'max_features': 'log2', 'min_samples_leaf': 2, 'min_samples_split': 10}
# means -> %f stds-> (%f) params with: %r 0.8267728983858739 0.024454268244562146 {'criterion': 'entropy', 'max_depth': 8, 'max_features': 'log2', 'min_samples_leaf': 4, 'min_samples_split': 2}
# means -> %f stds-> (%f) params with: %r 0.8238276595168454 0.025775232509838614 {'criterion': 'entropy', 'max_depth': 8, 'max_features': 'log2', 'min_samples_leaf': 4, 'min_samples_split': 5}
# means -> %f stds-> (%f) params with: %r 0.8262237975300618 0.02358671590320168 {'criterion': 'entropy', 'max_depth': 8, 'max_features': 'log2', 'min_samples_leaf': 4, 'min_samples_split': 10}
# means -> %f stds-> (%f) params with: %r nan nan {'criterion': 'entropy', 'max_depth': 10, 'max_features': 'auto', 'min_samples_leaf': 1, 'min_samples_split': 2}
# means -> %f stds-> (%f) params with: %r nan nan {'criterion': 'entropy', 'max_depth': 10, 'max_features': 'auto', 'min_samples_leaf': 1, 'min_samples_split': 5}
# means -> %f stds-> (%f) params with: %r nan nan {'criterion': 'entropy', 'max_depth': 10, 'max_features': 'auto', 'min_samples_leaf': 1, 'min_samples_split': 10}
# means -> %f stds-> (%f) params with: %r nan nan {'criterion': 'entropy', 'max_depth': 10, 'max_features': 'auto', 'min_samples_leaf': 2, 'min_samples_split': 2}
# means -> %f stds-> (%f) params with: %r nan nan {'criterion': 'entropy', 'max_depth': 10, 'max_features': 'auto', 'min_samples_leaf': 2, 'min_samples_split': 5}
# means -> %f stds-> (%f) params with: %r nan nan {'criterion': 'entropy', 'max_depth': 10, 'max_features': 'auto', 'min_samples_leaf': 2, 'min_samples_split': 10}
# means -> %f stds-> (%f) params with: %r nan nan {'criterion': 'entropy', 'max_depth': 10, 'max_features': 'auto', 'min_samples_leaf': 4, 'min_samples_split': 2}
# means -> %f stds-> (%f) params with: %r nan nan {'criterion': 'entropy', 'max_depth': 10, 'max_features': 'auto', 'min_samples_leaf': 4, 'min_samples_split': 5}
# means -> %f stds-> (%f) params with: %r nan nan {'criterion': 'entropy', 'max_depth': 10, 'max_features': 'auto', 'min_samples_leaf': 4, 'min_samples_split': 10}
# means -> %f stds-> (%f) params with: %r 0.8457446376340592 0.039731014622658094 {'criterion': 'entropy', 'max_depth': 10, 'max_features': 'sqrt', 'min_samples_leaf': 1, 'min_samples_split': 2}
# means -> %f stds-> (%f) params with: %r 0.854761469504929 0.024318125805791565 {'criterion': 'entropy', 'max_depth': 10, 'max_features': 'sqrt', 'min_samples_leaf': 1, 'min_samples_split': 5}
# means -> %f stds-> (%f) params with: %r 0.8531043494745966 0.029647368507650984 {'criterion': 'entropy', 'max_depth': 10, 'max_features': 'sqrt', 'min_samples_leaf': 1, 'min_samples_split': 10}
# means -> %f stds-> (%f) params with: %r 0.8433444372224027 0.02294808474972945 {'criterion': 'entropy', 'max_depth': 10, 'max_features': 'sqrt', 'min_samples_leaf': 2, 'min_samples_split': 2}
# means -> %f stds-> (%f) params with: %r 0.848128249918752 0.027029072443788695 {'criterion': 'entropy', 'max_depth': 10, 'max_features': 'sqrt', 'min_samples_leaf': 2, 'min_samples_split': 5}
# means -> %f stds-> (%f) params with: %r 0.8543900985808687 0.026604018185700427 {'criterion': 'entropy', 'max_depth': 10, 'max_features': 'sqrt', 'min_samples_leaf': 2, 'min_samples_split': 10}
# means -> %f stds-> (%f) params with: %r 0.8431619678258044 0.03386374040865598 {'criterion': 'entropy', 'max_depth': 10, 'max_features': 'sqrt', 'min_samples_leaf': 4, 'min_samples_split': 2}
# means -> %f stds-> (%f) params with: %r 0.8608357707723974 0.02897845078758515 {'criterion': 'entropy', 'max_depth': 10, 'max_features': 'sqrt', 'min_samples_leaf': 4, 'min_samples_split': 5}
# means -> %f stds-> (%f) params with: %r 0.8525549100855813 0.0317690261616412 {'criterion': 'entropy', 'max_depth': 10, 'max_features': 'sqrt', 'min_samples_leaf': 4, 'min_samples_split': 10}
# means -> %f stds-> (%f) params with: %r 0.846469775755606 0.022354913709403047 {'criterion': 'entropy', 'max_depth': 10, 'max_features': 'log2', 'min_samples_leaf': 1, 'min_samples_split': 2}
# means -> %f stds-> (%f) params with: %r 0.8538372738598202 0.026184242116258225 {'criterion': 'entropy', 'max_depth': 10, 'max_features': 'log2', 'min_samples_leaf': 1, 'min_samples_split': 5}
# means -> %f stds-> (%f) params with: %r 0.8545759533095005 0.02811183790933675 {'criterion': 'entropy', 'max_depth': 10, 'max_features': 'log2', 'min_samples_leaf': 1, 'min_samples_split': 10}
# means -> %f stds-> (%f) params with: %r 0.8547577456396924 0.02600702901046931 {'criterion': 'entropy', 'max_depth': 10, 'max_features': 'log2', 'min_samples_leaf': 2, 'min_samples_split': 2}
# means -> %f stds-> (%f) params with: %r 0.8547590997725057 0.024552461868496613 {'criterion': 'entropy', 'max_depth': 10, 'max_features': 'log2', 'min_samples_leaf': 2, 'min_samples_split': 5}
# means -> %f stds-> (%f) params with: %r 0.8479478117213736 0.02695909061682662 {'criterion': 'entropy', 'max_depth': 10, 'max_features': 'log2', 'min_samples_leaf': 2, 'min_samples_split': 10}
# means -> %f stds-> (%f) params with: %r 0.8505226952659518 0.024302425237116832 {'criterion': 'entropy', 'max_depth': 10, 'max_features': 'log2', 'min_samples_leaf': 4, 'min_samples_split': 2}
# means -> %f stds-> (%f) params with: %r 0.8617555654858629 0.02494652778928829 {'criterion': 'entropy', 'max_depth': 10, 'max_features': 'log2', 'min_samples_leaf': 4, 'min_samples_split': 5}
# means -> %f stds-> (%f) params with: %r 0.8496032390856895 0.02901937364066834 {'criterion': 'entropy', 'max_depth': 10, 'max_features': 'log2', 'min_samples_leaf': 4, 'min_samples_split': 10}

# %%
clfModel_BestParam = tree.DecisionTreeClassifier(
    max_depth=best_params['max_depth'],
    min_samples_split=best_params['min_samples_split'],
    min_samples_leaf=best_params['min_samples_leaf'],
    max_features=best_params['max_features'],
    criterion=best_params['criterion']
)

# %%
clfModel_BestParam.fit(X_train_scaled, y_train_smote)
# Out:
# DecisionTreeClassifier(max_depth=10, max_features='log2', min_samples_leaf=4,
#                        min_samples_split=5)

# %%
print("ตัวอย่างข้อมูลชุดเรียนรู้ ->",clfModel_BestParam.score(X_train_scaled, y_train_smote))
# Out:
# ตัวอย่างข้อมูลชุดเรียนรู้ -> 0.8718703976435935

# %%
plt.figure(figsize=(12, 6))
tree.plot_tree(clfModel_BestParam.fit(X_train_scaled,y_train_smote))
plt.show()

# %%
y_pred = clfModel_BestParam.predict(X_test_scaled)
print("ตัวอย่างข้อมูลชุดทดสอบ ->",accuracy_score(y_test, y_pred))
# Out:
# ตัวอย่างข้อมูลชุดทดสอบ -> 0.7894308943089431

# %%
pd.crosstab(y_test, y_pred)
# Out:
# col_0        0    1
# alzheimer
# 0          934  211
# 1           48   37

# %%
print("Classification Report:\n", classification_report(y_test, y_pred))
# Out:
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.95      0.82      0.88      1145
#            1       0.15      0.44      0.22        85
#
#     accuracy                           0.79      1230
#    macro avg       0.55      0.63      0.55      1230
# weighted avg       0.90      0.79      0.83      1230

# %%
plt.figure(figsize=(12, 6))
tree.plot_tree(clfModel_BestParam.fit(X_test_scaled,y_test))
plt.show()
