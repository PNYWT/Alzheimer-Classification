# %%
import pandas as pd
import numpy as np

# %%
dataSet = pd.read_csv("Alzheimer.csv")
dataSet
# Out:
#          HN         Education   age  hypertension  heart_disease  \
# 0     11046  Secondary School  67.0             0              1
# 1     51676          Bachelor  61.0             0              0
# 2     35112  Secondary School  80.0             0              1
# 3     67182          Bachelor  49.0             0              0
# 4      1665          Bachelor  79.0             1              0
# ...     ...               ...   ...           ...            ...
# 4095  68398  Secondary School  82.0             1              0
# 4096  14180          Bachelor  13.0             0              0
# 4097  44873          Bachelor  81.0             0              0
# 4098  19723          Bachelor  35.0             0              0
# 4099  44679          Bachelor  44.0             0              0
#
#      family history Occupation Triglycerides  Blood Sugar   BMI  \
# 0               Yes    Private        Normal       228.69  36.6
# 1               Yes  Freelance          High       202.21   NaN
# 2               Yes    Private          High       105.92  32.5
# 3               Yes    Private        Normal       171.23  34.4
# 4               Yes  Freelance          High       174.12  24.0
# ...             ...        ...           ...          ...   ...
# 4095            Yes  Freelance          High        71.97  28.3
# 4096             No     Farmer          High       103.08  18.6
# 4097            Yes  Freelance        Normal       125.20  40.0
# 4098            Yes  Freelance          High        82.99  30.6
# 4099            Yes    Officer        Normal        85.28  26.2
#
#        smoking_status  alzheimer
# 0     formerly smoked          1
# 1        never smoked          1
# 2        never smoked          1
# 3              smokes          1
# 4        never smoked          1
# ...               ...        ...
# 4095     never smoked          0
# 4096          Unknown          0
# 4097     never smoked          0
# 4098     never smoked          0
# 4099          Unknown          0
#
# [4100 rows x 12 columns]

# %% [markdown]
# # MARK: Data Processing

# %%
dataSet.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4100 entries, 0 to 4099
# Data columns (total 12 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   HN              4100 non-null   int64
#  1   Education       4100 non-null   object
#  2   age             4100 non-null   float64
#  3   hypertension    4100 non-null   int64
#  4   heart_disease   4100 non-null   int64
#  5   family history  4100 non-null   object
#  6   Occupation      4100 non-null   object
#  7   Triglycerides   4100 non-null   object
#  8   Blood Sugar     4100 non-null   float64
#  9   BMI             3936 non-null   float64
#  10  smoking_status  4100 non-null   object
#  11  alzheimer       4100 non-null   int64
# dtypes: float64(3), int64(4), object(5)
# memory usage: 384.5+ KB

# %%
dataSet.isna().sum()
# Out:
# HN                  0
# Education           0
# age                 0
# hypertension        0
# heart_disease       0
# family history      0
# Occupation          0
# Triglycerides       0
# Blood Sugar         0
# BMI               164
# smoking_status      0
# alzheimer           0
# dtype: int64

# %% [markdown]
# ### MARK: เลือกที่จะ drop ทิ้งเพราะว่า Null มีจำนวนไม่เยอะมาก ไม่มีผลต่อ data เท่าที่ควร และ ไม่สามารถหาค่า BMI มาแทนที่ได้เพราะไม่มี weight และ height ของผู้ป่วย

# %%
dataSet = dataSet.dropna()
dataSet.isna().sum()
# Out:
# HN                0
# Education         0
# age               0
# hypertension      0
# heart_disease     0
# family history    0
# Occupation        0
# Triglycerides     0
# Blood Sugar       0
# BMI               0
# smoking_status    0
# alzheimer         0
# dtype: int64

# %% [markdown]
# ### MARK: ตรวจสอบ Class Target จำนวนเหมาะสมกันหรือไม่

# %%
print("Target == 1 ->", len(dataSet.loc[dataSet["alzheimer"] == 1, "alzheimer"]))
# Out:
# Target == 1 -> 202

# %%
print("Target == 1 ->", len(dataSet.loc[dataSet["alzheimer"] == 0, "alzheimer"]))
# Out:
# Target == 1 -> 3734

# %% [markdown]
# ### MARK: ปรับข้อมูล เป็น 0,1 <- LabelEncoder

# %%
from sklearn.preprocessing import LabelEncoder

# %%
dataSet.head()
# Out:
#       HN         Education   age  hypertension  heart_disease family history  \
# 0  11046  Secondary School  67.0             0              1            Yes
# 2  35112  Secondary School  80.0             0              1            Yes
# 3  67182          Bachelor  49.0             0              0            Yes
# 4   1665          Bachelor  79.0             1              0            Yes
# 5  66889  Secondary School  81.0             0              0            Yes
#
#   Occupation Triglycerides  Blood Sugar   BMI   smoking_status  alzheimer
# 0    Private        Normal       228.69  36.6  formerly smoked          1
# 2    Private          High       105.92  32.5     never smoked          1
# 3    Private        Normal       171.23  34.4           smokes          1
# 4  Freelance          High       174.12  24.0     never smoked          1
# 5    Private        Normal       186.21  29.0  formerly smoked          1

# %%
label_encoder = LabelEncoder()

# %%
dataSet['Education'] = label_encoder.fit_transform(dataSet['Education'])
dataSet['family history'] = label_encoder.fit_transform(dataSet['family history'])
dataSet['Occupation'] = label_encoder.fit_transform(dataSet['Occupation'])
dataSet['Triglycerides'] = label_encoder.fit_transform(dataSet['Triglycerides'])
dataSet['smoking_status'] = label_encoder.fit_transform(dataSet['smoking_status'])
# Out:
# C:\Users\PP\AppData\Local\Temp\ipykernel_25480\447424765.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataSet['Education'] = label_encoder.fit_transform(dataSet['Education'])
# C:\Users\PP\AppData\Local\Temp\ipykernel_25480\447424765.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataSet['family history'] = label_encoder.fit_transform(dataSet['family history'])
# C:\Users\PP\AppData\Local\Temp\ipykernel_25480\447424765.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataSet['Occupation'] = label_encoder.fit_transform(dataSet['Occupation'])
# C:\Users\PP\AppData\Local\Temp\ipykernel_25480\447424765.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataSet['Triglycerides'] = label_encoder.fit_transform(dataSet['Triglycerides'])
# C:\Users\PP\AppData\Local\Temp\ipykernel_25480\447424765.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataSet['smoking_status'] = label_encoder.fit_transform(dataSet['smoking_status'])

# %%
dataSet
# Out:
#          HN  Education   age  hypertension  heart_disease  family history  \
# 0     11046          1  67.0             0              1               1
# 2     35112          1  80.0             0              1               1
# 3     67182          0  49.0             0              0               1
# 4      1665          0  79.0             1              0               1
# 5     66889          1  81.0             0              0               1
# ...     ...        ...   ...           ...            ...             ...
# 4095  68398          1  82.0             1              0               1
# 4096  14180          0  13.0             0              0               0
# 4097  44873          0  81.0             0              0               1
# 4098  19723          0  35.0             0              0               1
# 4099  44679          0  44.0             0              0               1
#
#       Occupation  Triglycerides  Blood Sugar   BMI  smoking_status  alzheimer
# 0              4              1       228.69  36.6               1          1
# 2              4              0       105.92  32.5               2          1
# 3              4              1       171.23  34.4               3          1
# 4              1              0       174.12  24.0               2          1
# 5              4              1       186.21  29.0               1          1
# ...          ...            ...          ...   ...             ...        ...
# 4095           1              0        71.97  28.3               2          0
# 4096           0              0       103.08  18.6               0          0
# 4097           1              1       125.20  40.0               2          0
# 4098           1              0        82.99  30.6               2          0
# 4099           3              1        85.28  26.2               0          0
#
# [3936 rows x 12 columns]

# %% [markdown]
# # MARK: แบ่งข้อมูล

# %%
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, classification_report
from sklearn import tree
from sklearn.tree import plot_tree
import matplotlib.pyplot as plt

# %% [markdown]
# ### MARK: train_test_split

# %%
X = dataSet.drop(['HN', 'alzheimer'], axis=1)#dataSet.drop('alzheimer', axis=1)
y = dataSet["alzheimer"]
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# %%
X_train.head()
# Out:
#       Education   age  hypertension  heart_disease  family history  \
# 2837          0  22.0             0              0               0
# 2069          1  46.0             0              0               1
# 1724          0  42.0             0              0               1
# 1826          0  54.0             0              0               1
# 514           1   9.0             0              0               0
#
#       Occupation  Triglycerides  Blood Sugar   BMI  smoking_status
# 2837           4              0        80.72  29.3               0
# 2069           4              0        78.44  23.9               2
# 1724           1              1       124.34  34.7               1
# 1826           3              0       102.61  32.4               0
# 514            0              1       122.22  17.7               0

# %%
X_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2755 entries, 2837 to 3323
# Data columns (total 10 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Education       2755 non-null   int32
#  1   age             2755 non-null   float64
#  2   hypertension    2755 non-null   int64
#  3   heart_disease   2755 non-null   int64
#  4   family history  2755 non-null   int32
#  5   Occupation      2755 non-null   int32
#  6   Triglycerides   2755 non-null   int32
#  7   Blood Sugar     2755 non-null   float64
#  8   BMI             2755 non-null   float64
#  9   smoking_status  2755 non-null   int32
# dtypes: float64(3), int32(5), int64(2)
# memory usage: 182.9 KB

# %%
y_train.info()
# Out:
# <class 'pandas.core.series.Series'>
# Int64Index: 2755 entries, 2837 to 3323
# Series name: alzheimer
# Non-Null Count  Dtype
# --------------  -----
# 2755 non-null   int64
# dtypes: int64(1)
# memory usage: 43.0 KB

# %% [markdown]
# ### SMOTE (Synthetic Minority Over-sampling Technique): วิธีการที่ใช้การสร้างตัวอย่างสัญญาณเทียบเท่าจากคลาสน้อยโดยการผสมคุณลักษณะของตัวอย่างในคลาสน้อย

# %%
from imblearn.over_sampling import SMOTE

# %%
smote = SMOTE(random_state=42)
X_train_smote, y_train_smote = smote.fit_resample(X_train, y_train)

# %% [markdown]
# # MARK: Decision tree model Start (Default)

# %%
clfModel = tree.DecisionTreeClassifier(criterion="gini",class_weight='balanced',random_state=42)

# %%
clfModel.get_params()
# Out:
# {'ccp_alpha': 0.0,
#  'class_weight': 'balanced',
#  'criterion': 'gini',
#  'max_depth': None,
#  'max_features': None,
#  'max_leaf_nodes': None,
#  'min_impurity_decrease': 0.0,
#  'min_samples_leaf': 1,
#  'min_samples_split': 2,
#  'min_weight_fraction_leaf': 0.0,
#  'random_state': 42,
#  'splitter': 'best'}

# %%
clfModel.fit(X_train_smote,y_train_smote)
# Out:
# DecisionTreeClassifier(class_weight='balanced', random_state=42)

# %%
print("ตัวอย่างข้อมูลชุดเรียนรู้ ->",clfModel.score(X_train_smote,y_train_smote))
# อันเดียวกัน
# y_train_pred = clf.predict(X_train)
# accuracy_score(y_train, y_train_pred)
# Out:
# ตัวอย่างข้อมูลชุดเรียนรู้ -> 1.0

# %% [markdown]
# ### MARK: Visualize Decision Tree

# %%
plt.figure(figsize=(12, 6))
tree.plot_tree(clfModel.fit(X_train_smote,y_train_smote))
plt.show()

# %% [markdown]
# ### MARK: Predict and Score Model

# %%
y_pred = clfModel.predict(X_test)
print("ตัวอย่างข้อมูลชุดทดสอบ ->",accuracy_score(y_test, y_pred))
# Out:
# ตัวอย่างข้อมูลชุดทดสอบ -> 0.8653683319220999

# %%
pd.crosstab(y_test, y_pred)
# Out:
# col_0         0    1
# alzheimer
# 0          1008  106
# 1            53   14

# %%
print("Classification Report:\n", classification_report(y_test, y_pred))
# Out:
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.95      0.90      0.93      1114
#            1       0.12      0.21      0.15        67
#
#     accuracy                           0.87      1181
#    macro avg       0.53      0.56      0.54      1181
# weighted avg       0.90      0.87      0.88      1181

# %%
plt.figure(figsize=(12, 6))
tree.plot_tree(clfModel.fit(X_test,y_test))
plt.show()

# %% [markdown]
# ## MARK: หา Best Parameter และ ลองทำ Pruning

# %%
from sklearn.model_selection import GridSearchCV

# %% [markdown]
# ### MARK: ค้นหา best_params และประเมิน best_accuracy

# %%
param_grid = {
    'max_depth': [2, 4, 6, 8, 10],
    'min_samples_split': [2, 5, 10],
    'min_samples_leaf': [1, 2, 4],
    'max_features': ['auto', 'sqrt', 'log2'],
    'criterion': ['gini', 'entropy']
}
treeModel = tree.DecisionTreeClassifier()
# สร้าง Grid Search
grid_search = GridSearchCV(treeModel, param_grid, cv=10, scoring='accuracy')

# %%
grid_search.fit(X_train_smote,y_train_smote)
# Out:
# C:\Users\PP\anaconda3\envs\CallmeEnv\lib\site-packages\sklearn\model_selection\_validation.py:425: FitFailedWarning:
# 900 fits failed out of a total of 2700.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 900 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\Users\PP\anaconda3\envs\CallmeEnv\lib\site-packages\sklearn\model_selection\_validation.py", line 732, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\PP\anaconda3\envs\CallmeEnv\lib\site-packages\sklearn\base.py", line 1144, in wrapper
#     estimator._validate_params()
#   File "C:\Users\PP\anaconda3\envs\CallmeEnv\lib\site-packages\sklearn\base.py", line 637, in _validate_params
#     validate_parameter_constraints(
#   File "C:\Users\PP\anaconda3\envs\CallmeEnv\lib\site-packages\sklearn\utils\_param_validation.py", line 95, in validate_parameter_constraints
#     raise InvalidParameterError(
# sklearn.utils._param_validation.InvalidParameterError: The 'max_features' parameter of DecisionTreeClassifier must be an int in the range [1, inf), a float in the range (0.0, 1.0], a str among {'log2', 'sqrt'} or None. Got 'auto' instead.
#
#   warnings.warn(some_fits_failed_message, FitFailedWarning)
# C:\Users\PP\anaconda3\envs\CallmeEnv\lib\site-packages\sklearn\model_selection\_search.py:976: UserWarning: One or more of the test scores are non-finite: [       nan        nan        nan        nan        nan        nan
#         nan        nan        nan 0.67156489 0.7129771  0.69484733
#  0.68950382 0.69942748 0.68339695 0.7269084  0.72251908 0.69980916
#  0.7101145  0.74484733 0.74408397 0.68874046 0.7398855  0.72423664
#  0.71755725 0.71431298 0.66603053        nan        nan        nan
#         nan        nan        nan        nan        nan        nan
#  0.75       0.76583969 0.77137405 0.78396947 0.74274809 0.77652672
#  0.77385496 0.76278626 0.78053435 0.77538168 0.76946565 0.77557252
#  0.76851145 0.77232824 0.77709924 0.77538168 0.7759542  0.76412214
#         nan        nan        nan        nan        nan        nan
#         nan        nan        nan 0.81259542 0.80629771 0.8009542
#  0.79599237 0.81583969 0.80667939 0.80362595 0.81335878 0.81030534
#  0.80877863 0.80133588 0.80782443 0.79637405 0.79141221 0.80667939
#  0.80248092 0.81240458 0.81278626        nan        nan        nan
#         nan        nan        nan        nan        nan        nan
#  0.83874046 0.83339695 0.84408397 0.82251908 0.83148855 0.83416031
#  0.84599237 0.83473282 0.83339695 0.83683206 0.84255725 0.84503817
#  0.84408397 0.84274809 0.83645038 0.83931298 0.83912214 0.83854962
#         nan        nan        nan        nan        nan        nan
#         nan        nan        nan 0.87118321 0.86545802 0.86335878
#  0.87366412 0.86812977 0.86679389 0.85267176 0.85801527 0.85820611
#  0.87175573 0.87366412 0.86698473 0.87080153 0.85820611 0.85515267
#  0.86354962 0.84866412 0.8620229         nan        nan        nan
#         nan        nan        nan        nan        nan        nan
#  0.69103053 0.71526718 0.72099237 0.73778626 0.64312977 0.71087786
#  0.67328244 0.71870229 0.7120229  0.7120229  0.72977099 0.69217557
#  0.72003817 0.71431298 0.70114504 0.68416031 0.66736641 0.7471374
#         nan        nan        nan        nan        nan        nan
#         nan        nan        nan 0.76984733 0.77175573 0.74618321
#  0.76412214 0.76278626 0.77175573 0.76354962 0.7648855  0.78053435
#  0.74923664 0.76507634 0.75209924 0.76698473 0.76145038 0.74923664
#  0.77022901 0.7769084  0.76068702        nan        nan        nan
#         nan        nan        nan        nan        nan        nan
#  0.79732824 0.81278626 0.81316794 0.79828244 0.7980916  0.79923664
#  0.80706107 0.81259542 0.8009542  0.79427481 0.80477099 0.80343511
#  0.80591603 0.7860687  0.8019084  0.79332061 0.7990458  0.79942748
#         nan        nan        nan        nan        nan        nan
#         nan        nan        nan 0.82996183 0.83625954 0.81832061
#  0.83587786 0.82900763 0.83587786 0.82996183 0.82824427 0.82862595
#  0.83339695 0.83969466 0.83034351 0.83110687 0.83549618 0.8240458
#  0.82958015 0.83072519 0.83645038        nan        nan        nan
#         nan        nan        nan        nan        nan        nan
#  0.85419847 0.86259542 0.85362595 0.8528626  0.85725191 0.85438931
#  0.85648855 0.84866412 0.85305344 0.85171756 0.8601145  0.85916031
#  0.86450382 0.86374046 0.85553435 0.85687023 0.85496183 0.85935115]
#   warnings.warn(
# GridSearchCV(cv=10, estimator=DecisionTreeClassifier(),
#              param_grid={'criterion': ['gini', 'entropy'],
#                          'max_depth': [2, 4, 6, 8, 10],
#                          'max_features': ['auto', 'sqrt', 'log2'],
#                          'min_samples_leaf': [1, 2, 4],
#                          'min_samples_split': [2, 5, 10]},
#              scoring='accuracy')

# %%
best_params = grid_search.best_params_
print("Best Parameters:", best_params)
# Out:
# Best Parameters: {'criterion': 'gini', 'max_depth': 10, 'max_features': 'sqrt', 'min_samples_leaf': 2, 'min_samples_split': 2}

# %%
best_accuracy = grid_search.best_score_
print("Best Accuracy:", best_accuracy)
# Out:
# Best Accuracy: 0.8736641221374046

# %%
print("Best:",grid_search.best_score_,"using" , grid_search.best_params_)
means = grid_search.cv_results_["mean_test_score"]
stds = grid_search.cv_results_["std_test_score"]
params = grid_search.cv_results_["params"]
for means, stds, params in zip(means, stds, params):
    print("means -> %f stds-> (%f) params with: %r", means, stds, params)
# Out:
# Best: 0.8736641221374046 using {'criterion': 'gini', 'max_depth': 10, 'max_features': 'sqrt', 'min_samples_leaf': 2, 'min_samples_split': 2}
# means -> %f stds-> (%f) params with: %r nan nan {'criterion': 'gini', 'max_depth': 2, 'max_features': 'auto', 'min_samples_leaf': 1, 'min_samples_split': 2}
# means -> %f stds-> (%f) params with: %r nan nan {'criterion': 'gini', 'max_depth': 2, 'max_features': 'auto', 'min_samples_leaf': 1, 'min_samples_split': 5}
# means -> %f stds-> (%f) params with: %r nan nan {'criterion': 'gini', 'max_depth': 2, 'max_features': 'auto', 'min_samples_leaf': 1, 'min_samples_split': 10}
# means -> %f stds-> (%f) params with: %r nan nan {'criterion': 'gini', 'max_depth': 2, 'max_features': 'auto', 'min_samples_leaf': 2, 'min_samples_split': 2}
# means -> %f stds-> (%f) params with: %r nan nan {'criterion': 'gini', 'max_depth': 2, 'max_features': 'auto', 'min_samples_leaf': 2, 'min_samples_split': 5}
# means -> %f stds-> (%f) params with: %r nan nan {'criterion': 'gini', 'max_depth': 2, 'max_features': 'auto', 'min_samples_leaf': 2, 'min_samples_split': 10}
# means -> %f stds-> (%f) params with: %r nan nan {'criterion': 'gini', 'max_depth': 2, 'max_features': 'auto', 'min_samples_leaf': 4, 'min_samples_split': 2}
# means -> %f stds-> (%f) params with: %r nan nan {'criterion': 'gini', 'max_depth': 2, 'max_features': 'auto', 'min_samples_leaf': 4, 'min_samples_split': 5}
# means -> %f stds-> (%f) params with: %r nan nan {'criterion': 'gini', 'max_depth': 2, 'max_features': 'auto', 'min_samples_leaf': 4, 'min_samples_split': 10}
# means -> %f stds-> (%f) params with: %r 0.6715648854961832 0.05680775553139427 {'criterion': 'gini', 'max_depth': 2, 'max_features': 'sqrt', 'min_samples_leaf': 1, 'min_samples_split': 2}
# means -> %f stds-> (%f) params with: %r 0.7129770992366413 0.06953062978664074 {'criterion': 'gini', 'max_depth': 2, 'max_features': 'sqrt', 'min_samples_leaf': 1, 'min_samples_split': 5}
# means -> %f stds-> (%f) params with: %r 0.6948473282442749 0.06461241366615951 {'criterion': 'gini', 'max_depth': 2, 'max_features': 'sqrt', 'min_samples_leaf': 1, 'min_samples_split': 10}
# means -> %f stds-> (%f) params with: %r 0.689503816793893 0.06581645789754181 {'criterion': 'gini', 'max_depth': 2, 'max_features': 'sqrt', 'min_samples_leaf': 2, 'min_samples_split': 2}
# means -> %f stds-> (%f) params with: %r 0.6994274809160306 0.06501586588558339 {'criterion': 'gini', 'max_depth': 2, 'max_features': 'sqrt', 'min_samples_leaf': 2, 'min_samples_split': 5}
# means -> %f stds-> (%f) params with: %r 0.6833969465648855 0.06851357669625613 {'criterion': 'gini', 'max_depth': 2, 'max_features': 'sqrt', 'min_samples_leaf': 2, 'min_samples_split': 10}
# means -> %f stds-> (%f) params with: %r 0.726908396946565 0.06571899546121332 {'criterion': 'gini', 'max_depth': 2, 'max_features': 'sqrt', 'min_samples_leaf': 4, 'min_samples_split': 2}
# means -> %f stds-> (%f) params with: %r 0.7225190839694656 0.07450182233596231 {'criterion': 'gini', 'max_depth': 2, 'max_features': 'sqrt', 'min_samples_leaf': 4, 'min_samples_split': 5}
# means -> %f stds-> (%f) params with: %r 0.6998091603053435 0.07158422130644515 {'criterion': 'gini', 'max_depth': 2, 'max_features': 'sqrt', 'min_samples_leaf': 4, 'min_samples_split': 10}
# means -> %f stds-> (%f) params with: %r 0.7101145038167939 0.06639713130482497 {'criterion': 'gini', 'max_depth': 2, 'max_features': 'log2', 'min_samples_leaf': 1, 'min_samples_split': 2}
# means -> %f stds-> (%f) params with: %r 0.7448473282442748 0.061874749659428394 {'criterion': 'gini', 'max_depth': 2, 'max_features': 'log2', 'min_samples_leaf': 1, 'min_samples_split': 5}
# means -> %f stds-> (%f) params with: %r 0.7440839694656488 0.04829752653381961 {'criterion': 'gini', 'max_depth': 2, 'max_features': 'log2', 'min_samples_leaf': 1, 'min_samples_split': 10}
# means -> %f stds-> (%f) params with: %r 0.6887404580152672 0.07645720320337965 {'criterion': 'gini', 'max_depth': 2, 'max_features': 'log2', 'min_samples_leaf': 2, 'min_samples_split': 2}
# means -> %f stds-> (%f) params with: %r 0.739885496183206 0.05651594394550338 {'criterion': 'gini', 'max_depth': 2, 'max_features': 'log2', 'min_samples_leaf': 2, 'min_samples_split': 5}
# means -> %f stds-> (%f) params with: %r 0.724236641221374 0.0712537766959253 {'criterion': 'gini', 'max_depth': 2, 'max_features': 'log2', 'min_samples_leaf': 2, 'min_samples_split': 10}
# means -> %f stds-> (%f) params with: %r 0.7175572519083968 0.05974227420800966 {'criterion': 'gini', 'max_depth': 2, 'max_features': 'log2', 'min_samples_leaf': 4, 'min_samples_split': 2}
# means -> %f stds-> (%f) params with: %r 0.7143129770992366 0.06834645977800341 {'criterion': 'gini', 'max_depth': 2, 'max_features': 'log2', 'min_samples_leaf': 4, 'min_samples_split': 5}
# means -> %f stds-> (%f) params with: %r 0.666030534351145 0.05480123908823353 {'criterion': 'gini', 'max_depth': 2, 'max_features': 'log2', 'min_samples_leaf': 4, 'min_samples_split': 10}
# means -> %f stds-> (%f) params with: %r nan nan {'criterion': 'gini', 'max_depth': 4, 'max_features': 'auto', 'min_samples_leaf': 1, 'min_samples_split': 2}
# means -> %f stds-> (%f) params with: %r nan nan {'criterion': 'gini', 'max_depth': 4, 'max_features': 'auto', 'min_samples_leaf': 1, 'min_samples_split': 5}
# means -> %f stds-> (%f) params with: %r nan nan {'criterion': 'gini', 'max_depth': 4, 'max_features': 'auto', 'min_samples_leaf': 1, 'min_samples_split': 10}
# means -> %f stds-> (%f) params with: %r nan nan {'criterion': 'gini', 'max_depth': 4, 'max_features': 'auto', 'min_samples_leaf': 2, 'min_samples_split': 2}
# means -> %f stds-> (%f) params with: %r nan nan {'criterion': 'gini', 'max_depth': 4, 'max_features': 'auto', 'min_samples_leaf': 2, 'min_samples_split': 5}
# means -> %f stds-> (%f) params with: %r nan nan {'criterion': 'gini', 'max_depth': 4, 'max_features': 'auto', 'min_samples_leaf': 2, 'min_samples_split': 10}
# means -> %f stds-> (%f) params with: %r nan nan {'criterion': 'gini', 'max_depth': 4, 'max_features': 'auto', 'min_samples_leaf': 4, 'min_samples_split': 2}
# means -> %f stds-> (%f) params with: %r nan nan {'criterion': 'gini', 'max_depth': 4, 'max_features': 'auto', 'min_samples_leaf': 4, 'min_samples_split': 5}
# means -> %f stds-> (%f) params with: %r nan nan {'criterion': 'gini', 'max_depth': 4, 'max_features': 'auto', 'min_samples_leaf': 4, 'min_samples_split': 10}
# means -> %f stds-> (%f) params with: %r 0.7499999999999999 0.05043369972262269 {'criterion': 'gini', 'max_depth': 4, 'max_features': 'sqrt', 'min_samples_leaf': 1, 'min_samples_split': 2}
# means -> %f stds-> (%f) params with: %r 0.7658396946564886 0.04051963117378738 {'criterion': 'gini', 'max_depth': 4, 'max_features': 'sqrt', 'min_samples_leaf': 1, 'min_samples_split': 5}
# means -> %f stds-> (%f) params with: %r 0.7713740458015268 0.024585012084256373 {'criterion': 'gini', 'max_depth': 4, 'max_features': 'sqrt', 'min_samples_leaf': 1, 'min_samples_split': 10}
# means -> %f stds-> (%f) params with: %r 0.783969465648855 0.016030534351145022 {'criterion': 'gini', 'max_depth': 4, 'max_features': 'sqrt', 'min_samples_leaf': 2, 'min_samples_split': 2}
# means -> %f stds-> (%f) params with: %r 0.7427480916030536 0.03434902453166646 {'criterion': 'gini', 'max_depth': 4, 'max_features': 'sqrt', 'min_samples_leaf': 2, 'min_samples_split': 5}
# means -> %f stds-> (%f) params with: %r 0.7765267175572518 0.028208792443088663 {'criterion': 'gini', 'max_depth': 4, 'max_features': 'sqrt', 'min_samples_leaf': 2, 'min_samples_split': 10}
# means -> %f stds-> (%f) params with: %r 0.7738549618320609 0.04148075377784504 {'criterion': 'gini', 'max_depth': 4, 'max_features': 'sqrt', 'min_samples_leaf': 4, 'min_samples_split': 2}
# means -> %f stds-> (%f) params with: %r 0.7627862595419848 0.044650371473777734 {'criterion': 'gini', 'max_depth': 4, 'max_features': 'sqrt', 'min_samples_leaf': 4, 'min_samples_split': 5}
# means -> %f stds-> (%f) params with: %r 0.7805343511450381 0.03053435114503816 {'criterion': 'gini', 'max_depth': 4, 'max_features': 'sqrt', 'min_samples_leaf': 4, 'min_samples_split': 10}
# means -> %f stds-> (%f) params with: %r 0.7753816793893129 0.037162815028125074 {'criterion': 'gini', 'max_depth': 4, 'max_features': 'log2', 'min_samples_leaf': 1, 'min_samples_split': 2}
# means -> %f stds-> (%f) params with: %r 0.7694656488549618 0.032675411795151904 {'criterion': 'gini', 'max_depth': 4, 'max_features': 'log2', 'min_samples_leaf': 1, 'min_samples_split': 5}
# means -> %f stds-> (%f) params with: %r 0.7755725190839695 0.02684267324048435 {'criterion': 'gini', 'max_depth': 4, 'max_features': 'log2', 'min_samples_leaf': 1, 'min_samples_split': 10}
# means -> %f stds-> (%f) params with: %r 0.7685114503816795 0.0478322858362793 {'criterion': 'gini', 'max_depth': 4, 'max_features': 'log2', 'min_samples_leaf': 2, 'min_samples_split': 2}
# means -> %f stds-> (%f) params with: %r 0.7723282442748092 0.04333405985534258 {'criterion': 'gini', 'max_depth': 4, 'max_features': 'log2', 'min_samples_leaf': 2, 'min_samples_split': 5}
# means -> %f stds-> (%f) params with: %r 0.7770992366412213 0.022399085116215592 {'criterion': 'gini', 'max_depth': 4, 'max_features': 'log2', 'min_samples_leaf': 2, 'min_samples_split': 10}
# means -> %f stds-> (%f) params with: %r 0.7753816793893131 0.0227739811178191 {'criterion': 'gini', 'max_depth': 4, 'max_features': 'log2', 'min_samples_leaf': 4, 'min_samples_split': 2}
# means -> %f stds-> (%f) params with: %r 0.7759541984732825 0.033309044624841896 {'criterion': 'gini', 'max_depth': 4, 'max_features': 'log2', 'min_samples_leaf': 4, 'min_samples_split': 5}
# means -> %f stds-> (%f) params with: %r 0.7641221374045801 0.03937222245955069 {'criterion': 'gini', 'max_depth': 4, 'max_features': 'log2', 'min_samples_leaf': 4, 'min_samples_split': 10}
# means -> %f stds-> (%f) params with: %r nan nan {'criterion': 'gini', 'max_depth': 6, 'max_features': 'auto', 'min_samples_leaf': 1, 'min_samples_split': 2}
# means -> %f stds-> (%f) params with: %r nan nan {'criterion': 'gini', 'max_depth': 6, 'max_features': 'auto', 'min_samples_leaf': 1, 'min_samples_split': 5}
# means -> %f stds-> (%f) params with: %r nan nan {'criterion': 'gini', 'max_depth': 6, 'max_features': 'auto', 'min_samples_leaf': 1, 'min_samples_split': 10}
# means -> %f stds-> (%f) params with: %r nan nan {'criterion': 'gini', 'max_depth': 6, 'max_features': 'auto', 'min_samples_leaf': 2, 'min_samples_split': 2}
# means -> %f stds-> (%f) params with: %r nan nan {'criterion': 'gini', 'max_depth': 6, 'max_features': 'auto', 'min_samples_leaf': 2, 'min_samples_split': 5}
# means -> %f stds-> (%f) params with: %r nan nan {'criterion': 'gini', 'max_depth': 6, 'max_features': 'auto', 'min_samples_leaf': 2, 'min_samples_split': 10}
# means -> %f stds-> (%f) params with: %r nan nan {'criterion': 'gini', 'max_depth': 6, 'max_features': 'auto', 'min_samples_leaf': 4, 'min_samples_split': 2}
# means -> %f stds-> (%f) params with: %r nan nan {'criterion': 'gini', 'max_depth': 6, 'max_features': 'auto', 'min_samples_leaf': 4, 'min_samples_split': 5}
# means -> %f stds-> (%f) params with: %r nan nan {'criterion': 'gini', 'max_depth': 6, 'max_features': 'auto', 'min_samples_leaf': 4, 'min_samples_split': 10}
# means -> %f stds-> (%f) params with: %r 0.8125954198473282 0.025827598733919342 {'criterion': 'gini', 'max_depth': 6, 'max_features': 'sqrt', 'min_samples_leaf': 1, 'min_samples_split': 2}
# means -> %f stds-> (%f) params with: %r 0.806297709923664 0.03518133782402157 {'criterion': 'gini', 'max_depth': 6, 'max_features': 'sqrt', 'min_samples_leaf': 1, 'min_samples_split': 5}
# means -> %f stds-> (%f) params with: %r 0.8009541984732824 0.027669123328331276 {'criterion': 'gini', 'max_depth': 6, 'max_features': 'sqrt', 'min_samples_leaf': 1, 'min_samples_split': 10}
# means -> %f stds-> (%f) params with: %r 0.7959923664122137 0.026900274882707475 {'criterion': 'gini', 'max_depth': 6, 'max_features': 'sqrt', 'min_samples_leaf': 2, 'min_samples_split': 2}
# means -> %f stds-> (%f) params with: %r 0.8158396946564885 0.021493836888344078 {'criterion': 'gini', 'max_depth': 6, 'max_features': 'sqrt', 'min_samples_leaf': 2, 'min_samples_split': 5}
# means -> %f stds-> (%f) params with: %r 0.8066793893129771 0.023467075453165714 {'criterion': 'gini', 'max_depth': 6, 'max_features': 'sqrt', 'min_samples_leaf': 2, 'min_samples_split': 10}
# means -> %f stds-> (%f) params with: %r 0.8036259541984734 0.028847110083227365 {'criterion': 'gini', 'max_depth': 6, 'max_features': 'sqrt', 'min_samples_leaf': 4, 'min_samples_split': 2}
# means -> %f stds-> (%f) params with: %r 0.8133587786259543 0.030484214563733483 {'criterion': 'gini', 'max_depth': 6, 'max_features': 'sqrt', 'min_samples_leaf': 4, 'min_samples_split': 5}
# means -> %f stds-> (%f) params with: %r 0.8103053435114503 0.03027321541924187 {'criterion': 'gini', 'max_depth': 6, 'max_features': 'sqrt', 'min_samples_leaf': 4, 'min_samples_split': 10}
# means -> %f stds-> (%f) params with: %r 0.8087786259541986 0.02812280461036435 {'criterion': 'gini', 'max_depth': 6, 'max_features': 'log2', 'min_samples_leaf': 1, 'min_samples_split': 2}
# means -> %f stds-> (%f) params with: %r 0.8013358778625955 0.03410054903938645 {'criterion': 'gini', 'max_depth': 6, 'max_features': 'log2', 'min_samples_leaf': 1, 'min_samples_split': 5}
# means -> %f stds-> (%f) params with: %r 0.807824427480916 0.03161321608918746 {'criterion': 'gini', 'max_depth': 6, 'max_features': 'log2', 'min_samples_leaf': 1, 'min_samples_split': 10}
# means -> %f stds-> (%f) params with: %r 0.7963740458015266 0.02372944075623805 {'criterion': 'gini', 'max_depth': 6, 'max_features': 'log2', 'min_samples_leaf': 2, 'min_samples_split': 2}
# means -> %f stds-> (%f) params with: %r 0.791412213740458 0.02904339398795343 {'criterion': 'gini', 'max_depth': 6, 'max_features': 'log2', 'min_samples_leaf': 2, 'min_samples_split': 5}
# means -> %f stds-> (%f) params with: %r 0.806679389312977 0.019979922618698846 {'criterion': 'gini', 'max_depth': 6, 'max_features': 'log2', 'min_samples_leaf': 2, 'min_samples_split': 10}
# means -> %f stds-> (%f) params with: %r 0.8024809160305344 0.024988342949765492 {'criterion': 'gini', 'max_depth': 6, 'max_features': 'log2', 'min_samples_leaf': 4, 'min_samples_split': 2}
# means -> %f stds-> (%f) params with: %r 0.8124045801526718 0.022500477498834187 {'criterion': 'gini', 'max_depth': 6, 'max_features': 'log2', 'min_samples_leaf': 4, 'min_samples_split': 5}
# means -> %f stds-> (%f) params with: %r 0.8127862595419847 0.010844330263492663 {'criterion': 'gini', 'max_depth': 6, 'max_features': 'log2', 'min_samples_leaf': 4, 'min_samples_split': 10}
# means -> %f stds-> (%f) params with: %r nan nan {'criterion': 'gini', 'max_depth': 8, 'max_features': 'auto', 'min_samples_leaf': 1, 'min_samples_split': 2}
# means -> %f stds-> (%f) params with: %r nan nan {'criterion': 'gini', 'max_depth': 8, 'max_features': 'auto', 'min_samples_leaf': 1, 'min_samples_split': 5}
# means -> %f stds-> (%f) params with: %r nan nan {'criterion': 'gini', 'max_depth': 8, 'max_features': 'auto', 'min_samples_leaf': 1, 'min_samples_split': 10}
# means -> %f stds-> (%f) params with: %r nan nan {'criterion': 'gini', 'max_depth': 8, 'max_features': 'auto', 'min_samples_leaf': 2, 'min_samples_split': 2}
# means -> %f stds-> (%f) params with: %r nan nan {'criterion': 'gini', 'max_depth': 8, 'max_features': 'auto', 'min_samples_leaf': 2, 'min_samples_split': 5}
# means -> %f stds-> (%f) params with: %r nan nan {'criterion': 'gini', 'max_depth': 8, 'max_features': 'auto', 'min_samples_leaf': 2, 'min_samples_split': 10}
# means -> %f stds-> (%f) params with: %r nan nan {'criterion': 'gini', 'max_depth': 8, 'max_features': 'auto', 'min_samples_leaf': 4, 'min_samples_split': 2}
# means -> %f stds-> (%f) params with: %r nan nan {'criterion': 'gini', 'max_depth': 8, 'max_features': 'auto', 'min_samples_leaf': 4, 'min_samples_split': 5}
# means -> %f stds-> (%f) params with: %r nan nan {'criterion': 'gini', 'max_depth': 8, 'max_features': 'auto', 'min_samples_leaf': 4, 'min_samples_split': 10}
# means -> %f stds-> (%f) params with: %r 0.8387404580152671 0.027287407118702475 {'criterion': 'gini', 'max_depth': 8, 'max_features': 'sqrt', 'min_samples_leaf': 1, 'min_samples_split': 2}
# means -> %f stds-> (%f) params with: %r 0.8333969465648854 0.02772172377185322 {'criterion': 'gini', 'max_depth': 8, 'max_features': 'sqrt', 'min_samples_leaf': 1, 'min_samples_split': 5}
# means -> %f stds-> (%f) params with: %r 0.8440839694656488 0.028766195910384016 {'criterion': 'gini', 'max_depth': 8, 'max_features': 'sqrt', 'min_samples_leaf': 1, 'min_samples_split': 10}
# means -> %f stds-> (%f) params with: %r 0.8225190839694656 0.028992563381424336 {'criterion': 'gini', 'max_depth': 8, 'max_features': 'sqrt', 'min_samples_leaf': 2, 'min_samples_split': 2}
# means -> %f stds-> (%f) params with: %r 0.8314885496183206 0.025433282789171136 {'criterion': 'gini', 'max_depth': 8, 'max_features': 'sqrt', 'min_samples_leaf': 2, 'min_samples_split': 5}
# means -> %f stds-> (%f) params with: %r 0.8341603053435115 0.020791019126357644 {'criterion': 'gini', 'max_depth': 8, 'max_features': 'sqrt', 'min_samples_leaf': 2, 'min_samples_split': 10}
# means -> %f stds-> (%f) params with: %r 0.8459923664122136 0.022709923664122125 {'criterion': 'gini', 'max_depth': 8, 'max_features': 'sqrt', 'min_samples_leaf': 4, 'min_samples_split': 2}
# means -> %f stds-> (%f) params with: %r 0.834732824427481 0.027972178107748477 {'criterion': 'gini', 'max_depth': 8, 'max_features': 'sqrt', 'min_samples_leaf': 4, 'min_samples_split': 5}
# means -> %f stds-> (%f) params with: %r 0.8333969465648854 0.02570391785847928 {'criterion': 'gini', 'max_depth': 8, 'max_features': 'sqrt', 'min_samples_leaf': 4, 'min_samples_split': 10}
# means -> %f stds-> (%f) params with: %r 0.8368320610687023 0.025292560067712754 {'criterion': 'gini', 'max_depth': 8, 'max_features': 'log2', 'min_samples_leaf': 1, 'min_samples_split': 2}
# means -> %f stds-> (%f) params with: %r 0.8425572519083969 0.02214480660667133 {'criterion': 'gini', 'max_depth': 8, 'max_features': 'log2', 'min_samples_leaf': 1, 'min_samples_split': 5}
# means -> %f stds-> (%f) params with: %r 0.8450381679389313 0.034200262357782875 {'criterion': 'gini', 'max_depth': 8, 'max_features': 'log2', 'min_samples_leaf': 1, 'min_samples_split': 10}
# means -> %f stds-> (%f) params with: %r 0.8440839694656489 0.017657571013970082 {'criterion': 'gini', 'max_depth': 8, 'max_features': 'log2', 'min_samples_leaf': 2, 'min_samples_split': 2}
# means -> %f stds-> (%f) params with: %r 0.8427480916030534 0.026418721344537738 {'criterion': 'gini', 'max_depth': 8, 'max_features': 'log2', 'min_samples_leaf': 2, 'min_samples_split': 5}
# means -> %f stds-> (%f) params with: %r 0.8364503816793893 0.027774224597771565 {'criterion': 'gini', 'max_depth': 8, 'max_features': 'log2', 'min_samples_leaf': 2, 'min_samples_split': 10}
# means -> %f stds-> (%f) params with: %r 0.8393129770992367 0.030268402889934112 {'criterion': 'gini', 'max_depth': 8, 'max_features': 'log2', 'min_samples_leaf': 4, 'min_samples_split': 2}
# means -> %f stds-> (%f) params with: %r 0.8391221374045802 0.024350576700156574 {'criterion': 'gini', 'max_depth': 8, 'max_features': 'log2', 'min_samples_leaf': 4, 'min_samples_split': 5}
# means -> %f stds-> (%f) params with: %r 0.8385496183206108 0.021912519228102785 {'criterion': 'gini', 'max_depth': 8, 'max_features': 'log2', 'min_samples_leaf': 4, 'min_samples_split': 10}
# means -> %f stds-> (%f) params with: %r nan nan {'criterion': 'gini', 'max_depth': 10, 'max_features': 'auto', 'min_samples_leaf': 1, 'min_samples_split': 2}
# means -> %f stds-> (%f) params with: %r nan nan {'criterion': 'gini', 'max_depth': 10, 'max_features': 'auto', 'min_samples_leaf': 1, 'min_samples_split': 5}
# means -> %f stds-> (%f) params with: %r nan nan {'criterion': 'gini', 'max_depth': 10, 'max_features': 'auto', 'min_samples_leaf': 1, 'min_samples_split': 10}
# means -> %f stds-> (%f) params with: %r nan nan {'criterion': 'gini', 'max_depth': 10, 'max_features': 'auto', 'min_samples_leaf': 2, 'min_samples_split': 2}
# means -> %f stds-> (%f) params with: %r nan nan {'criterion': 'gini', 'max_depth': 10, 'max_features': 'auto', 'min_samples_leaf': 2, 'min_samples_split': 5}
# means -> %f stds-> (%f) params with: %r nan nan {'criterion': 'gini', 'max_depth': 10, 'max_features': 'auto', 'min_samples_leaf': 2, 'min_samples_split': 10}
# means -> %f stds-> (%f) params with: %r nan nan {'criterion': 'gini', 'max_depth': 10, 'max_features': 'auto', 'min_samples_leaf': 4, 'min_samples_split': 2}
# means -> %f stds-> (%f) params with: %r nan nan {'criterion': 'gini', 'max_depth': 10, 'max_features': 'auto', 'min_samples_leaf': 4, 'min_samples_split': 5}
# means -> %f stds-> (%f) params with: %r nan nan {'criterion': 'gini', 'max_depth': 10, 'max_features': 'auto', 'min_samples_leaf': 4, 'min_samples_split': 10}
# means -> %f stds-> (%f) params with: %r 0.8711832061068703 0.02454720778298715 {'criterion': 'gini', 'max_depth': 10, 'max_features': 'sqrt', 'min_samples_leaf': 1, 'min_samples_split': 2}
# means -> %f stds-> (%f) params with: %r 0.8654580152671756 0.021746516063491952 {'criterion': 'gini', 'max_depth': 10, 'max_features': 'sqrt', 'min_samples_leaf': 1, 'min_samples_split': 5}
# means -> %f stds-> (%f) params with: %r 0.8633587786259543 0.021288679034174543 {'criterion': 'gini', 'max_depth': 10, 'max_features': 'sqrt', 'min_samples_leaf': 1, 'min_samples_split': 10}
# means -> %f stds-> (%f) params with: %r 0.8736641221374046 0.026877926551844653 {'criterion': 'gini', 'max_depth': 10, 'max_features': 'sqrt', 'min_samples_leaf': 2, 'min_samples_split': 2}
# means -> %f stds-> (%f) params with: %r 0.8681297709923665 0.03261572655259572 {'criterion': 'gini', 'max_depth': 10, 'max_features': 'sqrt', 'min_samples_leaf': 2, 'min_samples_split': 5}
# means -> %f stds-> (%f) params with: %r 0.8667938931297711 0.025300478502559624 {'criterion': 'gini', 'max_depth': 10, 'max_features': 'sqrt', 'min_samples_leaf': 2, 'min_samples_split': 10}
# means -> %f stds-> (%f) params with: %r 0.852671755725191 0.022170283559477248 {'criterion': 'gini', 'max_depth': 10, 'max_features': 'sqrt', 'min_samples_leaf': 4, 'min_samples_split': 2}
# means -> %f stds-> (%f) params with: %r 0.8580152671755726 0.019744301002103164 {'criterion': 'gini', 'max_depth': 10, 'max_features': 'sqrt', 'min_samples_leaf': 4, 'min_samples_split': 5}
# means -> %f stds-> (%f) params with: %r 0.8582061068702289 0.027996254754639908 {'criterion': 'gini', 'max_depth': 10, 'max_features': 'sqrt', 'min_samples_leaf': 4, 'min_samples_split': 10}
# means -> %f stds-> (%f) params with: %r 0.8717557251908395 0.02564362905685622 {'criterion': 'gini', 'max_depth': 10, 'max_features': 'log2', 'min_samples_leaf': 1, 'min_samples_split': 2}
# means -> %f stds-> (%f) params with: %r 0.8736641221374046 0.02454053039034885 {'criterion': 'gini', 'max_depth': 10, 'max_features': 'log2', 'min_samples_leaf': 1, 'min_samples_split': 5}
# means -> %f stds-> (%f) params with: %r 0.8669847328244276 0.02209211608577261 {'criterion': 'gini', 'max_depth': 10, 'max_features': 'log2', 'min_samples_leaf': 1, 'min_samples_split': 10}
# means -> %f stds-> (%f) params with: %r 0.8708015267175572 0.02320174351304951 {'criterion': 'gini', 'max_depth': 10, 'max_features': 'log2', 'min_samples_leaf': 2, 'min_samples_split': 2}
# means -> %f stds-> (%f) params with: %r 0.8582061068702289 0.023544545211794422 {'criterion': 'gini', 'max_depth': 10, 'max_features': 'log2', 'min_samples_leaf': 2, 'min_samples_split': 5}
# means -> %f stds-> (%f) params with: %r 0.8551526717557252 0.024505630001164572 {'criterion': 'gini', 'max_depth': 10, 'max_features': 'log2', 'min_samples_leaf': 2, 'min_samples_split': 10}
# means -> %f stds-> (%f) params with: %r 0.8635496183206106 0.01994708488584624 {'criterion': 'gini', 'max_depth': 10, 'max_features': 'log2', 'min_samples_leaf': 4, 'min_samples_split': 2}
# means -> %f stds-> (%f) params with: %r 0.8486641221374047 0.025802909985956444 {'criterion': 'gini', 'max_depth': 10, 'max_features': 'log2', 'min_samples_leaf': 4, 'min_samples_split': 5}
# means -> %f stds-> (%f) params with: %r 0.8620229007633589 0.018285789108717112 {'criterion': 'gini', 'max_depth': 10, 'max_features': 'log2', 'min_samples_leaf': 4, 'min_samples_split': 10}
# means -> %f stds-> (%f) params with: %r nan nan {'criterion': 'entropy', 'max_depth': 2, 'max_features': 'auto', 'min_samples_leaf': 1, 'min_samples_split': 2}
# means -> %f stds-> (%f) params with: %r nan nan {'criterion': 'entropy', 'max_depth': 2, 'max_features': 'auto', 'min_samples_leaf': 1, 'min_samples_split': 5}
# means -> %f stds-> (%f) params with: %r nan nan {'criterion': 'entropy', 'max_depth': 2, 'max_features': 'auto', 'min_samples_leaf': 1, 'min_samples_split': 10}
# means -> %f stds-> (%f) params with: %r nan nan {'criterion': 'entropy', 'max_depth': 2, 'max_features': 'auto', 'min_samples_leaf': 2, 'min_samples_split': 2}
# means -> %f stds-> (%f) params with: %r nan nan {'criterion': 'entropy', 'max_depth': 2, 'max_features': 'auto', 'min_samples_leaf': 2, 'min_samples_split': 5}
# means -> %f stds-> (%f) params with: %r nan nan {'criterion': 'entropy', 'max_depth': 2, 'max_features': 'auto', 'min_samples_leaf': 2, 'min_samples_split': 10}
# means -> %f stds-> (%f) params with: %r nan nan {'criterion': 'entropy', 'max_depth': 2, 'max_features': 'auto', 'min_samples_leaf': 4, 'min_samples_split': 2}
# means -> %f stds-> (%f) params with: %r nan nan {'criterion': 'entropy', 'max_depth': 2, 'max_features': 'auto', 'min_samples_leaf': 4, 'min_samples_split': 5}
# means -> %f stds-> (%f) params with: %r nan nan {'criterion': 'entropy', 'max_depth': 2, 'max_features': 'auto', 'min_samples_leaf': 4, 'min_samples_split': 10}
# means -> %f stds-> (%f) params with: %r 0.691030534351145 0.06869937440802046 {'criterion': 'entropy', 'max_depth': 2, 'max_features': 'sqrt', 'min_samples_leaf': 1, 'min_samples_split': 2}
# means -> %f stds-> (%f) params with: %r 0.7152671755725191 0.073550321462985 {'criterion': 'entropy', 'max_depth': 2, 'max_features': 'sqrt', 'min_samples_leaf': 1, 'min_samples_split': 5}
# means -> %f stds-> (%f) params with: %r 0.7209923664122138 0.050294859267264534 {'criterion': 'entropy', 'max_depth': 2, 'max_features': 'sqrt', 'min_samples_leaf': 1, 'min_samples_split': 10}
# means -> %f stds-> (%f) params with: %r 0.7377862595419847 0.05498170760218816 {'criterion': 'entropy', 'max_depth': 2, 'max_features': 'sqrt', 'min_samples_leaf': 2, 'min_samples_split': 2}
# means -> %f stds-> (%f) params with: %r 0.6431297709923663 0.018659399330656985 {'criterion': 'entropy', 'max_depth': 2, 'max_features': 'sqrt', 'min_samples_leaf': 2, 'min_samples_split': 5}
# means -> %f stds-> (%f) params with: %r 0.7108778625954199 0.05038493223364535 {'criterion': 'entropy', 'max_depth': 2, 'max_features': 'sqrt', 'min_samples_leaf': 2, 'min_samples_split': 10}
# means -> %f stds-> (%f) params with: %r 0.6732824427480916 0.06863227985009723 {'criterion': 'entropy', 'max_depth': 2, 'max_features': 'sqrt', 'min_samples_leaf': 4, 'min_samples_split': 2}
# means -> %f stds-> (%f) params with: %r 0.7187022900763359 0.05913690746369148 {'criterion': 'entropy', 'max_depth': 2, 'max_features': 'sqrt', 'min_samples_leaf': 4, 'min_samples_split': 5}
# means -> %f stds-> (%f) params with: %r 0.7120229007633587 0.06455038068187101 {'criterion': 'entropy', 'max_depth': 2, 'max_features': 'sqrt', 'min_samples_leaf': 4, 'min_samples_split': 10}
# means -> %f stds-> (%f) params with: %r 0.7120229007633588 0.06518481701625263 {'criterion': 'entropy', 'max_depth': 2, 'max_features': 'log2', 'min_samples_leaf': 1, 'min_samples_split': 2}
# means -> %f stds-> (%f) params with: %r 0.7297709923664122 0.046895336040939456 {'criterion': 'entropy', 'max_depth': 2, 'max_features': 'log2', 'min_samples_leaf': 1, 'min_samples_split': 5}
# means -> %f stds-> (%f) params with: %r 0.692175572519084 0.05701637300793121 {'criterion': 'entropy', 'max_depth': 2, 'max_features': 'log2', 'min_samples_leaf': 1, 'min_samples_split': 10}
# means -> %f stds-> (%f) params with: %r 0.7200381679389314 0.05965717229636542 {'criterion': 'entropy', 'max_depth': 2, 'max_features': 'log2', 'min_samples_leaf': 2, 'min_samples_split': 2}
# means -> %f stds-> (%f) params with: %r 0.7143129770992367 0.06139019621539045 {'criterion': 'entropy', 'max_depth': 2, 'max_features': 'log2', 'min_samples_leaf': 2, 'min_samples_split': 5}
# means -> %f stds-> (%f) params with: %r 0.701145038167939 0.051287258113712444 {'criterion': 'entropy', 'max_depth': 2, 'max_features': 'log2', 'min_samples_leaf': 2, 'min_samples_split': 10}
# means -> %f stds-> (%f) params with: %r 0.6841603053435115 0.05176823521937532 {'criterion': 'entropy', 'max_depth': 2, 'max_features': 'log2', 'min_samples_leaf': 4, 'min_samples_split': 2}
# means -> %f stds-> (%f) params with: %r 0.6673664122137405 0.060535903352162135 {'criterion': 'entropy', 'max_depth': 2, 'max_features': 'log2', 'min_samples_leaf': 4, 'min_samples_split': 5}
# means -> %f stds-> (%f) params with: %r 0.7471374045801527 0.04842404483733282 {'criterion': 'entropy', 'max_depth': 2, 'max_features': 'log2', 'min_samples_leaf': 4, 'min_samples_split': 10}
# means -> %f stds-> (%f) params with: %r nan nan {'criterion': 'entropy', 'max_depth': 4, 'max_features': 'auto', 'min_samples_leaf': 1, 'min_samples_split': 2}
# means -> %f stds-> (%f) params with: %r nan nan {'criterion': 'entropy', 'max_depth': 4, 'max_features': 'auto', 'min_samples_leaf': 1, 'min_samples_split': 5}
# means -> %f stds-> (%f) params with: %r nan nan {'criterion': 'entropy', 'max_depth': 4, 'max_features': 'auto', 'min_samples_leaf': 1, 'min_samples_split': 10}
# means -> %f stds-> (%f) params with: %r nan nan {'criterion': 'entropy', 'max_depth': 4, 'max_features': 'auto', 'min_samples_leaf': 2, 'min_samples_split': 2}
# means -> %f stds-> (%f) params with: %r nan nan {'criterion': 'entropy', 'max_depth': 4, 'max_features': 'auto', 'min_samples_leaf': 2, 'min_samples_split': 5}
# means -> %f stds-> (%f) params with: %r nan nan {'criterion': 'entropy', 'max_depth': 4, 'max_features': 'auto', 'min_samples_leaf': 2, 'min_samples_split': 10}
# means -> %f stds-> (%f) params with: %r nan nan {'criterion': 'entropy', 'max_depth': 4, 'max_features': 'auto', 'min_samples_leaf': 4, 'min_samples_split': 2}
# means -> %f stds-> (%f) params with: %r nan nan {'criterion': 'entropy', 'max_depth': 4, 'max_features': 'auto', 'min_samples_leaf': 4, 'min_samples_split': 5}
# means -> %f stds-> (%f) params with: %r nan nan {'criterion': 'entropy', 'max_depth': 4, 'max_features': 'auto', 'min_samples_leaf': 4, 'min_samples_split': 10}
# means -> %f stds-> (%f) params with: %r 0.7698473282442749 0.03432144602498679 {'criterion': 'entropy', 'max_depth': 4, 'max_features': 'sqrt', 'min_samples_leaf': 1, 'min_samples_split': 2}
# means -> %f stds-> (%f) params with: %r 0.7717557251908397 0.022438073979693246 {'criterion': 'entropy', 'max_depth': 4, 'max_features': 'sqrt', 'min_samples_leaf': 1, 'min_samples_split': 5}
# means -> %f stds-> (%f) params with: %r 0.7461832061068702 0.05294898829605402 {'criterion': 'entropy', 'max_depth': 4, 'max_features': 'sqrt', 'min_samples_leaf': 1, 'min_samples_split': 10}
# means -> %f stds-> (%f) params with: %r 0.7641221374045802 0.04394454340343283 {'criterion': 'entropy', 'max_depth': 4, 'max_features': 'sqrt', 'min_samples_leaf': 2, 'min_samples_split': 2}
# means -> %f stds-> (%f) params with: %r 0.7627862595419848 0.039222548483481674 {'criterion': 'entropy', 'max_depth': 4, 'max_features': 'sqrt', 'min_samples_leaf': 2, 'min_samples_split': 5}
# means -> %f stds-> (%f) params with: %r 0.7717557251908398 0.021151375576331927 {'criterion': 'entropy', 'max_depth': 4, 'max_features': 'sqrt', 'min_samples_leaf': 2, 'min_samples_split': 10}
# means -> %f stds-> (%f) params with: %r 0.7635496183206106 0.035951382363255964 {'criterion': 'entropy', 'max_depth': 4, 'max_features': 'sqrt', 'min_samples_leaf': 4, 'min_samples_split': 2}
# means -> %f stds-> (%f) params with: %r 0.764885496183206 0.03169088359488105 {'criterion': 'entropy', 'max_depth': 4, 'max_features': 'sqrt', 'min_samples_leaf': 4, 'min_samples_split': 5}
# means -> %f stds-> (%f) params with: %r 0.7805343511450381 0.021061648337895256 {'criterion': 'entropy', 'max_depth': 4, 'max_features': 'sqrt', 'min_samples_leaf': 4, 'min_samples_split': 10}
# means -> %f stds-> (%f) params with: %r 0.749236641221374 0.04304863001716904 {'criterion': 'entropy', 'max_depth': 4, 'max_features': 'log2', 'min_samples_leaf': 1, 'min_samples_split': 2}
# means -> %f stds-> (%f) params with: %r 0.7650763358778626 0.02457982670117174 {'criterion': 'entropy', 'max_depth': 4, 'max_features': 'log2', 'min_samples_leaf': 1, 'min_samples_split': 5}
# means -> %f stds-> (%f) params with: %r 0.7520992366412214 0.037215697736744775 {'criterion': 'entropy', 'max_depth': 4, 'max_features': 'log2', 'min_samples_leaf': 1, 'min_samples_split': 10}
# means -> %f stds-> (%f) params with: %r 0.7669847328244275 0.04243727311054417 {'criterion': 'entropy', 'max_depth': 4, 'max_features': 'log2', 'min_samples_leaf': 2, 'min_samples_split': 2}
# means -> %f stds-> (%f) params with: %r 0.7614503816793893 0.043392431301152945 {'criterion': 'entropy', 'max_depth': 4, 'max_features': 'log2', 'min_samples_leaf': 2, 'min_samples_split': 5}
# means -> %f stds-> (%f) params with: %r 0.749236641221374 0.05672916569275273 {'criterion': 'entropy', 'max_depth': 4, 'max_features': 'log2', 'min_samples_leaf': 2, 'min_samples_split': 10}
# means -> %f stds-> (%f) params with: %r 0.7702290076335878 0.025335002710345188 {'criterion': 'entropy', 'max_depth': 4, 'max_features': 'log2', 'min_samples_leaf': 4, 'min_samples_split': 2}
# means -> %f stds-> (%f) params with: %r 0.7769083969465649 0.020294614912357522 {'criterion': 'entropy', 'max_depth': 4, 'max_features': 'log2', 'min_samples_leaf': 4, 'min_samples_split': 5}
# means -> %f stds-> (%f) params with: %r 0.7606870229007634 0.029170395121046556 {'criterion': 'entropy', 'max_depth': 4, 'max_features': 'log2', 'min_samples_leaf': 4, 'min_samples_split': 10}
# means -> %f stds-> (%f) params with: %r nan nan {'criterion': 'entropy', 'max_depth': 6, 'max_features': 'auto', 'min_samples_leaf': 1, 'min_samples_split': 2}
# means -> %f stds-> (%f) params with: %r nan nan {'criterion': 'entropy', 'max_depth': 6, 'max_features': 'auto', 'min_samples_leaf': 1, 'min_samples_split': 5}
# means -> %f stds-> (%f) params with: %r nan nan {'criterion': 'entropy', 'max_depth': 6, 'max_features': 'auto', 'min_samples_leaf': 1, 'min_samples_split': 10}
# means -> %f stds-> (%f) params with: %r nan nan {'criterion': 'entropy', 'max_depth': 6, 'max_features': 'auto', 'min_samples_leaf': 2, 'min_samples_split': 2}
# means -> %f stds-> (%f) params with: %r nan nan {'criterion': 'entropy', 'max_depth': 6, 'max_features': 'auto', 'min_samples_leaf': 2, 'min_samples_split': 5}
# means -> %f stds-> (%f) params with: %r nan nan {'criterion': 'entropy', 'max_depth': 6, 'max_features': 'auto', 'min_samples_leaf': 2, 'min_samples_split': 10}
# means -> %f stds-> (%f) params with: %r nan nan {'criterion': 'entropy', 'max_depth': 6, 'max_features': 'auto', 'min_samples_leaf': 4, 'min_samples_split': 2}
# means -> %f stds-> (%f) params with: %r nan nan {'criterion': 'entropy', 'max_depth': 6, 'max_features': 'auto', 'min_samples_leaf': 4, 'min_samples_split': 5}
# means -> %f stds-> (%f) params with: %r nan nan {'criterion': 'entropy', 'max_depth': 6, 'max_features': 'auto', 'min_samples_leaf': 4, 'min_samples_split': 10}
# means -> %f stds-> (%f) params with: %r 0.7973282442748092 0.03542428900815912 {'criterion': 'entropy', 'max_depth': 6, 'max_features': 'sqrt', 'min_samples_leaf': 1, 'min_samples_split': 2}
# means -> %f stds-> (%f) params with: %r 0.8127862595419847 0.020204687959362942 {'criterion': 'entropy', 'max_depth': 6, 'max_features': 'sqrt', 'min_samples_leaf': 1, 'min_samples_split': 5}
# means -> %f stds-> (%f) params with: %r 0.8131679389312977 0.01471941999868218 {'criterion': 'entropy', 'max_depth': 6, 'max_features': 'sqrt', 'min_samples_leaf': 1, 'min_samples_split': 10}
# means -> %f stds-> (%f) params with: %r 0.7982824427480917 0.023958553698434814 {'criterion': 'entropy', 'max_depth': 6, 'max_features': 'sqrt', 'min_samples_leaf': 2, 'min_samples_split': 2}
# means -> %f stds-> (%f) params with: %r 0.7980916030534351 0.02880099157238701 {'criterion': 'entropy', 'max_depth': 6, 'max_features': 'sqrt', 'min_samples_leaf': 2, 'min_samples_split': 5}
# means -> %f stds-> (%f) params with: %r 0.7992366412213741 0.019307847129682035 {'criterion': 'entropy', 'max_depth': 6, 'max_features': 'sqrt', 'min_samples_leaf': 2, 'min_samples_split': 10}
# means -> %f stds-> (%f) params with: %r 0.8070610687022901 0.02556753397918122 {'criterion': 'entropy', 'max_depth': 6, 'max_features': 'sqrt', 'min_samples_leaf': 4, 'min_samples_split': 2}
# means -> %f stds-> (%f) params with: %r 0.8125954198473282 0.018100619391418892 {'criterion': 'entropy', 'max_depth': 6, 'max_features': 'sqrt', 'min_samples_leaf': 4, 'min_samples_split': 5}
# means -> %f stds-> (%f) params with: %r 0.8009541984732825 0.023012608558608823 {'criterion': 'entropy', 'max_depth': 6, 'max_features': 'sqrt', 'min_samples_leaf': 4, 'min_samples_split': 10}
# means -> %f stds-> (%f) params with: %r 0.7942748091603054 0.02730808672760816 {'criterion': 'entropy', 'max_depth': 6, 'max_features': 'log2', 'min_samples_leaf': 1, 'min_samples_split': 2}
# means -> %f stds-> (%f) params with: %r 0.8047709923664123 0.020941124134828598 {'criterion': 'entropy', 'max_depth': 6, 'max_features': 'log2', 'min_samples_leaf': 1, 'min_samples_split': 5}
# means -> %f stds-> (%f) params with: %r 0.8034351145038168 0.023435238829021005 {'criterion': 'entropy', 'max_depth': 6, 'max_features': 'log2', 'min_samples_leaf': 1, 'min_samples_split': 10}
# means -> %f stds-> (%f) params with: %r 0.8059160305343511 0.01538717156129867 {'criterion': 'entropy', 'max_depth': 6, 'max_features': 'log2', 'min_samples_leaf': 2, 'min_samples_split': 2}
# means -> %f stds-> (%f) params with: %r 0.7860687022900763 0.02052658129342521 {'criterion': 'entropy', 'max_depth': 6, 'max_features': 'log2', 'min_samples_leaf': 2, 'min_samples_split': 5}
# means -> %f stds-> (%f) params with: %r 0.8019083969465648 0.02476213982184517 {'criterion': 'entropy', 'max_depth': 6, 'max_features': 'log2', 'min_samples_leaf': 2, 'min_samples_split': 10}
# means -> %f stds-> (%f) params with: %r 0.7933206106870229 0.02871550877191744 {'criterion': 'entropy', 'max_depth': 6, 'max_features': 'log2', 'min_samples_leaf': 4, 'min_samples_split': 2}
# means -> %f stds-> (%f) params with: %r 0.7990458015267176 0.029737331724330313 {'criterion': 'entropy', 'max_depth': 6, 'max_features': 'log2', 'min_samples_leaf': 4, 'min_samples_split': 5}
# means -> %f stds-> (%f) params with: %r 0.7994274809160304 0.023034754323963166 {'criterion': 'entropy', 'max_depth': 6, 'max_features': 'log2', 'min_samples_leaf': 4, 'min_samples_split': 10}
# means -> %f stds-> (%f) params with: %r nan nan {'criterion': 'entropy', 'max_depth': 8, 'max_features': 'auto', 'min_samples_leaf': 1, 'min_samples_split': 2}
# means -> %f stds-> (%f) params with: %r nan nan {'criterion': 'entropy', 'max_depth': 8, 'max_features': 'auto', 'min_samples_leaf': 1, 'min_samples_split': 5}
# means -> %f stds-> (%f) params with: %r nan nan {'criterion': 'entropy', 'max_depth': 8, 'max_features': 'auto', 'min_samples_leaf': 1, 'min_samples_split': 10}
# means -> %f stds-> (%f) params with: %r nan nan {'criterion': 'entropy', 'max_depth': 8, 'max_features': 'auto', 'min_samples_leaf': 2, 'min_samples_split': 2}
# means -> %f stds-> (%f) params with: %r nan nan {'criterion': 'entropy', 'max_depth': 8, 'max_features': 'auto', 'min_samples_leaf': 2, 'min_samples_split': 5}
# means -> %f stds-> (%f) params with: %r nan nan {'criterion': 'entropy', 'max_depth': 8, 'max_features': 'auto', 'min_samples_leaf': 2, 'min_samples_split': 10}
# means -> %f stds-> (%f) params with: %r nan nan {'criterion': 'entropy', 'max_depth': 8, 'max_features': 'auto', 'min_samples_leaf': 4, 'min_samples_split': 2}
# means -> %f stds-> (%f) params with: %r nan nan {'criterion': 'entropy', 'max_depth': 8, 'max_features': 'auto', 'min_samples_leaf': 4, 'min_samples_split': 5}
# means -> %f stds-> (%f) params with: %r nan nan {'criterion': 'entropy', 'max_depth': 8, 'max_features': 'auto', 'min_samples_leaf': 4, 'min_samples_split': 10}
# means -> %f stds-> (%f) params with: %r 0.8299618320610687 0.018233931399934972 {'criterion': 'entropy', 'max_depth': 8, 'max_features': 'sqrt', 'min_samples_leaf': 1, 'min_samples_split': 2}
# means -> %f stds-> (%f) params with: %r 0.836259541984733 0.021006241077583237 {'criterion': 'entropy', 'max_depth': 8, 'max_features': 'sqrt', 'min_samples_leaf': 1, 'min_samples_split': 5}
# means -> %f stds-> (%f) params with: %r 0.818320610687023 0.020192968040322588 {'criterion': 'entropy', 'max_depth': 8, 'max_features': 'sqrt', 'min_samples_leaf': 1, 'min_samples_split': 10}
# means -> %f stds-> (%f) params with: %r 0.8358778625954197 0.017963277291221522 {'criterion': 'entropy', 'max_depth': 8, 'max_features': 'sqrt', 'min_samples_leaf': 2, 'min_samples_split': 2}
# means -> %f stds-> (%f) params with: %r 0.8290076335877863 0.02621112169983112 {'criterion': 'entropy', 'max_depth': 8, 'max_features': 'sqrt', 'min_samples_leaf': 2, 'min_samples_split': 5}
# means -> %f stds-> (%f) params with: %r 0.8358778625954197 0.025332127490145222 {'criterion': 'entropy', 'max_depth': 8, 'max_features': 'sqrt', 'min_samples_leaf': 2, 'min_samples_split': 10}
# means -> %f stds-> (%f) params with: %r 0.8299618320610687 0.01952636094189992 {'criterion': 'entropy', 'max_depth': 8, 'max_features': 'sqrt', 'min_samples_leaf': 4, 'min_samples_split': 2}
# means -> %f stds-> (%f) params with: %r 0.8282442748091603 0.02583041880257805 {'criterion': 'entropy', 'max_depth': 8, 'max_features': 'sqrt', 'min_samples_leaf': 4, 'min_samples_split': 5}
# means -> %f stds-> (%f) params with: %r 0.8286259541984734 0.01559289940138587 {'criterion': 'entropy', 'max_depth': 8, 'max_features': 'sqrt', 'min_samples_leaf': 4, 'min_samples_split': 10}
# means -> %f stds-> (%f) params with: %r 0.8333969465648854 0.02121756377458089 {'criterion': 'entropy', 'max_depth': 8, 'max_features': 'log2', 'min_samples_leaf': 1, 'min_samples_split': 2}
# means -> %f stds-> (%f) params with: %r 0.8396946564885497 0.018502594875634847 {'criterion': 'entropy', 'max_depth': 8, 'max_features': 'log2', 'min_samples_leaf': 1, 'min_samples_split': 5}
# means -> %f stds-> (%f) params with: %r 0.8303435114503817 0.023129424581085682 {'criterion': 'entropy', 'max_depth': 8, 'max_features': 'log2', 'min_samples_leaf': 1, 'min_samples_split': 10}
# means -> %f stds-> (%f) params with: %r 0.8311068702290075 0.02020108255463055 {'criterion': 'entropy', 'max_depth': 8, 'max_features': 'log2', 'min_samples_leaf': 2, 'min_samples_split': 2}
# means -> %f stds-> (%f) params with: %r 0.835496183206107 0.02033674321336983 {'criterion': 'entropy', 'max_depth': 8, 'max_features': 'log2', 'min_samples_leaf': 2, 'min_samples_split': 5}
# means -> %f stds-> (%f) params with: %r 0.8240458015267175 0.019099230539231772 {'criterion': 'entropy', 'max_depth': 8, 'max_features': 'log2', 'min_samples_leaf': 2, 'min_samples_split': 10}
# means -> %f stds-> (%f) params with: %r 0.8295801526717558 0.02915603361861272 {'criterion': 'entropy', 'max_depth': 8, 'max_features': 'log2', 'min_samples_leaf': 4, 'min_samples_split': 2}
# means -> %f stds-> (%f) params with: %r 0.8307251908396946 0.029193483583037336 {'criterion': 'entropy', 'max_depth': 8, 'max_features': 'log2', 'min_samples_leaf': 4, 'min_samples_split': 5}
# means -> %f stds-> (%f) params with: %r 0.8364503816793892 0.021575016197726744 {'criterion': 'entropy', 'max_depth': 8, 'max_features': 'log2', 'min_samples_leaf': 4, 'min_samples_split': 10}
# means -> %f stds-> (%f) params with: %r nan nan {'criterion': 'entropy', 'max_depth': 10, 'max_features': 'auto', 'min_samples_leaf': 1, 'min_samples_split': 2}
# means -> %f stds-> (%f) params with: %r nan nan {'criterion': 'entropy', 'max_depth': 10, 'max_features': 'auto', 'min_samples_leaf': 1, 'min_samples_split': 5}
# means -> %f stds-> (%f) params with: %r nan nan {'criterion': 'entropy', 'max_depth': 10, 'max_features': 'auto', 'min_samples_leaf': 1, 'min_samples_split': 10}
# means -> %f stds-> (%f) params with: %r nan nan {'criterion': 'entropy', 'max_depth': 10, 'max_features': 'auto', 'min_samples_leaf': 2, 'min_samples_split': 2}
# means -> %f stds-> (%f) params with: %r nan nan {'criterion': 'entropy', 'max_depth': 10, 'max_features': 'auto', 'min_samples_leaf': 2, 'min_samples_split': 5}
# means -> %f stds-> (%f) params with: %r nan nan {'criterion': 'entropy', 'max_depth': 10, 'max_features': 'auto', 'min_samples_leaf': 2, 'min_samples_split': 10}
# means -> %f stds-> (%f) params with: %r nan nan {'criterion': 'entropy', 'max_depth': 10, 'max_features': 'auto', 'min_samples_leaf': 4, 'min_samples_split': 2}
# means -> %f stds-> (%f) params with: %r nan nan {'criterion': 'entropy', 'max_depth': 10, 'max_features': 'auto', 'min_samples_leaf': 4, 'min_samples_split': 5}
# means -> %f stds-> (%f) params with: %r nan nan {'criterion': 'entropy', 'max_depth': 10, 'max_features': 'auto', 'min_samples_leaf': 4, 'min_samples_split': 10}
# means -> %f stds-> (%f) params with: %r 0.8541984732824426 0.02802420973401623 {'criterion': 'entropy', 'max_depth': 10, 'max_features': 'sqrt', 'min_samples_leaf': 1, 'min_samples_split': 2}
# means -> %f stds-> (%f) params with: %r 0.8625954198473282 0.017594550491016974 {'criterion': 'entropy', 'max_depth': 10, 'max_features': 'sqrt', 'min_samples_leaf': 1, 'min_samples_split': 5}
# means -> %f stds-> (%f) params with: %r 0.8536259541984732 0.023091603053435106 {'criterion': 'entropy', 'max_depth': 10, 'max_features': 'sqrt', 'min_samples_leaf': 1, 'min_samples_split': 10}
# means -> %f stds-> (%f) params with: %r 0.8528625954198473 0.025510492167970033 {'criterion': 'entropy', 'max_depth': 10, 'max_features': 'sqrt', 'min_samples_leaf': 2, 'min_samples_split': 2}
# means -> %f stds-> (%f) params with: %r 0.8572519083969465 0.02551548841734087 {'criterion': 'entropy', 'max_depth': 10, 'max_features': 'sqrt', 'min_samples_leaf': 2, 'min_samples_split': 5}
# means -> %f stds-> (%f) params with: %r 0.8543893129770991 0.025760531368742703 {'criterion': 'entropy', 'max_depth': 10, 'max_features': 'sqrt', 'min_samples_leaf': 2, 'min_samples_split': 10}
# means -> %f stds-> (%f) params with: %r 0.8564885496183207 0.023679507433963517 {'criterion': 'entropy', 'max_depth': 10, 'max_features': 'sqrt', 'min_samples_leaf': 4, 'min_samples_split': 2}
# means -> %f stds-> (%f) params with: %r 0.8486641221374047 0.02458871525981614 {'criterion': 'entropy', 'max_depth': 10, 'max_features': 'sqrt', 'min_samples_leaf': 4, 'min_samples_split': 5}
# means -> %f stds-> (%f) params with: %r 0.8530534351145038 0.024139524123422733 {'criterion': 'entropy', 'max_depth': 10, 'max_features': 'sqrt', 'min_samples_leaf': 4, 'min_samples_split': 10}
# means -> %f stds-> (%f) params with: %r 0.8517175572519085 0.029749576364445838 {'criterion': 'entropy', 'max_depth': 10, 'max_features': 'log2', 'min_samples_leaf': 1, 'min_samples_split': 2}
# means -> %f stds-> (%f) params with: %r 0.8601145038167939 0.024019281389028094 {'criterion': 'entropy', 'max_depth': 10, 'max_features': 'log2', 'min_samples_leaf': 1, 'min_samples_split': 5}
# means -> %f stds-> (%f) params with: %r 0.8591603053435115 0.028329251166432822 {'criterion': 'entropy', 'max_depth': 10, 'max_features': 'log2', 'min_samples_leaf': 1, 'min_samples_split': 10}
# means -> %f stds-> (%f) params with: %r 0.8645038167938932 0.029564758367995554 {'criterion': 'entropy', 'max_depth': 10, 'max_features': 'log2', 'min_samples_leaf': 2, 'min_samples_split': 2}
# means -> %f stds-> (%f) params with: %r 0.8637404580152671 0.018208947239506185 {'criterion': 'entropy', 'max_depth': 10, 'max_features': 'log2', 'min_samples_leaf': 2, 'min_samples_split': 5}
# means -> %f stds-> (%f) params with: %r 0.8555343511450382 0.027217915592490365 {'criterion': 'entropy', 'max_depth': 10, 'max_features': 'log2', 'min_samples_leaf': 2, 'min_samples_split': 10}
# means -> %f stds-> (%f) params with: %r 0.8568702290076337 0.027297415337311004 {'criterion': 'entropy', 'max_depth': 10, 'max_features': 'log2', 'min_samples_leaf': 4, 'min_samples_split': 2}
# means -> %f stds-> (%f) params with: %r 0.8549618320610687 0.013575129193724228 {'criterion': 'entropy', 'max_depth': 10, 'max_features': 'log2', 'min_samples_leaf': 4, 'min_samples_split': 5}
# means -> %f stds-> (%f) params with: %r 0.859351145038168 0.021507388051728762 {'criterion': 'entropy', 'max_depth': 10, 'max_features': 'log2', 'min_samples_leaf': 4, 'min_samples_split': 10}

# %%
clfModel_BestParam = tree.DecisionTreeClassifier(
    max_depth=best_params['max_depth'],
    min_samples_split=best_params['min_samples_split'],
    min_samples_leaf=best_params['min_samples_leaf'],
    max_features=best_params['max_features'],
    criterion=best_params['criterion']
)

# %%
clfModel_BestParam.fit(X_train_smote, y_train_smote)
# Out:
# DecisionTreeClassifier(max_depth=10, max_features='sqrt', min_samples_leaf=2)

# %%
print("ตัวอย่างข้อมูลชุดเรียนรู้ ->",clfModel_BestParam.score(X_train_smote, y_train_smote))
# Out:
# ตัวอย่างข้อมูลชุดเรียนรู้ -> 0.9032442748091603

# %%
plt.figure(figsize=(12, 6))
tree.plot_tree(clfModel_BestParam.fit(X_train_smote,y_train_smote))
plt.show()

# %%
y_pred = clfModel_BestParam.predict(X_test)
print("ตัวอย่างข้อมูลชุดทดสอบ ->",accuracy_score(y_test, y_pred))
# Out:
# ตัวอย่างข้อมูลชุดทดสอบ -> 0.8027095681625741

# %%
pd.crosstab(y_test, y_pred)
# Out:
# col_0        0    1
# alzheimer
# 0          927  187
# 1           46   21

# %%
print("Classification Report:\n", classification_report(y_test, y_pred))
# Out:
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.95      0.83      0.89      1114
#            1       0.10      0.31      0.15        67
#
#     accuracy                           0.80      1181
#    macro avg       0.53      0.57      0.52      1181
# weighted avg       0.90      0.80      0.85      1181

# %%
plt.figure(figsize=(12, 6))
tree.plot_tree(clfModel_BestParam.fit(X_test,y_test))
plt.show()

# %% [markdown]
# ## MARK: feature_importances จากชุดเรียนรู้

# %%
np.array([X.columns.values.tolist(), list(clfModel.feature_importances_)]).T
# Out:
# array([['Education', '0.016650279771710758'],
#        ['age', '0.4635206866578581'],
#        ['hypertension', '0.025692443685866907'],
#        ['heart_disease', '0.025645844958020747'],
#        ['family history', '0.009696969696970018'],
#        ['Occupation', '0.06268895448579194'],
#        ['Triglycerides', '0.00946328740295296'],
#        ['Blood Sugar', '0.1580657103713937'],
#        ['BMI', '0.15855291708234448'],
#        ['smoking_status', '0.07002290588709051']], dtype='<U32')

# %%
feature_names = X.columns.values.tolist()
importances = clfModel.feature_importances_
indices = np.argsort(importances)[::-1]

# %%
plt.figure(figsize=(10, 6))
plt.bar(range(X.shape[1]), importances[indices], align="center")
plt.xticks(range(X.shape[1]), [feature_names[i] for i in indices], rotation=90)
plt.xlabel("Feature_names")
plt.ylabel("Importances")
plt.title("Feature importances")
plt.show()

# %% [markdown]
# ### MARK: เลือก Feature importances 4 อันดับแรก เข้า model

# %%
from sklearn.model_selection import cross_val_score

# %%
feature_importances_Select = ['age', 'smoking_status', 'Blood Sugar', 'BMI']

# %%
X_feature_importances = dataSet[feature_importances_Select]
y_feature_importances = dataSet["alzheimer"]
X_trainIm, X_testIm, y_trainIm, y_testIm = train_test_split(X_feature_importances, y_feature_importances, test_size=0.3, random_state=42)

# %%
X_train_smote_Im, y_train_smote_Im = smote.fit_resample(X_trainIm, y_trainIm)

# %% [markdown]
# ### MARK: Select Feature importances Top 4

# %%
clfModel_Im = tree.DecisionTreeClassifier(criterion="gini",class_weight='balanced', random_state=42)

# %%
clfModel_Im.fit(X_train_smote_Im, y_train_smote_Im)
# Out:
# DecisionTreeClassifier(class_weight='balanced', random_state=42)

# %%
print("ตัวอย่างข้อมูลชุดเรียนรู้ ->",clfModel_Im.score(X_train_smote_Im, y_train_smote_Im))
# Out:
# ตัวอย่างข้อมูลชุดเรียนรู้ -> 1.0

# %%
plt.figure(figsize=(12, 6))
tree.plot_tree(clfModel_Im.fit(X_train_smote_Im, y_train_smote_Im))
plt.show()

# %%
y_predIm = clfModel_Im.predict(X_testIm)
print("ตัวอย่างข้อมูลทดสอบ ->",accuracy_score(y_testIm, y_predIm))
# Out:
# ตัวอย่างข้อมูลทดสอบ -> 0.8602878916172735

# %%
pd.crosstab(y_testIm, y_predIm)
# Out:
# col_0        0    1
# alzheimer
# 0          998  116
# 1           49   18

# %%
print("Classification Report:\n", classification_report(y_testIm, y_predIm))
# Out:
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.95      0.90      0.92      1114
#            1       0.13      0.27      0.18        67
#
#     accuracy                           0.86      1181
#    macro avg       0.54      0.58      0.55      1181
# weighted avg       0.91      0.86      0.88      1181

# %%
plt.figure(figsize=(12, 6))
tree.plot_tree(clfModel_Im.fit(X_testIm, y_testIm))
plt.show()

# %% [markdown]
# ## MARK: feature_importances Top 4 + Best param

# %%
clfModel_BestParam = tree.DecisionTreeClassifier(
    max_depth=best_params['max_depth'],
    min_samples_split=best_params['min_samples_split'],
    min_samples_leaf=best_params['min_samples_leaf'],
    max_features=best_params['max_features'],
    criterion=best_params['criterion']
)

# %%
clfModel_BestParam.get_params()
# Out:
# {'ccp_alpha': 0.0,
#  'class_weight': None,
#  'criterion': 'gini',
#  'max_depth': 10,
#  'max_features': 'sqrt',
#  'max_leaf_nodes': None,
#  'min_impurity_decrease': 0.0,
#  'min_samples_leaf': 2,
#  'min_samples_split': 2,
#  'min_weight_fraction_leaf': 0.0,
#  'random_state': None,
#  'splitter': 'best'}

# %%
clfModel_BestParam.fit(X_train_smote_Im, y_train_smote_Im)
# Out:
# DecisionTreeClassifier(max_depth=10, max_features='sqrt', min_samples_leaf=2)

# %%
print("ตัวอย่างข้อมูลชุดเรียนรู้ ->",clfModel_BestParam.score(X_train_smote_Im, y_train_smote_Im))
# Out:
# ตัวอย่างข้อมูลชุดเรียนรู้ -> 0.8793893129770992

# %%
plt.figure(figsize=(12, 6))
tree.plot_tree(clfModel_BestParam.fit(X_train_smote_Im,y_train_smote_Im))
plt.show()

# %%
y_pred = clfModel_BestParam.predict(X_testIm)
print("ตัวอย่างข้อมูลชุดทดสอบ ->",accuracy_score(y_testIm, y_pred))
# Out:
# ตัวอย่างข้อมูลชุดทดสอบ -> 0.7993226079593565

# %%
pd.crosstab(y_testIm, y_pred)
# Out:
# col_0        0    1
# alzheimer
# 0          917  197
# 1           40   27

# %%
print("Classification Report:\n", classification_report(y_testIm, y_pred))
# Out:
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.96      0.82      0.89      1114
#            1       0.12      0.40      0.19        67
#
#     accuracy                           0.80      1181
#    macro avg       0.54      0.61      0.54      1181
# weighted avg       0.91      0.80      0.85      1181

# %%
plt.figure(figsize=(12, 6))
tree.plot_tree(clfModel_BestParam.fit(X_testIm,y_testIm))
plt.show()
